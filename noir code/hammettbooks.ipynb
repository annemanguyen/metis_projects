# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords

import sys
import glob
import os

import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# %%
stop = stopwords.words('english')
stop = stop + [u'said',u'back',u'like',u'know',u'little']

# %%
tokenizer = RegexpTokenizer(r'\w+')

# %%
texts = []
path = '/home/amn34/metis/stuff/noirs/hammett'
for books in sorted(glob.glob(os.path.join(path, '*.txt'))):
    doc = open(books).read()
    doc = doc.decode('utf-8')
    doc = doc.lower()
    docwords = tokenizer.tokenize(doc)
    stopped = [w for w in docwords if not w in stop]
    #p_stem = PorterStemmer()
    #stemmed_words = [p_stem.stem(i) for i in stopped]
    texts.append(stopped)

# %%
#for i in texts: print i[0:50], '\n'

# %% [markdown]
# #### words across corpus

# %%
together = [item for sublist in texts for item in sublist]

# %%
from nltk import Text

# %%
from nltk import FreqDist

# %%
books = nltk.Text(together)

# %%
len(together)
# Out:
# 147380

# %%
len(set(together))
# Out:
# 11504

# %%
import pylab

# %%
from nltk.draw import dispersion_plot

# %%
books.dispersion_plot(['girl','gun','money','look','car','marlowe'])

# %%
bookwords = [i for i in books]

# %%
books.similar('man')
# Out:
# woman elihu dorothy told room women found lawyer mans drank way face
# looked visitor yellow rumbling rocked go still partners

# %%
books.similar('gun')
# Out:
# right knees one taxi shop show settee money rest thanks go hell chair
# children letting taxicab hold police laid fitzstephan

# %%
books.similar('girl')
# Out:
# door paper paul police dundy hands day went dorothy see anything son
# sat knew anybody agreed rest four ghastly slanting

# %%
books.common_contexts(['man','gun'])
# Out:
# No common contexts were found

# %%
books.concordance('man')
# Out:
# Displaying 25 of 821 matches:
#                                       man gray first heard personville called p
# ongregation stopped beside square set man rumpled gray clothes face grayish eve
#  looking bullet holes shot asked gray man scratched neck somebody gun wanted in
# o hours drinking whiskey talking gray man think right card showed one mentioned
# forty years old elihu willsson father man killed night owned personville heart
# tand asked papa put papa put mean old man maybe guess came home began running p
# ss came home began running papers old man old devil even getting close grave le
# e lew whisper goes far enough get old man using boy shake em loose guess got ti
# hotel beefy fellow look plain clothes man stood curb talked occupant stutz tour
# car bill quint told looked past beefy man saw thaler profile young dark small p
# ures regular cut die cute uh huh gray man agreed dynamite ii czar poisonville m
# s block looked hearing shots saw dead man lying sidewalk man woman bending stre
# ing shots saw dead man lying sidewalk man woman bending street dark anyone see
# k anyone see anybody anything clearly man woman disappeared anybody else reache
# ally morning herald gave summary dead man short career civic reformer expressed
# pped laurel avenue turned toward dead man house half block something changed mi
# anged mind destination smallish young man three shades brown crossed street ahe
# mber called told somebody claimed old man secretary brought san francisco donal
# d secretary noiseless slim sharp eyed man forty brought bedroom old man head sm
# rp eyed man forty brought bedroom old man head small almost perfectly round clo
# ws time came jump grab something sort man whose pocket try pick unless lot conf
#  days ago got check son letter asking man sent work man told come house last ni
# check son letter asking man sent work man told come house last night show got d
#  went ten twenty came eleven five old man sat straight bed called young mrs wil
# frightened face appeared door get old man roared face went jealous asked could

# %%
books.collocations()
# Out:
# ned beaumont; shook head; san francisco; district attorney; last
# night; brigid oshaughnessy; new york; dinah brand; fat man; living
# room; effie perine; thousand dollars; janet henry; old man; say
# anything; lower lip; taylor henry; opened door; julia wolf; cleared
# throat

# %%
books.count('gun')+books.count('guns')
# Out:
# 197

# %%
fd = nltk.FreqDist(books)

# %%
fd
# Out:
# FreqDist({u'fawn': 2,
#           u'yellow': 60,
#           u'factory': 3,
#           u'four': 136,
#           u'askew': 1,
#           u'woods': 2,
#           u'paolis': 1,
#           u'hanging': 31,
#           u'ringlets': 1,
#           u'gabrielle': 184,
#           u'increase': 4,
#           u'fiddling': 1,
#           u'scold': 2,
#           u'consulate': 1,
#           u'fingernails': 5,
#           u'hermann': 9,
#           u'lord': 10,
#           u'shaving': 3,
#           u'swivel': 2,
#           u'bellyache': 2,
#           u'trojan': 1,
#           u'pigment': 1,
#           u'forties': 4,
#           u'foul': 2,
#           u'experimentally': 2,
#           u'stabbed': 6,
#           u'bringing': 19,
#           u'markers': 4,
#           u'disturb': 3,
#           u'prize': 2,
#           u'elihu': 59,
#           u'wednesday': 2,
#           u'wavered': 1,
#           u'shows': 6,
#           u'commented': 1,
#           u'guardsmen': 1,
#           u'charter': 2,
#           u'glassy': 5,
#           u'tired': 46,
#           u'glasss': 1,
#           u'cordially': 2,
#           u'bacon': 2,
#           u'pulse': 3,
#           u'elegant': 1,
#           u'second': 80,
#           u'crisply': 1,
#           u'sailed': 1,
#           u'scraped': 4,
#           u'haughtily': 2,
#           u'blouse': 2,
#           u'edmondson': 1,
#           u'characterless': 1,
#           u'relieving': 1,
#           u'semicircular': 1,
#           u'forgetting': 1,
#           u'thunder': 1,
#           u'cooking': 1,
#           u'fingers': 119,
#           u'bonuses': 1,
#           u'roadhouse': 5,
#           u'increasing': 3,
#           u'admiral': 2,
#           u'submerged': 2,
#           u'specialist': 1,
#           u'hero': 2,
#           u'chins': 2,
#           u'reporter': 1,
#           u'interrupting': 1,
#           u'reported': 13,
#           u'china': 16,
#           u'cult': 12,
#           u'natured': 6,
#           u'darkness': 16,
#           u'substance': 3,
#           u'k': 18,
#           u'climbed': 24,
#           u'reports': 14,
#           u'poston': 2,
#           u'military': 1,
#           u'spotty': 1,
#           u'cheerfully': 17,
#           u'golden': 6,
#           u'topography': 1,
#           u'divide': 2,
#           u'secluded': 1,
#           u'explained': 42,
#           u'shabbily': 1,
#           u'replace': 1,
#           u'brought': 124,
#           u'stern': 3,
#           u'scoffed': 2,
#           u'cocaine': 1,
#           u'reddy': 10,
#           u'cheating': 2,
#           u'spoke': 113,
#           u'cowering': 1,
#           u'backing': 6,
#           u'music': 3,
#           u'therefore': 5,
#           u'passport': 1,
#           u'strike': 12,
#           u'care': 88,
#           u'carlists': 1,
#           u'owen': 13,
#           u'holy': 11,
#           u'relax': 2,
#           u'successful': 6,
#           u'brings': 2,
#           u'anywheres': 1,
#           u'hurt': 76,
#           u'glass': 132,
#           u'harmless': 3,
#           u'tying': 3,
#           u'hurl': 1,
#           u'hole': 31,
#           u'hold': 87,
#           u'blustering': 4,
#           u'unti1': 1,
#           u'locked': 32,
#           u'tiptoeing': 1,
#           u'thaler': 102,
#           u'blade': 14,
#           u'plunged': 3,
#           u'leaped': 1,
#           u'example': 1,
#           u'pooped': 1,
#           u'household': 3,
#           u'organized': 2,
#           u'caution': 4,
#           u'want': 467,
#           u'shielding': 2,
#           u'somebodys': 1,
#           u'absolute': 2,
#           u'livened': 1,
#           u'hog': 6,
#           u'hoe': 1,
#           u'stickum': 1,
#           u'knows': 79,
#           u'groaned': 13,
#           u'complaining': 3,
#           u'dimple': 1,
#           u'travel': 1,
#           u'drying': 1,
#           u'damage': 3,
#           u'machine': 15,
#           u'hot': 33,
#           u'hop': 5,
#           u'preferable': 1,
#           u'dignified': 3,
#           u'beauty': 3,
#           u'typed': 1,
#           u'despondent': 1,
#           u'forefingers': 1,
#           u'pimps': 1,
#           u'duveen': 1,
#           u'wrong': 76,
#           u'chump': 7,
#           u'pyjamas': 3,
#           u'extortion': 1,
#           u'types': 1,
#           u'calves': 1,
#           u'choking': 5,
#           u'effective': 1,
#           u'wins': 2,
#           u'attracts': 1,
#           u'headquarters': 9,
#           u'discontinued': 1,
#           u'alias': 6,
#           u'18th': 1,
#           u'keeps': 7,
#           u'lindbergh': 1,
#           u'hellbent': 1,
#           u'wing': 3,
#           u'wind': 11,
#           u'wine': 9,
#           u'senators': 5,
#           u'pocketknife': 1,
#           u'snugly': 2,
#           u'welcomed': 1,
#           u'dreamed': 4,
#           u'roquefort': 1,
#           u'sunshine': 2,
#           u'affect': 3,
#           u'soothingly': 1,
#           u'diagonally': 5,
#           u'wrought': 1,
#           u'wickedly': 1,
#           u'fit': 30,
#           u'screaming': 3,
#           u'fix': 17,
#           u'survivors': 1,
#           u'_j': 1,
#           u'_i': 1,
#           u'accentuating': 1,
#           u'wales': 2,
#           u'hidden': 9,
#           u'easier': 10,
#           u'corridor': 66,
#           u'wooded': 1,
#           u'slicing': 1,
#           u'effects': 2,
#           u'beaut': 1,
#           u'placatory': 4,
#           u'sixteen': 3,
#           u'slats': 2,
#           u'silver': 30,
#           u'scholar': 1,
#           u'haphazardly': 1,
#           u'merrily': 10,
#           u'lillian': 1,
#           u'barton': 2,
#           u'wooden': 32,
#           u'spotless': 1,
#           u'arrow': 6,
#           u'ashdod_': 1,
#           u'addicted': 1,
#           u'interfering': 3,
#           u'cheaters': 1,
#           u'blushed': 10,
#           u'obdurate': 1,
#           u'unwary': 1,
#           u'financial': 5,
#           u'snakes': 4,
#           u'knockout': 2,
#           u'contracting': 2,
#           u'strips': 4,
#           u'substantially': 1,
#           u'laboratory': 16,
#           u'whir': 1,
#           u'message': 21,
#           u'whip': 2,
#           u'forwarding': 3,
#           u'smirk': 1,
#           u'excepting': 3,
#           u'ry': 1,
#           u'mason': 3,
#           u'encourage': 2,
#           u'adapt': 1,
#           u'dinginess': 1,
#           u'engineer': 2,
#           u'mopped': 2,
#           u'nightdress': 1,
#           u'assured': 34,
#           u'succession': 1,
#           u'threatened': 11,
#           u'fugitive': 3,
#           u'mindedly': 3,
#           u'tinkled': 1,
#           u'sheet': 16,
#           u'obstructing': 1,
#           u'enormous': 7,
#           u'ate': 28,
#           u'bates': 1,
#           u'exposing': 2,
#           u'shelves': 1,
#           u'moment': 88,
#           u'ups': 1,
#           u'shipped': 1,
#           u'disturbed': 8,
#           u'coquettishly': 1,
#           u'loudness': 1,
#           u'wobbling': 1,
#           u'bagful': 1,
#           u'fences': 1,
#           u'playfully': 4,
#           u'whitr': 1,
#           u'wash': 6,
#           u'lauter': 2,
#           u'bitten': 5,
#           u'service': 4,
#           u'similarly': 1,
#           u'xii': 2,
#           u'engagement': 10,
#           u'chamb\xe3': 1,
#           u'reuben': 3,
#           u'needed': 23,
#           u'master': 9,
#           u'listed': 3,
#           u'xiv': 2,
#           u'miller': 9,
#           u'xix': 2,
#           u'gilbert': 75,
#           u'legs': 78,
#           u'bitter': 10,
#           u'listen': 79,
#           u'rewards': 1,
#           u'collapse': 1,
#           u'cushions': 1,
#           u'scrapes': 1,
#           u'snooty': 1,
#           u'lunger': 9,
#           u'frowned': 88,
#           u'lavender': 3,
#           u'task': 3,
#           u'_the': 2,
#           u'macman': 18,
#           u'crawl': 2,
#           u'technic': 1,
#           u'positively': 11,
#           u'surer': 1,
#           u'peril': 1,
#           u'showed': 54,
#           u'coward': 3,
#           u'handcuffs': 1,
#           u'tree': 13,
#           u'rusty': 22,
#           u'walloped': 1,
#           u'blasphemer': 1,
#           u'trey': 1,
#           u'pneumonia': 1,
#           u'idle': 3,
#           u'exclaimed': 33,
#           u'friend': 43,
#           u'seminary': 1,
#           u'feeling': 28,
#           u'groaning': 1,
#           u'longs': 1,
#           u'boston': 12,
#           u'shyly': 2,
#           u'dozed': 4,
#           u'paddled': 1,
#           u'alive': 19,
#           u'dozen': 57,
#           u'farnham': 1,
#           u'affairs': 25,
#           u'wholesome': 1,
#           u'person': 33,
#           u'uinns': 1,
#           u'responsible': 16,
#           u'eagerly': 10,
#           u'metallic': 4,
#           u'toothed': 2,
#           u'defiantly': 3,
#           u'doors': 22,
#           u'season': 2,
#           u'swellest': 1,
#           u'shall': 40,
#           u'huh': 73,
#           u'object': 2,
#           u'victoria': 1,
#           u'mouth': 289,
#           u'addict': 1,
#           u'letter': 80,
#           u'conceded': 4,
#           u'retaining': 1,
#           u'dangled': 1,
#           u'eyeless': 1,
#           u'singer': 1,
#           u'stupid': 16,
#           u'episode': 1,
#           u'snooping': 3,
#           u'grove': 1,
#           u'camp': 11,
#           u'passes': 1,
#           u'drunks': 1,
#           u'grandcourt': 1,
#           u'scream': 6,
#           u'came': 639,
#           u'saying': 146,
#           u'boogie': 1,
#           u'bomb': 27,
#           u'macswain': 38,
#           u'dicker': 1,
#           u'loitered': 2,
#           u'jocular': 1,
#           u'padded': 8,
#           u'gauge': 1,
#           u'hazy': 1,
#           u'loiterer': 1,
#           u'tempted': 7,
#           u'lumpishness': 1,
#           u'abreast': 2,
#           u'hounded': 1,
#           u'caper': 4,
#           u'touches': 1,
#           u'busy': 36,
#           u'clicked': 14,
#           u'shuffling': 2,
#           u'ment': 1,
#           u'bust': 3,
#           u'unfriends': 1,
#           u'bush': 54,
#           u'touched': 47,
#           u'rich': 3,
#           u'heartily': 7,
#           u'telegrams': 1,
#           u'emphatically': 3,
#           u'plate': 12,
#           u'shepp': 8,
#           u'klein': 1,
#           u'stammered': 8,
#           u'pocket': 157,
#           u'cushion': 3,
#           u'altogether': 15,
#           u'blistered': 1,
#           u'spilling': 1,
#           u'nicely': 12,
#           u'pretzel': 3,
#           u'patch': 3,
#           u'eyelids': 14,
#           u'lurched': 2,
#           u'release': 2,
#           u'boarded': 3,
#           u'respond': 2,
#           u'blew': 37,
#           u'shrewdly': 1,
#           u'fair': 35,
#           u'irritable': 9,
#           u'unexpectedly': 2,
#           u'bled': 2,
#           u'pads': 2,
#           u'result': 5,
#           u'babyhood': 1,
#           u'testamentary': 2,
#           u'news': 52,
#           u'resigned': 1,
#           u'hammer': 2,
#           u'best': 77,
#           u'sedans': 2,
#           u'lots': 4,
#           u'sombrero': 2,
#           u'deuce': 1,
#           u'rings': 4,
#           u'stealthy': 1,
#           u'xvi': 2,
#           u'opened': 245,
#           u'stamps': 1,
#           u'score': 5,
#           u'scorn': 1,
#           u'pirate': 4,
#           u'men': 140,
#           u'nature': 4,
#           u'rolled': 27,
#           u'smelled': 4,
#           u'authorizing': 1,
#           u'twinkling': 4,
#           u'cut': 68,
#           u'wte': 1,
#           u'extent': 1,
#           u'wheelbarrow': 1,
#           u'dexterously': 1,
#           u'debt': 3,
#           u'roller': 1,
#           u'pity': 2,
#           u'accident': 21,
#           u'apish': 23,
#           u'corrupted': 1,
#           u'country': 11,
#           u'pits': 1,
#           u'readers': 2,
#           u'adventurer': 1,
#           u'demanded': 44,
#           u'planned': 1,
#           u'dents': 2,
#           u'argue': 6,
#           u'adapted': 1,
#           u'asked': 939,
#           u'obscenity': 2,
#           u'unbuttoned': 5,
#           u'blondy': 2,
#           u'swinger': 1,
#           u'canyon': 1,
#           u'haggerty': 1,
#           u'brindle': 1,
#           u'blonde': 15,
#           u'sponged': 1,
#           u'union': 6,
#           u'breathlessly': 2,
#           u'much': 381,
#           u'chucked': 10,
#           u'fry': 1,
#           u'algebraism': 1,
#           u'dots': 1,
#           u'conversational': 1,
#           u'life': 62,
#           u'crying': 22,
#           u'spit': 15,
#           u'eastern': 1,
#           u'onyx': 2,
#           u'moneys': 1,
#           u'kids': 6,
#           u'child': 34,
#           u'worked': 45,
#           u'skilfully': 1,
#           u'chill': 3,
#           u'editorially': 1,
#           u'gritty': 1,
#           u'professionally': 1,
#           u'excited': 33,
#           u'employ': 3,
#           u'viii': 3,
#           u'frisco': 3,
#           u'elaborate': 2,
#           u'skirts': 1,
#           u'remembering': 3,
#           u'played': 28,
#           u'taxicabs': 1,
#           u'ditching': 2,
#           u'weirdness': 1,
#           u'eighteen': 4,
#           u'knocks': 1,
#           u'madonna': 1,
#           u'doorman': 3,
#           u'crusaders': 1,
#           u'trusted': 12,
#           u'severity': 1,
#           u'pawnshop': 2,
#           u'jolting': 1,
#           u'things': 214,
#           u'reflectively': 2,
#           u'stolid': 3,
#           u'haphazard': 2,
#           u'swarthy': 8,
#           u'clucking': 3,
#           u'split': 14,
#           u'babies': 1,
#           u'emphatic': 1,
#           u'fairly': 18,
#           u'boiled': 1,
#           u'hosiery': 1,
#           u'tops': 2,
#           u'photographers': 1,
#           u'stiffs': 1,
#           u'boiler': 1,
#           u'ownership': 2,
#           u'supper': 2,
#           u'therell': 3,
#           u'haggard': 6,
#           u'tune': 2,
#           u'suitable': 2,
#           u'matters': 3,
#           u'stillness': 1,
#           u'coldness': 2,
#           u'subpoena': 1,
#           u'raindrops': 1,
#           u'benignity': 1,
#           u'wahi': 1,
#           u'bellow': 1,
#           u'wahl': 1,
#           u'womaned': 1,
#           u'throttling': 1,
#           u'sleepy': 6,
#           u'disguise': 3,
#           u'exclaiming': 1,
#           u'cellophane': 1,
#           u'succeeding': 2,
#           u'previous': 17,
#           u'spectacles': 5,
#           u'hal': 4,
#           u'butchering': 1,
#           u'duffer': 2,
#           u'ease': 4,
#           u'bnt': 1,
#           u'thickening': 1,
#           u'hay': 1,
#           u'easy': 36,
#           u'prison': 14,
#           u'shoemaker': 2,
#           u'east': 16,
#           u'hat': 188,
#           u'abashed': 2,
#           u'wihd': 1,
#           u'municipal': 1,
#           u'casually': 14,
#           u'confidentially': 3,
#           u'posed': 2,
#           u'possible': 25,
#           u'possibly': 4,
#           u'birth': 1,
#           u'clustered': 1,
#           u'shadow': 19,
#           u'unique': 1,
#           u'bushy': 3,
#           u'wreckage': 1,
#           u'desire': 11,
#           u'psychological': 1,
#           u'obstacles': 1,
#           u'hooey': 7,
#           u'remind': 2,
#           u'pavement': 2,
#           u'steps': 75,
#           u'attorney': 88,
#           u'right': 680,
#           u'old': 193,
#           u'creek': 1,
#           u'crowd': 9,
#           u'people': 188,
#           u'creed': 1,
#           u'broadcasters': 1,
#           u'crown': 2,
#           u'tooker': 4,
#           u'coarsened': 1,
#           u'sure': 282,
#           u'insistence': 2,
#           u'billboard': 6,
#           u'creep': 1,
#           u'enemies': 7,
#           u'chorus': 1,
#           u'mcleod': 4,
#           u'ruffled': 2,
#           u'bottom': 29,
#           u'inhuman': 1,
#           u'fox': 4,
#           u'plucked': 2,
#           u'contributing': 1,
#           u'flopping': 1,
#           u'pinched': 10,
#           u'shaker': 8,
#           u'substitutes': 1,
#           u'shifting': 5,
#           u'losing': 14,
#           u'bowing': 2,
#           u'manufacturing': 2,
#           u'shaken': 5,
#           u'benches': 6,
#           u'filipino': 3,
#           u'boiling': 1,
#           u'dollars': 80,
#           u'citizens': 2,
#           u'despain': 51,
#           u'riffraff': 1,
#           u'despair': 1,
#           u'hospitallers': 1,
#           u'sweating': 5,
#           u'lacked': 2,
#           u'slightly': 21,
#           u'match': 16,
#           u'raised': 90,
#           u'sob': 6,
#           u'statements': 1,
#           u'sod': 1,
#           u'facility': 1,
#           u'maxwell': 3,
#           u'honeymoon': 1,
#           u'son': 90,
#           u'administer': 1,
#           u'respectable': 7,
#           u'sos': 5,
#           u'magazines': 2,
#           u'stockholder': 1,
#           u'federal': 1,
#           u'peoples': 1,
#           u'support': 8,
#           u'knowing': 50,
#           u'width': 1,
#           u'joseph': 44,
#           u'spring': 14,
#           u'call': 103,
#           u'halls': 1,
#           u'leading': 12,
#           u'happy': 22,
#           u'perfumes': 1,
#           u'offer': 14,
#           u'forming': 1,
#           u'dickering': 1,
#           u'shrilly': 2,
#           u'perfumed': 2,
#           u'safeguard': 1,
#           u'incinerator': 1,
#           u'congratulations': 2,
#           u'inside': 96,
#           u'myopia': 1,
#           u'considered': 12,
#           u'unanimous': 1,
#           u'smashed': 3,
#           u'palm': 13,
#           u'examples': 1,
#           u'passenger': 1,
#           u'jounced': 1,
#           u'disgrace': 3,
#           u'bathrobe': 12,
#           u'proven': 2,
#           u'proves': 1,
#           u'accounting': 1,
#           u'mrs': 229,
#           u'dealer': 5,
#           u'negotiations': 1,
#           u'protested': 26,
#           u'stolidity': 1,
#           u'dotted': 6,
#           u'floor': 226,
#           u'roly': 1,
#           u'wary': 6,
#           u'lordre': 1,
#           u'actor': 3,
#           u'uttered': 7,
#           u'flood': 1,
#           u'pasadena': 1,
#           u'role': 1,
#           u'smell': 1,
#           u'roll': 23,
#           u'hereby': 1,
#           u'intend': 7,
#           u'hurled': 2,
#           u'palms': 13,
#           u'postmarks': 2,
#           u'maimed': 1,
#           u'intent': 3,
#           u'smelling': 4,
#           u'rolling': 10,
#           u'explosions': 1,
#           u'lunge': 1,
#           u'fastened': 5,
#           u'sniffed': 5,
#           u'whete': 1,
#           u'time': 452,
#           u'push': 14,
#           u'shrieking': 1,
#           u'gown': 16,
#           u'childs': 1,
#           u'chain': 26,
#           u'whoever': 12,
#           u'novelty': 1,
#           u'apts': 1,
#           u'nephew': 2,
#           u'jarring': 1,
#           u'chair': 279,
#           u'grifter': 1,
#           u'vet': 2,
#           u'uneven': 3,
#           u'rousing': 1,
#           u'kneaded': 1,
#           u'methodically': 1,
#           u'ouray': 5,
#           u'balled': 1,
#           u'bribed': 1,
#           u'circumstances': 6,
#           u'jerk': 7,
#           u'choice': 5,
#           u'gloomy': 5,
#           u'opinions': 2,
#           u'knapsack': 1,
#           u'stays': 4,
#           u'spats': 2,
#           u'exact': 6,
#           u'minute': 62,
#           u'tear': 8,
#           u'kneading': 1,
#           u'minnie': 50,
#           u'leave': 82,
#           u'pursue': 1,
#           u'settle': 2,
#           u'inscribed': 1,
#           u'skewer': 1,
#           u'loads': 3,
#           u'prevent': 3,
#           u'spiritual': 1,
#           u'findings': 1,
#           u'insignificant': 2,
#           u'attic': 1,
#           u'sigh': 4,
#           u'sign': 18,
#           u'chopping': 2,
#           u'shirts': 3,
#           u'anaconda': 1,
#           u'patient': 10,
#           u'nightie': 1,
#           u'coppers': 29,
#           u'celebrated': 3,
#           u'xxvii': 1,
#           u'current': 3,
#           u'lazily': 6,
#           u'mell': 1,
#           u'falling': 14,
#           u'ground': 36,
#           u'boost': 2,
#           u'banister': 2,
#           u'funeral': 2,
#           u'understanding': 8,
#           u'yards': 6,
#           u'address': 43,
#           u'alone': 98,
#           u'along': 143,
#           u'dwindling': 1,
#           u'anchoring': 1,
#           u'militar': 1,
#           u'nitroglycerine': 4,
#           u'brilliant': 2,
#           u'saws': 1,
#           u'studied': 15,
#           u'wherever': 9,
#           u'influx': 1,
#           u'nowhere': 9,
#           u'love': 49,
#           u'stockton': 7,
#           u'prefer': 3,
#           u'cabell': 1,
#           u'logical': 3,
#           u'bloody': 11,
#           u'marvelous': 3,
#           u'inquisitively': 1,
#           u'fake': 4,
#           u'sky': 8,
#           u'crammed': 1,
#           u'huskily': 6,
#           u'working': 71,
#           u'whittled': 3,
#           u'angry': 26,
#           u'tightly': 2,
#           u'opposed': 1,
#           u'wondering': 19,
#           u'shouldered': 5,
#           u'theoretical': 1,
#           u'loving': 1,
#           u'scratched': 25,
#           u'introducing': 2,
#           u'pavlov': 1,
#           u'dampness': 7,
#           u'marbles': 1,
#           u'afford': 8,
#           u'apparent': 7,
#           u'tailing': 6,
#           u'refrain': 1,
#           u'appendix': 1,
#           u'everywhere': 8,
#           u'scratches': 2,
#           u'easiest': 3,
#           u'behalf': 3,
#           u'deserved': 2,
#           u'originally': 3,
#           u'pretend': 13,
#           u'believes': 5,
#           u'printing': 1,
#           u'values': 1,
#           u'slowness': 3,
#           u'stature': 2,
#           u'believed': 30,
#           u'detached': 3,
#           u'gunfire': 1,
#           u'admired': 2,
#           u'mirrors': 1,
#           u'romanticist': 1,
#           u'hides': 1,
#           u'allowed': 4,
#           u'offense': 1,
#           u'stole': 5,
#           u'evidently': 1,
#           u'listens': 1,
#           u'winter': 2,
#           u'divided': 4,
#           u'poking': 10,
#           u'vancouver': 2,
#           u'elephant': 1,
#           u'coleman': 2,
#           u'hillen': 1,
#           u'indulgently': 7,
#           u'hof': 1,
#           u'laundry': 4,
#           u'gumming': 2,
#           u'casualness': 1,
#           u'spot': 35,
#           u'breasted': 4,
#           u'explored': 1,
#           u'mustve': 8,
#           u'date': 32,
#           u'filthy': 7,
#           u'lids': 15,
#           u'disagreeable': 6,
#           u'naturedly': 9,
#           u'natural': 12,
#           u'conscious': 10,
#           u'radiator': 1,
#           u'ordinarily': 1,
#           u'st': 20,
#           u'darkened': 10,
#           u'sh': 12,
#           u'truck': 1,
#           u'denbar': 1,
#           u'swollen': 20,
#           u'sb': 2,
#           u'wolves': 2,
#           u'pulled': 78,
#           u'drunken': 7,
#           u'beaumont': 905,
#           u'years': 98,
#           u'hiring': 3,
#           u'experiments': 6,
#           u'bucking': 3,
#           u'darting': 3,
#           u'braids': 1,
#           u'drunker': 2,
#           u'tendency': 1,
#           u'thoughtfulness': 2,
#           u'tore': 14,
#           u'jig': 1,
#           u'ovals': 1,
#           u'yawning': 8,
#           u'thumb': 42,
#           u'torn': 23,
#           u'troubles': 21,
#           u'louisville': 1,
#           u'hubbub': 1,
#           u'938': 1,
#           u'suspicion': 14,
#           u'avis': 1,
#           u'thump': 1,
#           u'troubled': 6,
#           u'mused': 1,
#           u'apron': 3,
#           u'pinkened': 1,
#           u'matches': 5,
#           u'bashful': 1,
#           u'regarding': 3,
#           u'nation': 1,
#           u'records': 2,
#           u'arriving': 1,
#           u'reckoning': 2,
#           u'twilight': 3,
#           u'maintaining': 1,
#           u'smarted': 1,
#           u'martinez': 1,
#           u'shouted': 3,
#           u'dido': 1,
#           u'brody': 1,
#           u'revert': 1,
#           u'veins': 2,
#           u'quarter': 20,
#           u'cordiality': 1,
#           u'stalling': 10,
#           u'square': 37,
#           u'honduras': 1,
#           u'bursting': 1,
#           u'receipt': 4,
#           u'frames': 1,
#           u'owing': 3,
#           u'entering': 1,
#           u'sheathlike': 1,
#           u'naked': 4,
#           u'container': 1,
#           u'rounding': 1,
#           u'sniveling': 1,
#           u'maced': 1,
#           u'squared': 5,
#           u'astray': 1,
#           u'downhill': 8,
#           u'seriously': 18,
#           u'investigation': 7,
#           u'gunnison': 3,
#           u'suggesting': 1,
#           u'crawling': 5,
#           u'million': 4,
#           u'seventh': 6,
#           u'possibility': 2,
#           u'quite': 61,
#           u'fainter': 4,
#           u'inwardly': 1,
#           u'complicated': 3,
#           u'crazier': 1,
#           u'besides': 37,
#           u'longines': 1,
#           u'bumpy': 1,
#           u'quits': 2,
#           u'scarred': 3,
#           u'remainder': 5,
#           u'seventy': 14,
#           u'shores': 1,
#           u'training': 1,
#           u'dunne': 1,
#           u'disguised': 2,
#           u'gaff': 2,
#           u'modest': 3,
#           u'haldorns': 25,
#           u'mesopotamian': 1,
#           u'livingston': 2,
#           u'aboard': 3,
#           u'hooch': 3,
#           u'neglect': 2,
#           u'jumbled': 1,
#           u'emotion': 8,
#           u'intuition': 6,
#           u'saving': 6,
#           u'spoken': 13,
#           u'insecurely': 1,
#           u'one': 846,
#           u'cloakroom': 1,
#           u'voto': 1,
#           u'spanish': 2,
#           u'vote': 2,
#           u'chubby': 2,
#           u'potted': 2,
#           u'open': 165,
#           u'city': 113,
#           u'boulevard': 5,
#           u'convent': 1,
#           u'bite': 5,
#           u'indicate': 15,
#           u'twenties': 4,
#           u'stuffed': 8,
#           u'typing': 2,
#           u'bits': 5,
#           u'lingering': 1,
#           u'shawl': 1,
#           u'proving': 4,
#           u'meddling': 2,
#           u'swish': 2,
#           u'ridiculous': 13,
#           u'slashed': 1,
#           u'fooled': 2,
#           u'straightening': 3,
#           u'inventor': 6,
#           ...})

# %%
plt.figure(figsize = (12,8))
fd.plot(50,cumulative=False,color='purple')

# %%
fd.hapaxes()
# Out:
# [u'keno',
#  u'paolis',
#  u'ringlets',
#  u'pierce',
#  u'pigment',
#  u'wavered',
#  u'busybody',
#  u'commented',
#  u'guardsmen',
#  u'glasss',
#  u'elegant',
#  u'crisply',
#  u'sailed',
#  u'edmondson',
#  u'relieving',
#  u'semicircular',
#  u'thunder',
#  u'cooking',
#  u'bonuses',
#  u'specialist',
#  u'reporter',
#  u'interrupting',
#  u'military',
#  u'spotty',
#  u'topography',
#  u'garageman',
#  u'shabbily',
#  u'replace',
#  u'cocaine',
#  u'cloven',
#  u'moth',
#  u'passport',
#  u'plodded',
#  u'carlists',
#  u'anywheres',
#  u'pointedly',
#  u'hurl',
#  u'unti1',
#  u'leaped',
#  u'example',
#  u'pooped',
#  u'glued',
#  u'arresting',
#  u'somebodys',
#  u'livened',
#  u'hoe',
#  u'stickum',
#  u'dimple',
#  u'travel',
#  u'drying',
#  u'gouge',
#  u'preferable',
#  u'typed',
#  u'despondent',
#  u'forefingers',
#  u'pimps',
#  u'duveen',
#  u'italy',
#  u'extortion',
#  u'types',
#  u'calves',
#  u'welts',
#  u'effective',
#  u'attracts',
#  u'childhood',
#  u'18th',
#  u'lindbergh',
#  u'hellbent',
#  u'sarcastically',
#  u'pocketknife',
#  u'welcomed',
#  u'roquefort',
#  u'soothingly',
#  u'sentry',
#  u'wrought',
#  u'wickedly',
#  u'survivors',
#  u'rescued',
#  u'_j',
#  u'_i',
#  u'accentuating',
#  u'wooded',
#  u'slicing',
#  u'indecent',
#  u'beaut',
#  u'scholar',
#  u'haphazardly',
#  u'lillian',
#  u'spotless',
#  u'ashdod_',
#  u'addicted',
#  u'obdurate',
#  u'superintendents',
#  u'substantially',
#  u'whir',
#  u'smirk',
#  u'ry',
#  u'adapt',
#  u'dinginess',
#  u'sexton',
#  u'succession',
#  u'tinkled',
#  u'contrition',
#  u'bates',
#  u'shelves',
#  u'heading',
#  u'shipped',
#  u'coquettishly',
#  u'loudness',
#  u'wobbling',
#  u'bagful',
#  u'similarly',
#  u'chamb\xe3',
#  u'rewards',
#  u'collapse',
#  u'cushions',
#  u'scrapes',
#  u'snooty',
#  u'technic',
#  u'surer',
#  u'peril',
#  u'handcuffs',
#  u'walloped',
#  u'blasphemer',
#  u'trey',
#  u'pneumonia',
#  u'sheen',
#  u'silky',
#  u'seminary',
#  u'groaning',
#  u'longs',
#  u'lads',
#  u'width',
#  u'paddled',
#  u'farnham',
#  u'wholesome',
#  u'concrete',
#  u'uinns',
#  u'hum',
#  u'swellest',
#  u'screwing',
#  u'victoria',
#  u'addict',
#  u'retaining',
#  u'dangled',
#  u'eyeless',
#  u'singer',
#  u'episode',
#  u'grove',
#  u'drunks',
#  u'grandcourt',
#  u'boogie',
#  u'dicker',
#  u'jocular',
#  u'gauge',
#  u'asia',
#  u'loiterer',
#  u'lumpishness',
#  u'hounded',
#  u'touches',
#  u'ment',
#  u'buchman',
#  u'telegrams',
#  u'klein',
#  u'blistered',
#  u'spilling',
#  u'accordance',
#  u'templars',
#  u'doze',
#  u'babyhood',
#  u'resigned',
#  u'stealthy',
#  u'stamps',
#  u'alignment',
#  u'scorn',
#  u'espied',
#  u'authorizing',
#  u'wte',
#  u'extent',
#  u'wheelbarrow',
#  u'dexterously',
#  u'roller',
#  u'pits',
#  u'conclusions',
#  u'adventurer',
#  u'planned',
#  u'adapted',
#  u'topmost',
#  u'advertisements',
#  u'canyon',
#  u'haggerty',
#  u'brindle',
#  u'truthful',
#  u'sponged',
#  u'fry',
#  u'algebraism',
#  u'dots',
#  u'conversational',
#  u'eastern',
#  u'moneys',
#  u'skilfully',
#  u'gritty',
#  u'professionally',
#  u'flabbily',
#  u'skirts',
#  u'taxicabs',
#  u'weirdness',
#  u'madonna',
#  u'crusaders',
#  u'severity',
#  u'jolting',
#  u'cumbersome',
#  u'babies',
#  u'emphatic',
#  u'boiled',
#  u'hosiery',
#  u'monino',
#  u'photographers',
#  u'stiffs',
#  u'boiler',
#  u'registering',
#  u'chafing',
#  u'stillness',
#  u'subpoena',
#  u'raindrops',
#  u'benignity',
#  u'wahi',
#  u'bellow',
#  u'wahl',
#  u'womaned',
#  u'throttling',
#  u'placidity',
#  u'exclaiming',
#  u'cellophane',
#  u'marcelled',
#  u'bnt',
#  u'thickening',
#  u'hay',
#  u'johnnie',
#  u'wihd',
#  u'municipal',
#  u'birth',
#  u'clustered',
#  u'unique',
#  u'jackets',
#  u'creed',
#  u'creep',
#  u'consensus',
#  u'inhuman',
#  u'contributing',
#  u'flopping',
#  u'gorge',
#  u'substitutes',
#  u'rep',
#  u'mcintyre',
#  u'riffraff',
#  u'despair',
#  u'hospitallers',
#  u'statements',
#  u'sod',
#  u'facility',
#  u'honeymoon',
#  u'administer',
#  u'stockholder',
#  u'humorous',
#  u'goddamn',
#  u'halls',
#  u'perfumes',
#  u'forming',
#  u'dickering',
#  u'safeguard',
#  u'incinerator',
#  u'myopia',
#  u'unanimous',
#  u'passenger',
#  u'proves',
#  u'accounting',
#  u'negotiations',
#  u'stolidity',
#  u'roly',
#  u'lordre',
#  u'flood',
#  u'pasadena',
#  u'role',
#  u'smell',
#  u'hereby',
#  u'slaves',
#  u'maimed',
#  u'explosions',
#  u'whete',
#  u'archaeologist',
#  u'writhe',
#  u'firecracker',
#  u'resources',
#  u'apts',
#  u'jarring',
#  u'understandable',
#  u'grifter',
#  u'rousing',
#  u'methodically',
#  u'balled',
#  u'bribed',
#  u'knapsack',
#  u'kneading',
#  u'pursue',
#  u'inscribed',
#  u'skewer',
#  u'spiritual',
#  u'findings',
#  u'attic',
#  u'anaconda',
#  u'depressions',
#  u'nightie',
#  u'maine',
#  u'mell',
#  u'dwindling',
#  u'anchoring',
#  u'militar',
#  u'saws',
#  u'influx',
#  u'cabell',
#  u'inquisitively',
#  u'raiding',
#  u'crammed',
#  u'fresher',
#  u'opposed',
#  u'theoretical',
#  u'loving',
#  u'pavlov',
#  u'marbles',
#  u'chesty',
#  u'israel',
#  u'refrain',
#  u'appendix',
#  u'intoxicated',
#  u'discontented',
#  u'printing',
#  u'values',
#  u'gunfire',
#  u'mirrors',
#  u'romanticist',
#  u'hides',
#  u'offense',
#  u'evidently',
#  u'listens',
#  u'attempting',
#  u'elephant',
#  u'mormon',
#  u'hof',
#  u'aging',
#  u'casualness',
#  u'explored',
#  u'canvassing',
#  u'ordinarily',
#  u'truck',
#  u'denbar',
#  u'tendency',
#  u'jig',
#  u'ovals',
#  u'louisville',
#  u'hubbub',
#  u'938',
#  u'avis',
#  u'thump',
#  u'mused',
#  u'pinkened',
#  u'bashful',
#  u'nation',
#  u'remonstrated',
#  u'arriving',
#  u'maintaining',
#  u'smarted',
#  u'folsom',
#  u'dido',
#  u'brody',
#  u'revert',
#  u'shores',
#  u'breach',
#  u'cordiality',
#  u'honduras',
#  u'bursting',
#  u'kleptomaniac',
#  u'remembrance',
#  u'entering',
#  u'sheathlike',
#  u'joker',
#  u'container',
#  u'rounding',
#  u'sniveling',
#  u'astray',
#  u'caf\xe3',
#  u'suggesting',
#  u'spaniard',
#  u'inwardly',
#  u'crazier',
#  u'longines',
#  u'bumpy',
#  u'newsie',
#  u'monogrammed',
#  u'training',
#  u'dunne',
#  u'mesopotamian',
#  u'jumbled',
#  u'insecurely',
#  u'cloakroom',
#  u'voto',
#  u'teaches',
#  u'convent',
#  u'lesbian',
#  u'lingering',
#  u'shawl',
#  u'slashed',
#  u'impractical',
#  u'overtaken',
#  u'depressed',
#  u'favors',
#  u'ratting',
#  u'nie',
#  u'winkle',
#  u'illness',
#  u'sao',
#  u'pimply',
#  u'wronged',
#  u'goodman',
#  u'fashionably',
#  u'handshaking',
#  u'printer',
#  u'paged',
#  u'darkish',
#  u'risen',
#  u'knowingly',
#  u'inserted',
#  u'bads',
#  u'touchy',
#  u'cushioned',
#  u'squint',
#  u'butchered',
#  u'quiescent',
#  u'affirmed',
#  u'friction',
#  u'scarce',
#  u'cloak',
#  u'aimlessly',
#  u'carolina',
#  u'dissimilar',
#  u'windowed',
#  u'condemning',
#  u'tilting',
#  u'prime',
#  u'epistles',
#  u'worries',
#  u'morose',
#  u'sheathed',
#  u'motionlessness',
#  u'keyboard',
#  u'purest',
#  u'saundproofing',
#  u'bootleg',
#  u'goers',
#  u'wests',
#  u'moldy',
#  u'teens',
#  u'checkered',
#  u'amory',
#  u'icily',
#  u'jokers',
#  u'millionaire',
#  u'riddle',
#  u'inclining',
#  u'extravagantly',
#  u'feinted',
#  u'factness',
#  u'combined',
#  u'unbridgeable',
#  u'reflective',
#  u'crawford',
#  u'xxvi',
#  u'enable',
#  u'gish',
#  u'libel',
#  u'colluding',
#  u'polly',
#  u'intimately',
#  u'dressy',
#  u'collarless',
#  u'osgood',
#  u'brow',
#  u'pinky',
#  u'regularity',
#  u'croaker',
#  u'fame',
#  u'knowitall',
#  u'eadie',
#  u'scientifically',
#  u'essayed',
#  u'fatima',
#  u'lovers',
#  u'otto',
#  u'breakdown',
#  u'assigns',
#  u'sickness',
#  u'dreaminess',
#  u'cheery',
#  u'peculiarities',
#  u'machen',
#  u'214',
#  u'judiciously',
#  u'slimy',
#  u'trimmings',
#  u'grounded',
#  u'emily',
#  u'undeveloped',
#  u'jarred',
#  u'dryly',
#  u'pow',
#  u'prominently',
#  u'hereunto',
#  u'hove',
#  u'dromomania',
#  u'snare',
#  u'postal',
#  u'boast',
#  u'hustling',
#  u'discarded',
#  u'stationary',
#  u'grub',
#  u'pickled',
#  u'humdinger',
#  u'allaury',
#  u'belched',
#  u'scuffed',
#  u'memories',
#  u'scottie',
#  u'nook',
#  u'23rd',
#  u'dimples',
#  u'draggers',
#  u'unsuccessfully',
#  u'ration',
#  u'subscribed',
#  u'cares',
#  u'origine',
#  u'amusedly',
#  u'knifing',
#  u'chivalry',
#  u'bookcases',
#  u'snoutful',
#  u'bristled',
#  u'hookers',
#  u'wits',
#  u'mick',
#  u'mice',
#  u'mopping',
#  u'glinting',
#  u'exaniple',
#  u'pulp',
#  u'rust',
#  u'detailed',
#  u'escaping',
#  u'walks',
#  u'crease',
#  u'anywhcres',
#  u'fromthe',
#  u'roofed',
#  u'someones',
#  u'congress',
#  u'tove',
#  u'psychiatry',
#  u'homely',
#  u'culet',
#  u'menace',
#  u'graystone',
#  u'roadway',
#  u'chorusman',
#  u'puzzles',
#  u'hooking',
#  u'scrapping',
#  u'unbuttoning',
#  u'pigskin',
#  u'quicker',
#  u'nightdress',
#  u'paso',
#  u'healed',
#  u'tidily',
#  u'premature',
#  u'rehearsed',
#  u'hick',
#  u'handicapped',
#  u'hopheads',
#  u'imperceptibly',
#  u'whirled',
#  u'revealing',
#  u'hash',
#  u'indecision',
#  u'smartest',
#  u'gateposts',
#  u'shrieks',
#  u'introductory',
#  u'bulges',
#  u'acquittal',
#  u'brimmed',
#  u'vetch',
#  u'beheld',
#  u'obstructing',
#  u'trips',
#  u'wavering',
#  u'lameness',
#  u'chisel',
#  u'unguents',
#  u'prompt',
#  u'gallop',
#  u'rustled',
#  u'gerguson',
#  u'bided',
#  u'elaborately',
#  u'dazzle',
#  u'hickey',
#  u'reprimanded',
#  u'dismissed',
#  u'dilly',
#  u'tinge',
#  u'freshly',
#  u'occur',
#  u'clink',
#  u'blotter',
#  u'plane',
#  u'maltese',
#  u'authentic',
#  u'plank',
#  u'resemble',
#  u'rowdy',
#  u'deuces',
#  u'protestation',
#  u'wrench',
#  u'deafening',
#  u'quarreling',
#  u'wooly',
#  u'pant',
#  u'pane',
#  u'replies',
#  u'housemen',
#  u'blurring',
#  u'plotters',
#  u'shuddering',
#  u'ruining',
#  u'skipped',
#  u'severely',
#  u'propose',
#  u'tinie',
#  u'dispiritedly',
#  u'weeds',
#  u'likeness',
#  u'betweens',
#  u'blackjacks',
#  u'strangling',
#  u'energetically',
#  u'disorganized',
#  u'lantern',
#  u'resolute',
#  u'reduce',
#  u'tahiti',
#  u'immensely',
#  u'haldeman',
#  u'psychology',
#  u'workcd',
#  u'silks',
#  u'impudence',
#  u'attentions',
#  u'demure',
#  u'drifting',
#  u'drives',
#  u'abnormally',
#  u'reproach',
#  u'plowing',
#  u'insolence',
#  u'anecdote',
#  u'testament',
#  u'clump',
#  u'corrugated',
#  u'dumbfounded',
#  u'tappity',
#  u'broadcasted',
#  u'spiritually',
#  u'ironing',
#  u'numbed',
#  u'glitter',
#  u'peaceable',
#  u'introduction',
#  u'nobly',
#  u'flimsy',
#  u'caddopeak',
#  u'slopping',
#  u'justly',
#  u'spongy',
#  u'omelette',
#  u'grooved',
#  u'appreciation',
#  u'interviewer',
#  u'critically',
#  u'pear',
#  u'taxis',
#  u'insertion',
#  u'suffocating',
#  u'encumbering',
#  u'commotion',
#  u'nasal',
#  u'oyster',
#  u'unequal',
#  u'arson',
#  u'barred',
#  u'squunched',
#  u'barren',
#  u'wording',
#  u'pentagonal',
#  u'hipped',
#  u'flirted',
#  u'defended',
#  u'session',
#  u'overwhelmed',
#  u'consistently',
#  u'writes',
#  u'unjustly',
#  u'begins',
#  u'magicians',
#  u'beams',
#  u'resent',
#  u'remedy',
#  u'adhered',
#  u'frightening',
#  u'tumors',
#  u'disregarding',
#  u'terrifically',
#  u'tottering',
#  u'exercise',
#  u'bozo',
#  u'butchering',
#  u'debros',
#  u'baritone',
#  u'guides',
#  u'captured',
#  u'theatricals',
#  u'monsters',
#  u'15th',
#  u'renewed',
#  u'legislature',
#  u'fuff',
#  u'thou',
#  u'les',
#  u'wholl',
#  u'poverty',
#  u'patty',
#  u'loaf',
#  u'smashing',
#  u'dimensional',
#  u'mink',
#  u'adjoining',
#  u'jowls',
#  u'disowning',
#  u'monthly',
#  u'powdermarks',
#  u'widening',
#  u'pinkness',
#  u'raced',
#  u'squirrel',
#  u'mildness',
#  u'engage',
#  u'insiders',
#  u'towns',
#  u'consulate',
#  u'hardness',
#  u'forgetting',
#  u'marmora',
#  u'robin',
#  u'seams',
#  u'agitation',
#  u'chasm',
#  u'inches_',
#  u'gunk',
#  u'constricted',
#  u'satyrs',
#  u'elevated',
#  u'reachable',
#  u'specimen',
#  u'sicily',
#  u'snail',
#  u'deformity',
#  u'horde',
#  u'mongrels',
#  u'manhunting',
#  u'picks',
#  u'uncouth',
#  u'4th',
#  u'cod',
#  u'swinger',
#  u'jutting',
#  u'australia',
#  u'suffering',
#  u'quest',
#  u'sawed',
#  u'flannel',
#  u'sorting',
#  u'ivas',
#  u'wrastle',
#  u'chorus',
#  u'ornately',
#  u'clipping',
#  u'snuffled',
#  u'novelty',
#  u'inclination',
#  u'inserting',
#  u'dictates',
#  u'briefest',
#  u'tidal',
#  u'relating',
#  u'obscured',
#  u'dirtier',
#  u'oiling',
#  u'sub',
#  u'deserves',
#  u'libert',
#  u'illegal',
#  u'blackmailed',
#  u'colorado',
#  u'thudded',
#  u'primarily',
#  u'blubbered',
#  u'earysipelas',
#  u'tasting',
#  u'spending',
#  u'assuring',
#  u'submit',
#  u'custom',
#  u'occupy',
#  u'royalties',
#  u'instalments',
#  u'inched',
#  u'competition',
#  u'floridabianca',
#  u'throatiness',
#  u'um',
#  u'consumed',
#  u'surveying',
#  u'thugs',
#  u'informant',
#  u'idleness',
#  u'scraps',
#  u'heebie',
#  u'wrongly',
#  u'sided',
#  u'trimly',
#  u'hells',
#  u'tailored',
#  u'reasoned',
#  u'valuables',
#  u'pedestrians',
#  u'yegg',
#  u'crinkle',
#  u'holed',
#  u'partial',
#  u'splashing',
#  u'dubiety',
#  u'stops',
#  u'broader',
#  u'guzzled',
#  u'bluish',
#  u'turkish',
#  u'stocked',
#  u'torture',
#  u'brogues',
#  u'mare',
#  u'practicing',
#  u'whooping',
#  u'fewer',
#  u'damning',
#  u'1666',
#  u'massachusetts',
#  u'rack',
#  u'hyde',
#  u'victor',
#  u'sweats',
#  u'oration',
#  u'flowing',
#  u'frequent',
#  u'scenery',
#  u'respectively',
#  u'that_',
#  u'invented',
#  u'casing',
#  u'casino',
#  u'residents',
#  u'untangled',
#  u'auything',
#  u'adze',
#  u'cooperative',
#  u'nibbling',
#  u'opaquely',
#  u'irrepressible',
#  u'fortyninth',
#  u'humorless',
#  u'trumped',
#  u'patrol',
#  u'rubbish',
#  u'charity',
#  u'athlete',
#  u'insists',
#  u'billboards',
#  u'clumsiest',
#  u'rods',
#  u'reynolds',
#  u'lamely',
#  u'procured',
#  u'paternally',
#  u'wristwatch',
#  u'hitched',
#  u'racks',
#  u'daring',
#  u'realized',
#  u'22nd',
#  u'element',
#  u'erasing',
#  u'reversal',
#  u'strychnine',
#  u'eileen',
#  u'produced',
#  u'passion',
#  u'motorcycle',
#  u'warren',
#  u'responsibilities',
#  u'meantime',
#  u'spoiling',
#  u'snaky',
#  u'outlined',
#  u'dock',
#  u'snake',
#  u'bedamned',
#  u'sniffing',
#  u'wrangled',
#  u'suitors',
#  u'bums',
#  u'flanking',
#  u'deficiency',
#  u'irritation',
#  u'jagged',
#  u'overpowered',
#  u'shrinking',
#  u'discs',
#  u'hilarious',
#  u'loomed',
#  u'sanatorium',
#  u'embarrass',
#  u'shortest',
#  u'backless',
#  u'injudicious',
#  u'gallons',
#  u'scars',
#  u'david',
#  u'rothstein',
#  u'1342',
#  u'occurrences',
#  u'gimcrackery',
#  u'erstwhile',
#  u'lengthily',
#  u'rumpling',
#  u'cats',
#  u'interests',
#  u'enforcement',
#  u'gummy',
#  u'testing',
#  u'chagrin',
#  u'burglarized',
#  u'beatings',
#  u'vouch',
#  u'uncurtained',
#  u'goodnight',
#  u'bind',
#  u'gabriclie',
#  u'ruckuses',
#  u'macanlay',
#  u'powders',
#  u'spelled',
#  u'defending',
#  u'livingroom',
#  u'reloaded',
#  u'mechanism',
#  u'waffles',
#  u'twentytwo',
#  u'demolished',
#  u'squawks',
#  u'lindb',
#  u'scooping',
#  u'courtesy',
#  u'device',
#  u'medal',
#  u'07',
#  u'pettier',
#  u'hypocrite',
#  u'ignited',
#  u'ascot',
#  u'hiving',
#  u'wounded',
#  ...]

# %%
books.count('dame')
# Out:
# 13

# %%
books.count('girl')
# Out:
# 361

# %% [markdown]
# #### per book

# %%
sent = pd.read_pickle('sentiment.pkl')

# %%
def chunker(seq, size):
    return (seq[pos:pos + size] for pos in xrange(0, len(seq), size))

# %%
from collections import Counter

# %%
woman = [u'she',u'her',u'girl',u'woman',u'blonde']
uniwoman = [unicode(i) for i in woman]

# %%
wordcounts=[]
wordprop = []
lengths = []
fds = []
sentscore = []
sentpages = []
womanpages = []
poscount = []
negcount = []

for i in texts:
    lengths.append(len(i))
    book = nltk.Text(i)
    wordcounts.append([book.count('gun'), book.count('girl'), book.count('cigarette')])
    wordprop.append([(book.count('gun')/float(len(i))), (book.count('girl')/float(len(i))),(book.count('cigarette')/float(len(i)))])
    fd = nltk.FreqDist(book)
    fds.append(fd)
    
    #bookwords = [i.encode('utf-8') for i in book]
    bookwords = [i for i in book]
    words = pd.DataFrame(columns=['word'])
    words.word = bookwords
    booksentiment = pd.merge(words, sent, how='left', on='word')
    booksentiment.fillna(0, inplace=True)
    sentscore.append(sum(booksentiment.sentiment))
    
    pagesent = []
    for chunk in chunker(booksentiment,150):
        pagesent.append(sum(chunk.sentiment))
    sentpages.append(pagesent)
    
    pagewoman = []
    for chunk in chunker(bookwords,150):
        womantmp = 0
        for word in chunk:
            if word in uniwoman:
                womantmp+=1
        pagewoman.append(womantmp)
    womanpages.append(pagewoman)
    
    poscount.append(Counter(booksentiment.sentiment.values)[1])
    negcount.append(Counter(booksentiment.sentiment.values)[-1])

# %%
lengths
# Out:
# [27586, 30856, 33467, 30718, 24753]

# %%
#pre stop word lengths: [31642, 37630, 32703, 33922, 36076, 55034, 22985]

# %%
poscount
# Out:
# [3546, 4300, 4426, 3927, 3536]

# %%
posprop = [i/float(j) for i,j in zip(poscount,lengths)]

# %%
#pre stop pos: [4766, 5763, 5463, 5239, 5745, 9284, 3897]
#pre stop neg: [3828, 4418, 3777, 3992, 4362, 6848, 2526]

# %%
negcount
# Out:
# [3127, 3669, 4412, 3164, 2703]

# %%
negprop = [i/float(j) for i,j in zip(negcount,lengths)]

# %%
negprop
# Out:
# [0.11335460015950119,
#  0.11890718174747213,
#  0.1318313562613918,
#  0.10300149749332639,
#  0.10919888498363835]

# %%
posprop
# Out:
# [0.12854346407598058,
#  0.13935701322271196,
#  0.13224967878805988,
#  0.1278403541897259,
#  0.14285137155092312]

# %%
gun = [i[0] for i in wordprop]
girl = [i[1] for i in wordprop]
cig = [i[2] for i in wordprop]

# %%
gun
# Out:
# [0.002428768215761618,
#  0.0010046668395125745,
#  0.0007171243314309619,
#  0.0005208672439611954,
#  0.0015351674544499658]

# %%
plt.figure(figsize=(12,5))
plt.plot(range(len(gun)),gun,color='r')
plt.plot(range(len(girl)),girl,color='b')
plt.plot(range(len(cig)),cig,color='g')

# %%
normlengths = [(i-np.mean(lengths))/(max(lengths)-min(lengths)) for i in lengths]
normsent = [(i-np.mean(sentscore))/(max(sentscore)-min(sentscore)) for i in sentscore]

# %%
normlengths
# Out:
# [-0.21689235712646315,
#  0.15836584806059215,
#  0.45799862290566906,
#  0.14252926325453294,
#  -0.54200137709433094]

# %%
normsent
# Out:
# [-0.13797313797313798,
#  0.12087912087912088,
#  -0.63247863247863245,
#  0.28205128205128205,
#  0.36752136752136755]

# %%
plt.figure(figsize=(12,5))
plt.plot(range(len(normlengths)),normlengths,color='r')
plt.plot(range(len(normsent)),normsent,color='b')

# %%
gunabs = [i[0] for i in wordcounts]
girlabs = [i[1] for i in wordcounts]
cigabs = [i[2] for i in wordcounts]

# %%
wordcounts
# Out:
# [[67, 79, 14], [31, 107, 10], [24, 94, 62], [16, 30, 27], [38, 51, 6]]

# %%
plt.figure(figsize=(12,5))
plt.plot(range(len(gunabs)),gunabs,color='r')
plt.plot(range(len(girlabs)),girlabs,color='b')
plt.plot(range(len(cigabs)),cigabs,color='g')

# %%
for i in fds:
    plt.figure(figsize=(8,4))
    i.plot(50,cumulative=False,color='purple')

# %%
for i in sentpages:
    plt.figure(figsize=(12,4))
    plt.bar(range(len(i)),i,color='turquoise')

# %% [markdown]
# #### sentiment transforms

# %%
import scipy

# %%
from scipy import fftpack

# %% [markdown]
# #### sp1

# %%
x = range(len(sentpages[0]))
cN = len(sentpages[0])
cx = np.linspace(0,2*np.pi,cN)
cy = np.asarray(sentpages[0])

cw = scipy.fftpack.rfft(cy)
cf = scipy.fftpack.rfftfreq(cN, cx[1]-cx[0])
cspectrum = cw**2

ccutoff_idx = cspectrum < (cspectrum.max()/3)
cw2 = cw.copy()
cw2[ccutoff_idx] = 0

cy2 = scipy.fftpack.irfft(cw2)

plt.figure(figsize=(12,4))
plt.plot(x, cy)
plt.plot(x, cy2)

# %% [markdown]
# #### sp1

# %%
x = range(len(sentpages[1]))
cN = len(sentpages[1])
cx = np.linspace(0,2*np.pi,cN)
cy = np.asarray(sentpages[1])

cw = scipy.fftpack.rfft(cy)
cf = scipy.fftpack.rfftfreq(cN, cx[1]-cx[0])
cspectrum = cw**2

ccutoff_idx = cspectrum < (cspectrum.max()/6)
cw2 = cw.copy()
cw2[ccutoff_idx] = 0

cy2 = scipy.fftpack.irfft(cw2)

plt.figure(figsize=(12,4))
plt.plot(x, cy)
plt.plot(x, cy2)

# %% [markdown]
# #### sp2

# %%
x = range(len(sentpages[2]))
cN = len(sentpages[2])
cx = np.linspace(0,2*np.pi,cN)
cy = np.asarray(sentpages[2])

cw = scipy.fftpack.rfft(cy)
cf = scipy.fftpack.rfftfreq(cN, cx[1]-cx[0])
cspectrum = cw**2

ccutoff_idx = cspectrum < (cspectrum.max()/1)
cw2 = cw.copy()
cw2[ccutoff_idx] = 0

cy2 = scipy.fftpack.irfft(cw2)

plt.figure(figsize=(12,4))
plt.plot(x, cy)
plt.plot(x, cy2)

# %% [markdown]
# #### sp3

# %%
x = range(len(sentpages[3]))
cN = len(sentpages[3])
cx = np.linspace(0,2*np.pi,cN)
cy = np.asarray(sentpages[3])

cw = scipy.fftpack.rfft(cy)
cf = scipy.fftpack.rfftfreq(cN, cx[1]-cx[0])
cspectrum = cw**2

ccutoff_idx = cspectrum < (cspectrum.max()/13)
cw2 = cw.copy()
cw2[ccutoff_idx] = 0

cy2 = scipy.fftpack.irfft(cw2)

plt.figure(figsize=(12,4))
plt.plot(x, cy)
plt.plot(x, cy2)

# %% [markdown]
# #### sp4

# %%
x = range(len(sentpages[4]))
cN = len(sentpages[4])
cx = np.linspace(0,2*np.pi,cN)
cy = np.asarray(sentpages[4])

cw = scipy.fftpack.rfft(cy)
cf = scipy.fftpack.rfftfreq(cN, cx[1]-cx[0])
cspectrum = cw**2

ccutoff_idx = cspectrum < (cspectrum.max()/17)
cw2 = cw.copy()
cw2[ccutoff_idx] = 0

cy2 = scipy.fftpack.irfft(cw2)

plt.figure(figsize=(12,4))
plt.plot(x, cy)
plt.plot(x, cy2)

# %% [markdown]
# #### sentiment dictionary

# %%
sentdictwords = sent.word.values

# %%
uniques = set(together)

# %%
unique = [i for i in uniques]

# %%
len(unique), len(together)
# Out:
# (11504, 147380)

# %%
rep = []
for word in unique:
    if word in sentdictwords:
        rep.append(word)

# %%
len(rep)
# Out:
# 4762

# %%
rep
# Out:
# [u'fawn',
#  u'yellow',
#  u'hanging',
#  u'looking',
#  u'scold',
#  u'lord',
#  u'shaving',
#  u'foul',
#  u'disturb',
#  u'prize',
#  u'busybody',
#  u'tired',
#  u'elegant',
#  u'haughtily',
#  u'blouse',
#  u'captain',
#  u'relieving',
#  u'spitefulness',
#  u'thunder',
#  u'cooking',
#  u'bonuses',
#  u'increasing',
#  u'admiral',
#  u'specialist',
#  u'hero',
#  u'reporter',
#  u'reported',
#  u'cult',
#  u'substance',
#  u'military',
#  u'spotty',
#  u'golden',
#  u'divide',
#  u'replace',
#  u'stern',
#  u'cocaine',
#  u'cheating',
#  u'spoke',
#  u'moth',
#  u'music',
#  u'therefore',
#  u'strike',
#  u'holy',
#  u'relax',
#  u'successful',
#  u'hurt',
#  u'pointedly',
#  u'glass',
#  u'hole',
#  u'hold',
#  u'household',
#  u'organized',
#  u'arresting',
#  u'caution',
#  u'want',
#  u'absolute',
#  u'hog',
#  u'hoe',
#  u'complaining',
#  u'travel',
#  u'damage',
#  u'machine',
#  u'hot',
#  u'hop',
#  u'gouge',
#  u'preferable',
#  u'dignified',
#  u'beauty',
#  u'despondent',
#  u'wrong',
#  u'extortion',
#  u'effective',
#  u'wins',
#  u'headquarters',
#  u'childhood',
#  u'wind',
#  u'wine',
#  u'sarcastically',
#  u'welcomed',
#  u'soothingly',
#  u'sentry',
#  u'wrought',
#  u'wickedly',
#  u'fit',
#  u'screaming',
#  u'fix',
#  u'hidden',
#  u'easier',
#  u'ached',
#  u'indecent',
#  u'silver',
#  u'scholar',
#  u'clumsy',
#  u'wooden',
#  u'spotless',
#  u'addicted',
#  u'development',
#  u'financial',
#  u'contracting',
#  u'substantially',
#  u'ring',
#  u'whip',
#  u'smirk',
#  u'mason',
#  u'encourage',
#  u'adapt',
#  u'disinterested',
#  u'assured',
#  u'fugitive',
#  u'enormous',
#  u'ate',
#  u'disturbed',
#  u'loudness',
#  u'playfully',
#  u'wash',
#  u'service',
#  u'engagement',
#  u'master',
#  u'bitter',
#  u'listen',
#  u'collapse',
#  u'motionless',
#  u'crawl',
#  u'positively',
#  u'peril',
#  u'coward',
#  u'tree',
#  u'rusty',
#  u'pneumonia',
#  u'idle',
#  u'sheen',
#  u'feeling',
#  u'shyly',
#  u'pigs',
#  u'width',
#  u'dozen',
#  u'wholesome',
#  u'concrete',
#  u'responsible',
#  u'eagerly',
#  u'toothed',
#  u'defiantly',
#  u'hum',
#  u'object',
#  u'mouth',
#  u'addict',
#  u'letter',
#  u'conceded',
#  u'singer',
#  u'grove',
#  u'camp',
#  u'scream',
#  u'bomb',
#  u'gauge',
#  u'caper',
#  u'touches',
#  u'busy',
#  u'shuffling',
#  u'bust',
#  u'bush',
#  u'touched',
#  u'rich',
#  u'heartily',
#  u'emphatically',
#  u'cushion',
#  u'altogether',
#  u'spilling',
#  u'nicely',
#  u'accordance',
#  u'patch',
#  u'release',
#  u'respond',
#  u'fair',
#  u'unexpectedly',
#  u'result',
#  u'resigned',
#  u'hammer',
#  u'best',
#  u'stealthy',
#  u'score',
#  u'alignment',
#  u'scorn',
#  u'pirate',
#  u'nature',
#  u'smelled',
#  u'dexterously',
#  u'debt',
#  u'roller',
#  u'pity',
#  u'accident',
#  u'dents',
#  u'argue',
#  u'obscenity',
#  u'topmost',
#  u'truthful',
#  u'union',
#  u'much',
#  u'fry',
#  u'conversational',
#  u'life',
#  u'spit',
#  u'child',
#  u'worked',
#  u'chill',
#  u'gritty',
#  u'employ',
#  u'elaborate',
#  u'trusted',
#  u'severity',
#  u'cumbersome',
#  u'dryness',
#  u'haphazard',
#  u'split',
#  u'emphatic',
#  u'fairly',
#  u'hosiery',
#  u'tops',
#  u'ownership',
#  u'haggard',
#  u'chafing',
#  u'stillness',
#  u'coldness',
#  u'subpoena',
#  u'bellow',
#  u'sleepy',
#  u'disguise',
#  u'succeeding',
#  u'ease',
#  u'thickening',
#  u'easy',
#  u'prison',
#  u'casually',
#  u'knock',
#  u'possible',
#  u'possibly',
#  u'birth',
#  u'shadow',
#  u'unique',
#  u'bushy',
#  u'desire',
#  u'pavement',
#  u'attorney',
#  u'right',
#  u'crowd',
#  u'creed',
#  u'insistence',
#  u'creep',
#  u'enemies',
#  u'consensus',
#  u'bottom',
#  u'inhuman',
#  u'fox',
#  u'gorge',
#  u'losing',
#  u'despair',
#  u'lacked',
#  u'slightly',
#  u'sob',
#  u'statements',
#  u'honeymoon',
#  u'administer',
#  u'respectable',
#  u'support',
#  u'humorous',
#  u'goddamn',
#  u'happy',
#  u'offer',
#  u'forming',
#  u'shrilly',
#  u'amusing',
#  u'safeguard',
#  u'congratulations',
#  u'utmost',
#  u'myopia',
#  u'unanimous',
#  u'smashed',
#  u'mighty',
#  u'passenger',
#  u'disgrace',
#  u'proven',
#  u'proves',
#  u'protested',
#  u'floor',
#  u'actor',
#  u'flood',
#  u'role',
#  u'smell',
#  u'roll',
#  u'intend',
#  u'slaves',
#  u'intent',
#  u'smelling',
#  u'warn',
#  u'time',
#  u'push',
#  u'stricken',
#  u'archaeologist',
#  u'detective',
#  u'writhe',
#  u'chain',
#  u'resources',
#  u'jarring',
#  u'understandable',
#  u'chair',
#  u'vet',
#  u'uneven',
#  u'rousing',
#  u'jerk',
#  u'choice',
#  u'gloomy',
#  u'exact',
#  u'tear',
#  u'leave',
#  u'pursue',
#  u'settle',
#  u'prevent',
#  u'spiritual',
#  u'attic',
#  u'somber',
#  u'sign',
#  u'chopping',
#  u'anaconda',
#  u'depressions',
#  u'celebrated',
#  u'current',
#  u'falling',
#  u'crashing',
#  u'boost',
#  u'jury',
#  u'funeral',
#  u'understanding',
#  u'address',
#  u'dwindling',
#  u'brilliant',
#  u'concealed',
#  u'love',
#  u'prefer',
#  u'logical',
#  u'bloody',
#  u'marvelous',
#  u'fake',
#  u'crammed',
#  u'fresher',
#  u'working',
#  u'angry',
#  u'opposed',
#  u'theoretical',
#  u'loving',
#  u'scratched',
#  u'afford',
#  u'apparent',
#  u'refrain',
#  u'appendix',
#  u'intoxicated',
#  u'scratches',
#  u'discontented',
#  u'easiest',
#  u'behalf',
#  u'tobacco',
#  u'unnatural',
#  u'pretend',
#  u'printing',
#  u'values',
#  u'slowness',
#  u'believed',
#  u'allowed',
#  u'offense',
#  u'stole',
#  u'evidently',
#  u'winter',
#  u'divided',
#  u'elephant',
#  u'laundry',
#  u'spot',
#  u'wrinkled',
#  u'filthy',
#  u'disagreeable',
#  u'natural',
#  u'darkened',
#  u'truck',
#  u'swollen',
#  u'drunken',
#  u'tendency',
#  u'thoughtfulness',
#  u'yawning',
#  u'thumb',
#  u'torn',
#  u'troubles',
#  u'suspicion',
#  u'thump',
#  u'troubled',
#  u'apron',
#  u'bashful',
#  u'nation',
#  u'twilight',
#  u'revert',
#  u'breach',
#  u'quarter',
#  u'receipt',
#  u'owing',
#  u'joker',
#  u'astray',
#  u'seriously',
#  u'investigation',
#  u'possibility',
#  u'quite',
#  u'complicated',
#  u'besides',
#  u'bumpy',
#  u'scarred',
#  u'remainder',
#  u'gaff',
#  u'modest',
#  u'aboard',
#  u'neglect',
#  u'emotion',
#  u'intuition',
#  u'saving',
#  u'vote',
#  u'open',
#  u'convent',
#  u'bite',
#  u'lesbian',
#  u'stuffed',
#  u'proving',
#  u'ridiculous',
#  u'fooled',
#  u'inventor',
#  u'impractical',
#  u'overtaken',
#  u'depressed',
#  u'glossy',
#  u'damned',
#  u'prospect',
#  u'illness',
#  u'nicer',
#  u'sag',
#  u'argument',
#  u'sad',
#  u'buried',
#  u'flatness',
#  u'sap',
#  u'saw',
#  u'baggage',
#  u'note',
#  u'take',
#  u'wanting',
#  u'fashionably',
#  u'ironically',
#  u'knowingly',
#  u'lawn',
#  u'enamel',
#  u'touchy',
#  u'average',
#  u'drive',
#  u'ways',
#  u'quiescent',
#  u'salt',
#  u'friction',
#  u'bright',
#  u'scarce',
#  u'aggressive',
#  u'slow',
#  u'cloak',
#  u'uppermost',
#  u'robe',
#  u'dissimilar',
#  u'assistant',
#  u'cursing',
#  u'infallible',
#  u'prime',
#  u'saliva',
#  u'borrow',
#  u'worried',
#  u'priest',
#  u'liable',
#  u'worries',
#  u'vision',
#  u'arrival',
#  u'gangster',
#  u'anyways',
#  u'teens',
#  u'checkered',
#  u'screen',
#  u'dome',
#  u'jovial',
#  u'spare',
#  u'menacing',
#  u'parapet',
#  u'millionaire',
#  u'expression',
#  u'riddle',
#  u'extravagantly',
#  u'gaiety',
#  u'unconsciousness',
#  u'stretch',
#  u'reflective',
#  u'enable',
#  u'formed',
#  u'majestic',
#  u'libel',
#  u'profane',
#  u'prominence',
#  u'straighten',
#  u'intimately',
#  u'newspaper',
#  u'brow',
#  u'engaged',
#  u'dubious',
#  u'regularity',
#  u'fame',
#  u'preparatory',
#  u'lump',
#  u'breakdown',
#  u'sickness',
#  u'domineering',
#  u'cheery',
#  u'idiotically',
#  u'peculiarities',
#  u'rest',
#  u'slimy',
#  u'scrape',
#  u'grounded',
#  u'pow',
#  u'prominently',
#  u'starving',
#  u'dart',
#  u'dark',
#  u'snarl',
#  u'world',
#  u'snare',
#  u'vague',
#  u'dare',
#  u'boast',
#  u'clam',
#  u'stranger',
#  u'clay',
#  u'claw',
#  u'stationary',
#  u'satisfactory',
#  u'grub',
#  u'divine',
#  u'faster',
#  u'memories',
#  u'noon',
#  u'unsuccessfully',
#  u'scientific',
#  u'power',
#  u'intimate',
#  u'ration',
#  u'sprung',
#  u'stone',
#  u'ace',
#  u'favorite',
#  u'slender',
#  u'act',
#  u'stony',
#  u'chivalry',
#  u'burning',
#  u'sneering',
#  u'burglar',
#  u'gleam',
#  u'complete',
#  u'wits',
#  u'land',
#  u'handsome',
#  u'pull',
#  u'rush',
#  u'rage',
#  u'dirty',
#  u'rust',
#  u'darker',
#  u'gone',
#  u'gong',
#  u'fright',
#  u'exhausted',
#  u'stealing',
#  u'wildly',
#  u'ay',
#  u'ax',
#  u'tranquil',
#  u'tremble',
#  u'cream',
#  u'sympathetically',
#  u'backgammon',
#  u'congress',
#  u'dented',
#  u'menace',
#  u'mocking',
#  u'mask',
#  u'mass',
#  u'original',
#  u'consider',
#  u'weariness',
#  u'foggy',
#  u'taxicab',
#  u'careful',
#  u'hunting',
#  u'laughing',
#  u'tail',
#  u'smile',
#  u'appointment',
#  u'puzzled',
#  u'candid',
#  u'condition',
#  u'cable',
#  u'large',
#  u'sang',
#  u'sane',
#  u'dusky',
#  u'harry',
#  u'small',
#  u'quicker',
#  u'premature',
#  u'pass',
#  u'rye',
#  u'handicapped',
#  u'clock',
#  u'nurse',
#  u'revealing',
#  u'full',
#  u'hash',
#  u'indecision',
#  u'smartest',
#  u'introductory',
#  u'experience',
#  u'acquittal',
#  u'action',
#  u'obstructing',
#  u'pearl',
#  u'door',
#  u'alcove',
#  u'company',
#  u'possession',
#  u'cunning',
#  u'chisel',
#  u'carefully',
#  u'learn',
#  u'beautiful',
#  u'prompt',
#  u'gallop',
#  u'neglected',
#  u'accept',
#  u'sense',
#  u'station',
#  u'dress',
#  u'information',
#  u'dazzle',
#  u'glowing',
#  u'tinge',
#  u'occur',
#  u'creature',
#  u'plant',
#  u'lanky',
#  u'intended',
#  u'sympathize',
#  u'plane',
#  u'waves',
#  u'ethics',
#  u'authentic',
#  u'refuse',
#  u'rowdy',
#  u'wrench',
#  u'bowl',
#  u'attitude',
#  u'paper',
#  u'smiling',
#  u'blurring',
#  u'symptoms',
#  u'plotters',
#  u'ruining',
#  u'lies',
#  u'ally',
#  u'wry',
#  u'severely',
#  u'propose',
#  u'dispiritedly',
#  u'weeds',
#  u'weedy',
#  u'sucked',
#  u'likeness',
#  u'lettuce',
#  u'coping',
#  u'found',
#  u'disorganized',
#  u'lantern',
#  u'resolute',
#  u'police',
#  u'operation',
#  u'immensely',
#  u'really',
#  u'anxious',
#  u'darling',
#  u'impudence',
#  u'nervously',
#  u'belief',
#  u'porcelain',
#  u'imagine',
#  u'reproach',
#  u'bumped',
#  u'devoid',
#  u'insolence',
#  u'testament',
#  u'castle',
#  u'clump',
#  u'major',
#  u'dumbfounded',
#  u'slipper',
#  u'glitter',
#  u'guess',
#  u'peaceable',
#  u'nobly',
#  u'flimsy',
#  u'saint',
#  u'justly',
#  u'relationship',
#  u'immediate',
#  u'appreciation',
#  u'interviewer',
#  u'grace',
#  u'condolences',
#  u'determined',
#  u'marriage',
#  u'suffocating',
#  u'caress',
#  u'blond',
#  u'sell',
#  u'pajamas',
#  u'commotion',
#  u'silvery',
#  u'frail',
#  u'play',
#  u'plan',
#  u'unequal',
#  u'arson',
#  u'gaby',
#  u'cover',
#  u'barred',
#  u'barren',
#  u'barrel',
#  u'dragged',
#  u'despise',
#  u'ugh',
#  u'golf',
#  u'gold',
#  u'defended',
#  u'overwhelmed',
#  u'consistently',
#  u'writer',
#  u'peculiar',
#  u'failed',
#  u'unjustly',
#  u'indifference',
#  u'sunny',
#  u'resent',
#  u'remedy',
#  u'frightening',
#  u'enemy',
#  u'sleeve',
#  u'terrifically',
#  u'exercise',
#  u'obscure',
#  u'insane',
#  u'set',
#  u'sex',
#  u'see',
#  u'sea',
#  u'outward',
#  u'spirits',
#  u'pleadingly',
#  u'movie',
#  u'candor',
#  u'premises',
#  u'untouched',
#  u'renewed',
#  u'legislature',
#  u'prospects',
#  u'barely',
#  u'connection',
#  u'poverty',
#  u'load',
#  u'loaf',
#  u'bell',
#  u'community',
#  u'hollow',
#  u'church',
#  u'belt',
#  u'worthless',
#  u'devil',
#  u'firm',
#  u'sweetheart',
#  u'fire',
#  u'engage',
#  u'hardness',
#  u'uncertain',
#  u'straight',
#  u'leaning',
#  u'pound',
#  u'agitation',
#  u'backing',
#  u'chasm',
#  u'chase',
#  u'funny',
#  u'elevated',
#  u'reachable',
#  u'cigar',
#  u'deformity',
#  u'alert',
#  u'horde',
#  u'necessity',
#  u'uncouth',
#  u'telegram',
#  u'rumbling',
#  u'stunt',
#  u'admission',
#  u'chest',
#  u'signals',
#  u'eager',
#  u'crying',
#  u'surprised',
#  u'niece',
#  u'shove',
#  u'emergency',
#  u'couple',
#  u'suffering',
#  u'quest',
#  u'blackjack',
#  u'flannel',
#  u'chorus',
#  u'continue',
#  u'senate',
#  u'spring',
#  u'bounce',
#  u'palm',
#  u'sight',
#  u'curious',
#  u'pale',
#  u'twinkle',
#  u'novelty',
#  u'behave',
#  u'seclusion',
#  u'inclination',
#  u'crooks',
#  u'odor',
#  u'agreement',
#  u'tidal',
#  u'obscured',
#  u'deserved',
#  u'exaggerated',
#  u'hatchet',
#  u'wrinkles',
#  u'ambush',
#  u'illegal',
#  u'recommended',
#  u'garbage',
#  u'appropriate',
#  u'primarily',
#  u'sock',
#  u'assuring',
#  u'submit',
#  u'custom',
#  u'occupy',
#  u'suit',
#  u'relaxed',
#  u'link',
#  u'competition',
#  u'considerable',
#  u'faded',
#  u'genial',
#  u'likewise',
#  u'influence',
#  u'surveying',
#  u'graceful',
#  u'concealment',
#  u'puzzling',
#  u'invalid',
#  u'occasional',
#  u'definitely',
#  u'wrongly',
#  u'hells',
#  u'reasoned',
#  u'age',
#  u'annoyed',
#  u'incomplete',
#  u'walker',
#  u'fresh',
#  u'sharply',
#  u'scratch',
#  u'cobalt',
#  u'softer',
#  u'bluish',
#  u'concerned',
#  u'young',
#  u'send',
#  u'dislike',
#  u'sent',
#  u'torture',
#  u'mare',
#  u'wipe',
#  u'marry',
#  u'damning',
#  u'try',
#  u'race',
#  u'rack',
#  u'crook',
#  u'odd',
#  u'victor',
#  u'oration',
#  u'frequent',
#  u'scenery',
#  u'led',
#  u'lee',
#  u'punch',
#  u'great',
#  u'receive',
#  u'casino',
#  u'opinion',
#  u'innocence',
#  u'cooperative',
#  u'standing',
#  u'confidence',
#  u'doubt',
#  u'irrepressible',
#  u'pencil',
#  u'patrol',
#  u'dealings',
#  u'rubbish',
#  u'baby',
#  u'gladly',
#  u'defiance',
#  u'charity',
#  u'customer',
#  u'retreated',
#  u'athlete',
#  u'pour',
#  u'thin',
#  u'wedge',
#  u'bent',
#  u'process',
#  u'lock',
#  u'slim',
#  u'high',
#  u'beckoned',
#  u'bend',
#  u'slip',
#  u'weaken',
#  u'struggling',
#  u'delay',
#  u'animal',
#  u'comedy',
#  u'greatly',
#  u'scornful',
#  u'testimony',
#  u'wristwatch',
#  u'preferring',
#  u'fits',
#  u'hawk',
#  u'daring',
#  u'noises',
#  u'knotted',
#  u'allow',
#  u'classy',
#  u'reversal',
#  u'heater',
#  u'move',
#  u'doubtful',
#  u'passion',
#  u'motorcycle',
#  u'warren',
#  u'perfect',
#  u'insistent',
#  u'dock',
#  u'snake',
#  u'kiss',
#  u'cage',
#  u'transparent',
#  u'intelligent',
#  u'sufficiently',
#  u'delightful',
#  u'truth',
#  u'watery',
#  u'bump',
#  u'flanking',
#  u'deficiency',
#  u'irritation',
#  u'jagged',
#  u'fundamentally',
#  u'soundly',
#  u'hilarious',
#  u'shut',
#  u'title',
#  u'greedy',
#  u'surely',
#  u'thrust',
#  u'embarrass',
#  u'scary',
#  u'glistening',
#  u'injudicious',
#  u'spill',
#  u'could',
#  ...]

# %%
sentwords = zip(sent.word, sent.sentiment)

# %%
poswords = []
negwords = []
for i in sentwords:
    if i[1] == 1:
        poswords.append(i[0])
    elif i[1] == -1:
        negwords.append(i[0])

# %%
sentwords
# Out:
# [(u'2-faced', -1),
#  (u'2-faces', -1),
#  (u'a+', 1),
#  (u'aback', 0),
#  (u'abacus', 0),
#  (u'abandon', -1),
#  (u'abandoned', -1),
#  (u'abandonment', -1),
#  (u'abase', -1),
#  (u'abasement', -1),
#  (u'abash', -1),
#  (u'abate', -1),
#  (u'abba', 1),
#  (u'abbot', 0),
#  (u'abdicate', -1),
#  (u'abduction', -1),
#  (u'aberrant', -1),
#  (u'aberration', -1),
#  (u'abeyance', 0),
#  (u'abhor', -1),
#  (u'abhorred', -1),
#  (u'abhorrence', -1),
#  (u'abhorrent', -1),
#  (u'abhorrently', -1),
#  (u'abhors', -1),
#  (u'abidance', 1),
#  (u'abide', 1),
#  (u'abilities', 1),
#  (u'ability', 1),
#  (u'abject', -1),
#  (u'abjectly', -1),
#  (u'abjure', -1),
#  (u'ablaze', 0),
#  (u'able', 1),
#  (u'abnormal', -1),
#  (u'aboard', 0),
#  (u'abode', 0),
#  (u'abolish', -1),
#  (u'abolition', -1),
#  (u'abominable', -1),
#  (u'abominably', -1),
#  (u'abominate', -1),
#  (u'abomination', -1),
#  (u'aboriginal', 0),
#  (u'abort', -1),
#  (u'aborted', -1),
#  (u'abortion', -1),
#  (u'abortive', -1),
#  (u'aborts', -1),
#  (u'abound', 1),
#  (u'abounds', 1),
#  (u'above', 1),
#  (u'above-average', 1),
#  (u'abovementioned', 1),
#  (u'abrade', -1),
#  (u'abrasion', -1),
#  (u'abrasive', -1),
#  (u'abroad', 0),
#  (u'abrogate', -1),
#  (u'abrupt', -1),
#  (u'abruptly', -1),
#  (u'abscess', -1),
#  (u'abscond', -1),
#  (u'absence', -1),
#  (u'absent', -1),
#  (u'absent-minded', -1),
#  (u'absentee', -1),
#  (u'absenteeism', -1),
#  (u'absinthe', 0),
#  (u'absolute', 1),
#  (u'absolutely', 0),
#  (u'absolution', 1),
#  (u'absolve', 1),
#  (u'absorbed', 1),
#  (u'absorbent', 1),
#  (u'absorption', 1),
#  (u'absurd', -1),
#  (u'absurdity', -1),
#  (u'absurdly', -1),
#  (u'absurdness', -1),
#  (u'abundance', -1),
#  (u'abundant', 1),
#  (u'abuse', -1),
#  (u'abused', -1),
#  (u'abuses', -1),
#  (u'abusive', -1),
#  (u'abysmal', -1),
#  (u'abysmally', -1),
#  (u'abyss', -1),
#  (u'academic', 1),
#  (u'academy', 1),
#  (u'accede', 1),
#  (u'accelerate', 0),
#  (u'acceleration', 0),
#  (u'accentuate', 1),
#  (u'accept', 1),
#  (u'acceptable', 1),
#  (u'acceptance', 1),
#  (u'access', 0),
#  (u'accessable', 1),
#  (u'accessible', 1),
#  (u'accession', 1),
#  (u'accident', -1),
#  (u'accidental', -1),
#  (u'accidentally', 0),
#  (u'acclaim', 1),
#  (u'acclaimed', 1),
#  (u'acclamation', 1),
#  (u'accolade', 1),
#  (u'accolades', 1),
#  (u'accommodate', 1),
#  (u'accommodation', 1),
#  (u'accommodative', 1),
#  (u'accomodative', 1),
#  (u'accompaniment', 1),
#  (u'accompany', 0),
#  (u'accomplish', 1),
#  (u'accomplished', 1),
#  (u'accomplishment', 1),
#  (u'accomplishments', 1),
#  (u'accord', 1),
#  (u'accordance', 1),
#  (u'accordantly', 1),
#  (u'accordion', 0),
#  (u'accost', -1),
#  (u'account', 0),
#  (u'accountability', 1),
#  (u'accountable', 1),
#  (u'accountant', 0),
#  (u'accounts', 0),
#  (u'accredited', 1),
#  (u'accrue', 1),
#  (u'accueil', 1),
#  (u'accumulate', 0),
#  (u'accumulation', 0),
#  (u'accuracy', 1),
#  (u'accurate', 1),
#  (u'accurately', 1),
#  (u'accurateness', 1),
#  (u'accursed', -1),
#  (u'accusation', -1),
#  (u'accusations', -1),
#  (u'accusative', -1),
#  (u'accuse', -1),
#  (u'accused', -1),
#  (u'accuser', -1),
#  (u'accuses', -1),
#  (u'accusing', -1),
#  (u'accusingly', -1),
#  (u'accustom', 0),
#  (u'ace', 1),
#  (u'acerbate', -1),
#  (u'acerbic', -1),
#  (u'acerbically', -1),
#  (u'ache', -1),
#  (u'ached', -1),
#  (u'aches', -1),
#  (u'achey', -1),
#  (u'achievable', 1),
#  (u'achieve', 1),
#  (u'achievement', 1),
#  (u'achievements', 1),
#  (u'achievible', 1),
#  (u'aching', -1),
#  (u'acid', -1),
#  (u'acknowledge', 1),
#  (u'acknowledgement', 1),
#  (u'acknowledgment', 1),
#  (u'acme', 0),
#  (u'acquaint', 1),
#  (u'acquaintance', 1),
#  (u'acquainted', 0),
#  (u'acquire', 1),
#  (u'acquiring', 1),
#  (u'acquisition', 0),
#  (u'acquisitions', 0),
#  (u'acquit', 1),
#  (u'acquittal', 1),
#  (u'acreage', 0),
#  (u'acres', 0),
#  (u'acrid', -1),
#  (u'acridly', -1),
#  (u'acridness', -1),
#  (u'acrimonious', -1),
#  (u'acrimoniously', -1),
#  (u'acrimony', -1),
#  (u'acrobat', 1),
#  (u'act', 0),
#  (u'acting', 0),
#  (u'action', 1),
#  (u'actionable', -1),
#  (u'active', 1),
#  (u'activist', 0),
#  (u'activity', 0),
#  (u'actor', 0),
#  (u'actual', 1),
#  (u'actuality', 1),
#  (u'actually', 0),
#  (u'acuity', 1),
#  (u'acumen', 1),
#  (u'adamant', -1),
#  (u'adamantly', -1),
#  (u'adapt', 1),
#  (u'adaptability', 1),
#  (u'adaptable', 1),
#  (u'adaptation', 1),
#  (u'adaptive', 1),
#  (u'added', 0),
#  (u'adder', -1),
#  (u'addict', -1),
#  (u'addicted', -1),
#  (u'addicting', -1),
#  (u'addiction', -1),
#  (u'addicts', -1),
#  (u'address', 0),
#  (u'addresses', 1),
#  (u'adept', 1),
#  (u'adeptly', 1),
#  (u'adeptness', 1),
#  (u'adequacy', 1),
#  (u'adequate', 1),
#  (u'adhere', 0),
#  (u'adherence', 1),
#  (u'adherent', 1),
#  (u'adhering', 0),
#  (u'adhesion', 1),
#  (u'adhesive', 1),
#  (u'adieu', 0),
#  (u'adipose', -1),
#  (u'adjournment', 0),
#  (u'adjudicate', -1),
#  (u'adjunct', 1),
#  (u'adjust', 1),
#  (u'adjustable', 1),
#  (u'adjustment', 1),
#  (u'administer', 0),
#  (u'administration', 0),
#  (u'administrative', 0),
#  (u'admirable', 1),
#  (u'admirably', 1),
#  (u'admiral', 1),
#  (u'admiration', 1),
#  (u'admire', 1),
#  (u'admirer', 1),
#  (u'admiring', 1),
#  (u'admiringly', 1),
#  (u'admissible', 1),
#  (u'admission', 1),
#  (u'admit', 1),
#  (u'admittance', 1),
#  (u'admittedly', 1),
#  (u'admitting', 0),
#  (u'admonish', -1),
#  (u'admonisher', -1),
#  (u'admonishingly', -1),
#  (u'admonishment', -1),
#  (u'admonition', -1),
#  (u'adolescents', 0),
#  (u'adopt', 0),
#  (u'adorable', 1),
#  (u'adoration', 1),
#  (u'adore', 1),
#  (u'adored', 1),
#  (u'adorer', 1),
#  (u'adoring', 1),
#  (u'adoringly', 1),
#  (u'adorn', 1),
#  (u'adornment', 1),
#  (u'adrift', -1),
#  (u'adroit', 1),
#  (u'adroitly', 1),
#  (u'adulate', 1),
#  (u'adulation', 1),
#  (u'adulatory', 1),
#  (u'adult', 1),
#  (u'adulterate', -1),
#  (u'adulterated', -1),
#  (u'adulteration', -1),
#  (u'adulterier', -1),
#  (u'adultery', -1),
#  (u'advance', 1),
#  (u'advanced', 1),
#  (u'advancement', 1),
#  (u'advantage', 1),
#  (u'advantageous', 1),
#  (u'advantageously', 1),
#  (u'advantages', 1),
#  (u'advent', 1),
#  (u'adventure', 1),
#  (u'adventuresome', 1),
#  (u'adventurism', 1),
#  (u'adventurous', 1),
#  (u'adversarial', -1),
#  (u'adversary', -1),
#  (u'adverse', -1),
#  (u'adversity', -1),
#  (u'advice', 1),
#  (u'advisable', 1),
#  (u'advise', 1),
#  (u'advised', 0),
#  (u'advisement', 0),
#  (u'adviser', 1),
#  (u'advocacy', 1),
#  (u'advocate', 1),
#  (u'advocated', 1),
#  (u'advocates', 1),
#  (u'aerial', 0),
#  (u'aeronautics', 0),
#  (u'aesthetic', 1),
#  (u'aesthetics', 1),
#  (u'affability', 1),
#  (u'affable', 1),
#  (u'affably', 1),
#  (u'affair', 0),
#  (u'affect', 0),
#  (u'affectation', 1),
#  (u'affected', 0),
#  (u'affection', 1),
#  (u'affectionate', 1),
#  (u'affiche', 0),
#  (u'affiliate', 1),
#  (u'affiliated', 1),
#  (u'affiliation', 1),
#  (u'affinity', 1),
#  (u'affirm', 1),
#  (u'affirmation', 1),
#  (u'affirmative', 1),
#  (u'affirmatively', 1),
#  (u'affix', 1),
#  (u'afflict', -1),
#  (u'afflicted', -1),
#  (u'affliction', -1),
#  (u'afflictive', -1),
#  (u'affluence', 1),
#  (u'affluent', 1),
#  (u'afford', 1),
#  (u'affordable', 1),
#  (u'affordably', 1),
#  (u'affront', -1),
#  (u'afloat', 1),
#  (u'afordable', 1),
#  (u'afraid', -1),
#  (u'afresh', 0),
#  (u'aftermath', -1),
#  (u'aftertaste', -1),
#  (u'afterthought', 0),
#  (u'aga', 1),
#  (u'against', -1),
#  (u'age', 0),
#  (u'aggravate', -1),
#  (u'aggravated', -1),
#  (u'aggravating', -1),
#  (u'aggravation', -1),
#  (u'aggregate', 1),
#  (u'aggregation', 1),
#  (u'aggression', -1),
#  (u'aggressive', -1),
#  (u'aggressiveness', -1),
#  (u'aggressor', -1),
#  (u'aggrieve', -1),
#  (u'aggrieved', -1),
#  (u'aggrivation', -1),
#  (u'aghast', -1),
#  (u'agile', 1),
#  (u'agilely', 1),
#  (u'agility', 1),
#  (u'agitate', -1),
#  (u'agitated', -1),
#  (u'agitation', -1),
#  (u'agitator', -1),
#  (u'agonies', -1),
#  (u'agonize', -1),
#  (u'agonizing', -1),
#  (u'agonizingly', -1),
#  (u'agony', -1),
#  (u'agree', 1),
#  (u'agreeability', 1),
#  (u'agreeable', 1),
#  (u'agreeableness', 1),
#  (u'agreeably', 1),
#  (u'agreed', 1),
#  (u'agreeing', 1),
#  (u'agreement', 1),
#  (u'agricultural', 0),
#  (u'agriculture', 1),
#  (u'aground', -1),
#  (u'agua', 0),
#  (u'aha', 0),
#  (u'ahead', 1),
#  (u'aid', 1),
#  (u'aiding', 1),
#  (u'ail', -1),
#  (u'ailing', -1),
#  (u'ailment', -1),
#  (u'aim', 0),
#  (u'aimless', -1),
#  (u'air', 0),
#  (u'airman', 0),
#  (u'airport', 0),
#  (u'airs', -1),
#  (u'airship', 0),
#  (u'aisle', 0),
#  (u'akin', 0),
#  (u'alabaster', 1),
#  (u'alarm', -1),
#  (u'alarmed', -1),
#  (u'alarming', -1),
#  (u'alarmingly', -1),
#  (u'alas', -1),
#  (u'alb', 0),
#  (u'alcohol', 0),
#  (u'alcoholism', -1),
#  (u'alcove', 0),
#  (u'alert', 0),
#  (u'alertness', 1),
#  (u'alerts', 0),
#  (u'alfalfa', 0),
#  (u'algebraic', 0),
#  (u'alibi', 0),
#  (u'alien', -1),
#  (u'alienate', -1),
#  (u'alienated', -1),
#  (u'alienation', -1),
#  (u'alight', 1),
#  (u'alignment', 0),
#  (u'alimentation', 1),
#  (u'alimony', -1),
#  (u'alive', 1),
#  (u'all-around', 1),
#  (u'all-time', 0),
#  (u'allay', 1),
#  (u'allegation', -1),
#  (u'allegations', -1),
#  (u'allege', -1),
#  (u'allegiance', 1),
#  (u'allegorize', 0),
#  (u'allegro', 1),
#  (u'allergic', -1),
#  (u'allergies', -1),
#  (u'allergy', -1),
#  (u'alleviate', 1),
#  (u'alleviation', 1),
#  (u'alliance', 1),
#  (u'alliances', 0),
#  (u'allied', 1),
#  (u'allies', 1),
#  (u'alligator', 0),
#  (u'allow', 1),
#  (u'allowable', 1),
#  (u'allowance', 1),
#  (u'allowed', 0),
#  (u'alloy', 0),
#  (u'allure', 1),
#  (u'alluring', 1),
#  (u'alluringly', 1),
#  (u'allusion', 0),
#  (u'allusions', 0),
#  (u'alluvial', 0),
#  (u'ally', 1),
#  (u'almighty', 1),
#  (u'aloha', 1),
#  (u'aloof', -1),
#  (u'aloud', 0),
#  (u'alter', 0),
#  (u'altercation', -1),
#  (u'alternate', 0),
#  (u'although', -1),
#  (u'altogether', 0),
#  (u'altruist', 1),
#  (u'altruistic', 1),
#  (u'altruistically', 1),
#  (u'amalgam', 0),
#  (u'amaze', 1),
#  (u'amazed', 1),
#  (u'amazement', 1),
#  (u'amazes', 1),
#  (u'amazing', 1),
#  (u'amazingly', 1),
#  (u'ambassador', 1),
#  (u'ambient', 0),
#  (u'ambiguity', -1),
#  (u'ambiguous', -1),
#  (u'ambition', 1),
#  (u'ambitious', 1),
#  (u'ambitiously', 1),
#  (u'ambivalence', -1),
#  (u'ambivalent', -1),
#  (u'ambulance', 0),
#  (u'ambush', -1),
#  (u'ameliorate', 1),
#  (u'amen', 1),
#  (u'amenable', 1),
#  (u'amend', 1),
#  (u'amends', 1),
#  (u'amenity', 1),
#  (u'amethyst', 0),
#  (u'amiability', 1),
#  (u'amiabily', 1),
#  (u'amiable', 1),
#  (u'amicability', 1),
#  (u'amicable', 1),
#  (u'amicably', 1),
#  (u'amiss', -1),
#  (u'amity', 1),
#  (u'ammonia', 0),
#  (u'ammunition', 0),
#  (u'amnesia', -1),
#  (u'amnesty', 1),
#  (u'amortization', 0),
#  (u'amount', 0),
#  (u'amour', 1),
#  (u'amphetamines', -1),
#  (u'amphibian', 0),
#  (u'ample', 1),
#  (u'amplify', 1),
#  (u'amply', 1),
#  (u'amputate', -1),
#  (u'amuse', 1),
#  (u'amused', 1),
#  (u'amusement', 1),
#  (u'amusing', 1),
#  (u'amusingly', 1),
#  (u'anaconda', -1),
#  (u'anaesthetic', 0),
#  (u'anal', -1),
#  (u'analgesic', 0),
#  (u'analysis', 0),
#  (u'analyst', 1),
#  (u'analytic', 0),
#  (u'analytical', 0),
#  (u'analyze', 0),
#  (u'anarchism', -1),
#  (u'anarchist', -1),
#  (u'anarchistic', -1),
#  (u'anarchy', -1),
#  (u'anathema', -1),
#  (u'ancestral', 0),
#  (u'anchor', 1),
#  (u'anchorage', 1),
#  (u'ancient', -1),
#  (u'anemic', -1),
#  (u'anemone', 0),
#  (u'anew', 0),
#  (u'angel', 1),
#  (u'angelic', 1),
#  (u'anger', -1),
#  (u'angina', -1),
#  (u'angling', -1),
#  (u'angrily', -1),
#  (u'angriness', -1),
#  (u'angry', -1),
#  (u'anguish', -1),
#  (u'animal', 0),
#  (u'animate', 1),
#  (u'animated', 1),
#  (u'animation', 0),
#  (u'animosity', -1),
#  (u'animus', -1),
#  (u'annihilate', -1),
#  (u'annihilated', -1),
#  (u'annihilation', -1),
#  (u'announcement', 0),
#  (u'annoy', -1),
#  (u'annoyance', -1),
#  (u'annoyances', -1),
#  (u'annoyed', -1),
#  (u'annoying', -1),
#  (u'annoyingly', -1),
#  (u'annoys', -1),
#  (u'annul', -1),
#  (u'annulment', -1),
#  (u'anoint', 1),
#  (u'anomalous', -1),
#  (u'anomaly', -1),
#  (u'anonymous', -1),
#  (u'answer', 0),
#  (u'answerable', 0),
#  (u'ant', 0),
#  (u'antagonism', -1),
#  (u'antagonist', -1),
#  (u'antagonistic', -1),
#  (u'antagonize', -1),
#  (u'antelope', 0),
#  (u'antenna', 0),
#  (u'anthem', 0),
#  (u'anthrax', -1),
#  (u'anti-', -1),
#  (u'anti-american', -1),
#  (u'anti-israeli', -1),
#  (u'anti-occupation', -1),
#  (u'anti-proliferation', -1),
#  (u'anti-semites', -1),
#  (u'anti-social', -1),
#  (u'anti-us', -1),
#  (u'anti-white', -1),
#  (u'antibiotics', 1),
#  (u'antichrist', -1),
#  (u'anticipate', 0),
#  (u'anticipation', 0),
#  (u'anticipatory', 0),
#  (u'antidote', 1),
#  (u'antifungal', 1),
#  (u'antipathy', -1),
#  (u'antiquated', -1),
#  (u'antique', 1),
#  (u'antiquity', 0),
#  (u'antiseptic', 1),
#  (u'antisocial', -1),
#  (u'antithesis', -1),
#  (u'antithetical', -1),
#  (u'anvil', 0),
#  (u'anxieties', -1),
#  (u'anxiety', -1),
#  (u'anxious', -1),
#  (u'anxiously', -1),
#  (u'anxiousness', -1),
#  (u'anyhow', 0),
#  (u'anyway', 0),
#  (u'anyways', 0),
#  (u'aorta', 0),
#  (u'apache', -1),
#  (u'apathetic', -1),
#  (u'apathetically', -1),
#  (u'apathy', -1),
#  (u'ape', -1),
#  (u'apex', 0),
#  (u'aphid', -1),
#  (u'aplomb', 1),
#  (u'apocalypse', -1),
#  (u'apocalyptic', -1),
#  (u'apologetic', 1),
#  (u'apologist', -1),
#  (u'apologists', -1),
#  (u'apologize', 1),
#  (u'apology', 1),
#  (u'apostle', 1),
#  (u'apostolic', 0),
#  (u'apostrophe', 0),
#  (u'apotheosis', 1),
#  (u'appal', -1),
#  (u'appall', -1),
#  (u'appalled', -1),
#  (u'appalling', -1),
#  (u'appallingly', -1),
#  (u'apparatus', 0),
#  (u'apparent', 0),
#  (u'apparently', 0),
#  (u'apparition', 0),
#  (u'appeal', 1),
#  (u'appealing', 1),
#  (u'appear', 0),
#  (u'appearance', 0),
#  (u'appease', 1),
#  (u'appellant', 0),
#  (u'append', 1),
#  (u'appendicitis', -1),
#  (u'appendix', 0),
#  (u'applaud', 1),
#  (u'applause', 1),
#  (u'apple', 0),
#  (u'appliance', 0),
#  (u'appliances', 0),
#  (u'applicant', 0),
#  (u'apply', 0),
#  (u'appoint', 1),
#  (u'appointment', 0),
#  (u'apportionment', 0),
#  (u'appraise', 0),
#  (u'appreciable', 1),
#  (u'appreciate', 1),
#  (u'appreciated', 1),
#  (u'appreciates', 1),
#  (u'appreciation', 1),
#  (u'appreciative', 1),
#  (u'appreciatively', 1),
#  (u'appreciativeness', 1),
#  (u'apprehend', 1),
#  (u'apprehension', -1),
#  (u'apprehensions', -1),
#  (u'apprehensive', -1),
#  (u'apprehensively', -1),
#  (u'apprentice', 0),
#  (u'apprenticeship', 0),
#  (u'approach', 1),
#  (u'approaching', 0),
#  (u'approbation', 1),
#  (u'appropriate', 1),
#  (u'appropriation', -1),
#  (u'approval', 1),
#  (u'approve', 1),
#  (u'approving', 1),
#  (u'approximate', 0),
#  (u'approximately', 0),
#  (u'approximation', 0),
#  (u'apron', 0),
#  (u'apt', 1),
#  (u'aptitude', 1),
#  (u'aptly', 1),
#  (u'aqua', 0),
#  (u'aquamarine', 0),
#  (u'aquarium', 0),
#  (u'aquatic', 0),
#  (u'aqueduct', 0),
#  (u'aqueous', 0),
#  (u'arable', 0),
#  (u'arbiter', 1),
#  (u'arbitrary', -1),
#  (u'arbitrate', 1),
#  (u'arbitration', 1),
#  (u'arbitrator', 0),
#  (u'arbor', 0),
#  (u'arcane', -1),
#  (u'archaeological', 0),
#  (u'archaeologist', 0),
#  (u'archaeology', 1),
#  (u'archaic', -1),
#  (u'archipelago', 0),
#  (u'architecture', 0),
#  (u'arctic', 0),
#  (u'ardent', 1),
#  (u'ardently', 1),
#  (u'ardor', 1),
#  (u'arduous', -1),
#  (u'arduously', -1),
#  (u'argent', 0),
#  (u'argue', -1),
#  (u'argument', -1),
#  (u'argumentation', 0),
#  (u'argumentative', -1),
#  (u'arguments', -1),
#  (u'arid', -1),
#  (u'arise', 0),
#  (u'arisen', 1),
#  (u'aristocracy', 1),
#  (u'aristocrat', 1),
#  (u'aristocratic', 1),
#  (u'arithmetic', 0),
#  (u'ark', 0),
#  (u'arm', 0),
#  (u'armada', 0),
#  (u'armament', 0),
#  (u'armaments', -1),
#  (u'armed', -1),
#  (u'armor', 1),
#  (u'armored', 0),
#  (u'armory', 0),
#  (u'army', 0),
#  (u'aroma', 1),
#  (u'arose', 0),
#  (u'arousal', 1),
#  (u'arouse', 1),
#  (u'arousing', 1),
#  (u'arraignment', -1),
#  (u'arrange', 0),
#  (u'arrangement', 0),
#  (u'array', 1),
#  (u'arrears', -1),
#  (u'arrest', -1),
#  (u'arresting', 1),
#  (u'arrival', 0),
#  (u'arrive', 0),
#  (u'arrogance', -1),
#  (u'arrogant', -1),
#  (u'arrogantly', -1),
#  (u'arsenic', -1),
#  (u'arson', -1),
#  (u'art', 1),
#  (u'artery', 0),
#  (u'arthropod', 0),
#  (u'artichoke', 0),
#  (u'articles', 0),
#  (u'articulate', 1),
#  (u'articulation', 1),
#  (u'artificial', -1),
#  (u'artillery', -1),
#  (u'artisan', 1),
#  (u'artiste', 1),
#  (u'artistic', 1),
#  (u'ascend', 0),
#  (u'ascendancy', 1),
#  (u'ascendant', 1),
#  (u'ascension', 0),
#  (u'ascent', 1),
#  (u'ascertain', 0),
#  (u'ascertainable', 1),
#  (u'ascertainment', 0),
#  (u'ascribe', 1),
#  (u'ash', -1),
#  (u'ashamed', -1),
#  (u'ashes', -1),
#  (u'asinine', -1),
#  (u'asininely', -1),
#  (u'asinininity', -1),
#  (u'ask', 0),
#  (u'askance', -1),
#  (u'asleep', 0),
#  (u'asp', 0),
#  (u'aspartame', 0),
#  (u'asperse', -1),
#  (u'aspersion', -1),
#  (u'aspersions', -1),
#  (u'asphalt', 0),
#  (u'aspiration', 1),
#  (u'aspirations', 1),
#  (u'aspire', 1),
#  (u'aspiring', 1),
#  (u'ass', -1),
#  (u'assail', -1),
#  (u'assailant', -1),
#  (u'assassin', -1),
#  (u'assassinate', -1),
#  (u'assassination', -1),
#  (u'assault', -1),
#  (u'assemble', 0),
#  (u'assembly', 1),
#  (u'assent', 1),
#  (u'assert', 0),
#  (u'asserting', 1),
#  (u'assertion', 1),
#  (u'assertions', 1),
#  (u'assertive', 1),
#  (u'assess', 0),
#  (u'assessment', 0),
#  (u'assessments', 0),
#  (u'assessor', 0),
#  (u'asset', 1),
#  (u'assets', 1),
#  (u'asshole', -1),
#  (u'assiduous', 1),
#  (u'assiduously', 1),
#  (u'assign', 0),
#  (u'assignee', 0),
#  (u'assignment', 0),
#  (u'assimilate', 0),
#  (u'assist', 1),
#  (u'assistance', 1),
#  (u'assistant', 1),
#  (u'associate', 1),
#  (u'association', 1),
#  (u'assuage', 1),
#  (u'assult', -1),
#  (u'assume', 0),
#  (u'assumption', 0),
#  (u'assurance', 1),
#  (u'assurances', 1),
#  (u'assure', 1),
#  (u'assured', 1),
#  (u'assuredly', 1),
#  (u'assuring', 1),
#  (u'asterisk', 0),
#  (u'astonish', 1),
#  (u'astonished', 1),
#  (u'astonishing', 1),
#  (u'astonishingly', 1),
#  (u'astonishment', 1),
#  (u'astound', 1),
#  (u'astounded', 1),
#  (u'astounding', 1),
#  (u'astoundingly', 1),
#  (u'astray', -1),
#  (u'astringent', -1),
#  (u'astrologer', 1),
#  (u'astronaut', 1),
#  (u'astronomer', 1),
#  (u'astronomic', 0),
#  (u'astronomical', 0),
#  (u'astronomically', 0),
#  (u'astute', 1),
#  (u'astutely', 1),
#  (u'asunder', -1),
#  (u'asylum', -1),
#  (u'asymmetric', 0),
#  (u'asymmetry', 0),
#  (u'asymptotic', 0),
#  (u'ate', 0),
#  (u'atheism', -1),
#  (u'atherosclerosis', -1),
#  (u'athlete', 1),
#  (u'athletic', 1),
#  (u'athletics', 0),
#  (u'atmospheric', 0),
#  (u'atom', 1),
#  (u'atone', 1),
#  (u'atonement', 1),
#  (u'atrocious', -1),
#  (u'atrocities', -1),
#  (u'atrocity', -1),
#  (u'atrophy', -1),
#  (u'attach', 0),
#  (u'attachment', 1),
#  (u'attack', -1),
#  (u'attacking', -1),
#  (u'attacks', -1),
#  (u'attain', 1),
#  (u'attainable', 1),
#  (u'attainment', 1),
#  (u'attempt', 0),
#  (u'attend', 1),
#  (u'attendance', 1),
#  (u'attendant', 1),
#  (u'attention', 1),
#  (u'attentive', 1),
#  (u'attenuated', -1),
#  (u'attenuation', -1),
#  (u'attest', 1),
#  (u'attestation', 0),
#  (u'attic', 0),
#  (u'attitude', 0),
#  (u'attitudes', 0),
#  (u'attorney', 1),
#  (u'attract', 1),
#  (u'attraction', 1),
#  (u'attractive', 1),
#  (u'attractively', 1),
#  (u'attractiveness', 1),
#  (u'attrition', 0),
#  (u'attune', 1),
#  (u'auburn', 0),
#  (u'auction', 0),
#  (u'audacious', -1),
#  (u'audaciously', -1),
#  (u'audaciousness', -1),
#  (u'audacity', -1),
#  (u'audible', 1),
#  (u'audibly', 1),
#  (u'audiciously', -1),
#  (u'audience', 0),
#  (u'auditor', 0),
#  (u'auditory', 0),
#  (u'augment', 1),
#  (u'augmentation', 1),
#  (u'august', 1),
#  (u'aunt', 1),
#  (u'aura', 1),
#  (u'auspices', 0),
#  (u'auspicious', 1),
#  (u'austere', -1),
#  (u'austerity', -1),
#  (u'authentic', 1),
#  (u'authenticate', 0),
#  (u'authentication', 0),
#  (u'authenticity', 1),
#  (u'author', 1),
#  (u'authoritarian', -1),
#  (u'authoritative', 1),
#  (u'authority', 1),
#  (u'authorization', 1),
#  (u'authorize', 0),
#  (u'authorized', 1),
#  (u'auto', 0),
#  (u'autocrat', -1),
#  (u'autocratic', -1),
#  (u'autograph', 0),
#  (u'automatic', 0),
#  (u'autonomous', 1),
#  (u'autopsy', -1),
#  (u'autumn', 0),
#  (u'auxiliary', 0),
#  (u'avail', 0),
#  (u'availability', 1),
#  (u'available', 1),
#  (u'avalanche', -1),
#  (u'avarice', -1),
#  (u'avaricious', -1),
#  (u'avariciously', -1),
#  (u'avatar', 1),
#  (u'avenge', -1),
#  (u'avenger', -1),
#  (u'aver', 1),
#  (u'average', 0),
#  (u'averse', -1),
#  (u'aversion', -1),
#  (u'avert', 0),
#  (u'avid', 1),
#  (u'avidly', 1),
#  (u'avocado', 0),
#  (u'avoid', -1),
#  (u'avoidance', -1),
#  (u'avoiding', 0),
#  (u'await', 0),
#  (u'awaken', 0),
#  (u'award', 1),
#  (u'awarded', 1),
#  (u'awards', 1),
#  (u'aware', 1),
#  (u'awareness', 1),
#  (u'awe', 1),
#  (u'awed', 1),
#  (u'aweful', -1),
#  (u'awesome', 1),
#  (u'awesomely', 1),
#  (u'awesomeness', 1),
#  (u'awestruck', 1),
#  (u'awful', -1),
#  (u'awfully', -1),
#  (u'awfulness', -1),
#  (u'awkward', -1),
#  (u'awkwardness', -1),
#  (u'awry', -1),
#  (u'awsome', 1),
#  ...]

# %%
len(poswords), len(negwords)
# Out:
# (4295, 6621)

# %%
4295/(4295+6621.0)
# Out:
# 0.3934591425430561

# %%
chandlerposwords = []
chandlernegwords = []
for i in rep:
    if i in poswords:
        chandlerposwords.append(i)
    elif i in negwords:
        chandlernegwords.append(i)

# %%
chandlerposwords
# Out:
# [u'prize',
#  u'elegant',
#  u'captain',
#  u'relieving',
#  u'bonuses',
#  u'admiral',
#  u'hero',
#  u'reporter',
#  u'substance',
#  u'golden',
#  u'music',
#  u'holy',
#  u'relax',
#  u'successful',
#  u'pointedly',
#  u'household',
#  u'organized',
#  u'arresting',
#  u'want',
#  u'absolute',
#  u'travel',
#  u'hot',
#  u'preferable',
#  u'dignified',
#  u'beauty',
#  u'effective',
#  u'wins',
#  u'childhood',
#  u'welcomed',
#  u'soothingly',
#  u'fit',
#  u'easier',
#  u'scholar',
#  u'spotless',
#  u'substantially',
#  u'encourage',
#  u'adapt',
#  u'assured',
#  u'playfully',
#  u'master',
#  u'positively',
#  u'tree',
#  u'wholesome',
#  u'concrete',
#  u'responsible',
#  u'eagerly',
#  u'rich',
#  u'heartily',
#  u'cushion',
#  u'nicely',
#  u'accordance',
#  u'fair',
#  u'best',
#  u'score',
#  u'dexterously',
#  u'topmost',
#  u'truthful',
#  u'conversational',
#  u'child',
#  u'worked',
#  u'elaborate',
#  u'trusted',
#  u'fairly',
#  u'tops',
#  u'ownership',
#  u'stillness',
#  u'succeeding',
#  u'ease',
#  u'easy',
#  u'birth',
#  u'unique',
#  u'desire',
#  u'attorney',
#  u'right',
#  u'insistence',
#  u'consensus',
#  u'honeymoon',
#  u'respectable',
#  u'support',
#  u'humorous',
#  u'happy',
#  u'offer',
#  u'amusing',
#  u'safeguard',
#  u'congratulations',
#  u'utmost',
#  u'unanimous',
#  u'mighty',
#  u'proven',
#  u'proves',
#  u'resources',
#  u'understandable',
#  u'rousing',
#  u'choice',
#  u'exact',
#  u'settle',
#  u'spiritual',
#  u'celebrated',
#  u'boost',
#  u'understanding',
#  u'brilliant',
#  u'love',
#  u'prefer',
#  u'logical',
#  u'marvelous',
#  u'fresher',
#  u'working',
#  u'theoretical',
#  u'loving',
#  u'afford',
#  u'easiest',
#  u'behalf',
#  u'values',
#  u'evidently',
#  u'natural',
#  u'thoughtfulness',
#  u'joker',
#  u'modest',
#  u'intuition',
#  u'open',
#  u'convent',
#  u'proving',
#  u'inventor',
#  u'overtaken',
#  u'glossy',
#  u'prospect',
#  u'nicer',
#  u'fashionably',
#  u'drive',
#  u'quiescent',
#  u'bright',
#  u'uppermost',
#  u'assistant',
#  u'infallible',
#  u'prime',
#  u'priest',
#  u'vision',
#  u'jovial',
#  u'spare',
#  u'gaiety',
#  u'enable',
#  u'majestic',
#  u'prominence',
#  u'straighten',
#  u'engaged',
#  u'regularity',
#  u'fame',
#  u'preparatory',
#  u'cheery',
#  u'rest',
#  u'prominently',
#  u'dare',
#  u'satisfactory',
#  u'divine',
#  u'faster',
#  u'scientific',
#  u'intimate',
#  u'ace',
#  u'favorite',
#  u'slender',
#  u'chivalry',
#  u'gleam',
#  u'complete',
#  u'wits',
#  u'land',
#  u'handsome',
#  u'pull',
#  u'ay',
#  u'tranquil',
#  u'cream',
#  u'original',
#  u'consider',
#  u'careful',
#  u'laughing',
#  u'smile',
#  u'candid',
#  u'large',
#  u'sane',
#  u'quicker',
#  u'pass',
#  u'nurse',
#  u'full',
#  u'smartest',
#  u'experience',
#  u'acquittal',
#  u'action',
#  u'company',
#  u'chisel',
#  u'carefully',
#  u'learn',
#  u'beautiful',
#  u'prompt',
#  u'accept',
#  u'sense',
#  u'information',
#  u'dazzle',
#  u'glowing',
#  u'intended',
#  u'ethics',
#  u'authentic',
#  u'smiling',
#  u'ally',
#  u'found',
#  u'resolute',
#  u'police',
#  u'darling',
#  u'major',
#  u'dumbfounded',
#  u'glitter',
#  u'peaceable',
#  u'nobly',
#  u'saint',
#  u'justly',
#  u'appreciation',
#  u'grace',
#  u'determined',
#  u'marriage',
#  u'caress',
#  u'gold',
#  u'defended',
#  u'consistently',
#  u'writer',
#  u'sunny',
#  u'remedy',
#  u'terrifically',
#  u'sex',
#  u'sea',
#  u'outward',
#  u'spirits',
#  u'candor',
#  u'premises',
#  u'renewed',
#  u'prospects',
#  u'community',
#  u'church',
#  u'sweetheart',
#  u'engage',
#  u'straight',
#  u'backing',
#  u'elevated',
#  u'reachable',
#  u'admission',
#  u'eager',
#  u'quest',
#  u'chorus',
#  u'continue',
#  u'curious',
#  u'twinkle',
#  u'novelty',
#  u'inclination',
#  u'agreement',
#  u'deserved',
#  u'recommended',
#  u'appropriate',
#  u'primarily',
#  u'assuring',
#  u'occupy',
#  u'suit',
#  u'relaxed',
#  u'considerable',
#  u'genial',
#  u'surveying',
#  u'graceful',
#  u'definitely',
#  u'reasoned',
#  u'fresh',
#  u'softer',
#  u'young',
#  u'marry',
#  u'victor',
#  u'oration',
#  u'led',
#  u'great',
#  u'innocence',
#  u'cooperative',
#  u'standing',
#  u'confidence',
#  u'baby',
#  u'gladly',
#  u'charity',
#  u'customer',
#  u'athlete',
#  u'slim',
#  u'beckoned',
#  u'preferring',
#  u'daring',
#  u'allow',
#  u'classy',
#  u'passion',
#  u'perfect',
#  u'insistent',
#  u'kiss',
#  u'transparent',
#  u'intelligent',
#  u'sufficiently',
#  u'delightful',
#  u'truth',
#  u'soundly',
#  u'hilarious',
#  u'title',
#  u'surely',
#  u'glistening',
#  u'soothing',
#  u'interests',
#  u'stars',
#  u'vouch',
#  u'appealing',
#  u'trusting',
#  u'gentle',
#  u'defending',
#  u'clearly',
#  u'heft',
#  u'accuracy',
#  u'courtesy',
#  u'medal',
#  u'stronger',
#  u'jam',
#  u'hope',
#  u'familiar',
#  u'lucky',
#  u'strides',
#  u'phonetic',
#  u'labor',
#  u'steadiness',
#  u'apologize',
#  u'coherence',
#  u'ball',
#  u'pleasantly',
#  u'generous',
#  u'kindness',
#  u'mannered',
#  u'dove',
#  u'flush',
#  u'imperative',
#  u'recognition',
#  u'doer',
#  u'keystone',
#  u'cultivated',
#  u'watchman',
#  u'naturally',
#  u'count',
#  u'smooth',
#  u'triumphant',
#  u'excitement',
#  u'convince',
#  u'rightly',
#  u'desirable',
#  u'encouragingly',
#  u'worth',
#  u'inquisitive',
#  u'triumph',
#  u'aristocrat',
#  u'deliberate',
#  u'religious',
#  u'neat',
#  u'protection',
#  u'celebration',
#  u'balance',
#  u'daughter',
#  u'credentials',
#  u'study',
#  u'glittering',
#  u'predominant',
#  u'ascribe',
#  u'word',
#  u'work',
#  u'recovery',
#  u'law',
#  u'shimmering',
#  u'appreciate',
#  u'greet',
#  u'green',
#  u'order',
#  u'modesty',
#  u'satisfied',
#  u'mayor',
#  u'safe',
#  u'reasonably',
#  u'reasonable',
#  u'recognizable',
#  u'fellowship',
#  u'amazement',
#  u'truthfulness',
#  u'organize',
#  u'thoughtfully',
#  u'compromise',
#  u'happily',
#  u'mercy',
#  u'iron',
#  u'strength',
#  u'genuine',
#  u'convenient',
#  u'elation',
#  u'luxury',
#  u'acquire',
#  u'maiden',
#  u'aunt',
#  u'notion',
#  u'reserve',
#  u'subtle',
#  u'enjoyed',
#  u'toast',
#  u'personality',
#  u'bodyguard',
#  u'gladness',
#  u'gentleman',
#  u'accord',
#  u'admiring',
#  u'matrimony',
#  u'gratitude',
#  u'exceeded',
#  u'flexible',
#  u'warmth',
#  u'innocent',
#  u'physician',
#  u'comfortably',
#  u'aid',
#  u'overtaking',
#  u'exceptionally',
#  u'confirmed',
#  u'soldier',
#  u'patent',
#  u'hand',
#  u'athletic',
#  u'board',
#  u'invaluable',
#  u'antique',
#  u'humor',
#  u'trophy',
#  u'profession',
#  u'balanced',
#  u'amused',
#  u'available',
#  u'vitality',
#  u'astonished',
#  u'true',
#  u'maximum',
#  u'crystal',
#  u'promises',
#  u'muscular',
#  u'definite',
#  u'promised',
#  u'interested',
#  u'guiltless',
#  u'convincing',
#  u'polite',
#  u'mightily',
#  u'loyal',
#  u'precedent',
#  u'dance',
#  u'grateful',
#  u'protective',
#  u'brave',
#  u'assistance',
#  u'uniform',
#  u'appeal',
#  u'satisfy',
#  u'supporting',
#  u'whiteness',
#  u'teacher',
#  u'merriment',
#  u'pillow',
#  u'extra',
#  u'marked',
#  u'sincerely',
#  u'prove',
#  u'live',
#  u'wonderfully',
#  u'entrance',
#  u'indescribable',
#  u'indescribably',
#  u'cab',
#  u'heart',
#  u'purity',
#  u'discussion',
#  u'flourish',
#  u'explicit',
#  u'occupant',
#  u'nerve',
#  u'playful',
#  u'lyre',
#  u'acknowledge',
#  u'chattering',
#  u'wealthy',
#  u'amusement',
#  u'increase',
#  u'care',
#  u'honest',
#  u'invitation',
#  u'promotion',
#  u'striking',
#  u'truthfully',
#  u'silent',
#  u'capitalize',
#  u'friend',
#  u'brains',
#  u'playmate',
#  u'amiable',
#  u'indisputable',
#  u'angel',
#  u'breakfast',
#  u'recover',
#  u'terrific',
#  u'neatly',
#  u'importantly',
#  u'reform',
#  u'steady',
#  u'sunset',
#  u'professional',
#  u'gratified',
#  u'truly',
#  u'roadster',
#  u'nicest',
#  u'pray',
#  u'learning',
#  u'favoritism',
#  u'embrace',
#  u'generously',
#  u'develop',
#  u'poetic',
#  u'inquiry',
#  u'noble',
#  u'constitutional',
#  u'authoritative',
#  u'breeze',
#  u'valuable',
#  u'civilized',
#  u'real',
#  u'earnest',
#  u'fortune',
#  u'greeting',
#  u'benefit',
#  u'assembly',
#  u'exciting',
#  u'fondness',
#  u'boldly',
#  u'journey',
#  u'dazzling',
#  u'watchdog',
#  u'politeness',
#  u'curiously',
#  u'hire',
#  u'receptive',
#  u'mover',
#  u'valid',
#  u'pool',
#  u'building',
#  u'bull',
#  u'thoughtful',
#  u'bequeath',
#  u'indubitably',
#  u'heaven',
#  u'ceaseless',
#  u'mild',
#  u'casual',
#  u'chuckle',
#  u'conscience',
#  u'learned',
#  u'strong',
#  u'ahead',
#  u'toughness',
#  u'bloodless',
#  u'foreseen',
#  u'dream',
#  u'help',
#  u'committed',
#  u'food',
#  u'fully',
#  u'safety',
#  u'reason',
#  u'bask',
#  u'heroic',
#  u'merry',
#  u'elder',
#  u'wonderful',
#  u'kindly',
#  u'aristocracy',
#  u'bride',
#  u'store',
#  u'sturdy',
#  u'clear',
#  u'clean',
#  u'pretty',
#  u'famous',
#  u'perfume',
#  u'recommendations',
#  u'courteous',
#  u'plausible',
#  u'culture',
#  u'practice',
#  u'wow',
#  u'familiarity',
#  u'league',
#  u'sensitive',
#  u'protector',
#  u'liked',
#  u'manners',
#  u'likes',
#  u'compromises',
#  u'smart',
#  u'guide',
#  u'ready',
#  u'grant',
#  u'grand',
#  u'bonus',
#  u'cleaning',
#  u'conveniently',
#  u'clears',
#  u'ambassador',
#  u'useful',
#  u'march',
#  u'enthusiastically',
#  u'outright',
#  u'inviting',
#  u'manifest',
#  u'softness',
#  u'ingratiating',
#  u'civilization',
#  u'suavely',
#  u'wealth',
#  u'shine',
#  u'faith',
#  u'aye',
#  u'positive',
#  u'shiny',
#  u'miracles',
#  u'caretaker',
#  u'properly',
#  u'corroborate',
#  u'cautiously',
#  u'nap',
#  u'forge',
#  u'smiles',
#  u'depth',
#  u'evenly',
#  u'cheerful',
#  u'helped',
#  u'proposition',
#  u'compact',
#  u'effort',
#  u'friendly',
#  u'virtuous',
#  u'fond',
#  u'persuade',
#  u'jump',
#  u'ardent',
#  u'convert',
#  u'justice',
#  u'addresses',
#  u'win',
#  u'manage',
#  u'wit',
#  u'agreeably',
#  u'agreeable',
#  u'charming',
#  u'meet',
#  u'articulation',
#  u'placid',
#  u'handy',
#  u'university',
#  u'upward',
#  u'variety',
#  u'special',
#  u'thriving',
#  u'completely',
#  u'stride',
#  u'powerful',
#  u'improving',
#  u'precisely',
#  u'quality',
#  u'management',
#  u'privacy',
#  u'perfectly',
#  u'defense',
#  u'providing',
#  u'sultry',
#  u'assurances',
#  u'able',
#  u'delivery',
#  u'shield',
#  u'winner',
#  u'hopeful',
#  u'brighter',
#  u'achieve',
#  u'dodge',
#  u'legitimate',
#  u'evident',
#  u'sensuality',
#  u'correctly',
#  u'nutritious',
#  u'importance',
#  u'approval',
#  u'precious',
#  u'career',
#  u'admit',
#  u'immense',
#  u'suggestions',
#  u'spaniel',
#  u'novel',
#  u'resident',
#  u'earnestness',
#  u'well',
#  u'corporation',
#  u'restore',
#  u'accurate',
#  u'laurel',
#  u'skill',
#  u'keen',
#  u'ample',
#  u'prominent',
#  u'necessary',
#  u'library',
#  u'hush',
#  u'warmer',
#  u'home',
#  u'liking',
#  u'broad',
#  u'cradle',
#  u'humorously',
#  u'offset',
#  u'freedom',
#  u'equally',
#  u'articulate',
#  u'utility',
#  u'doubtless',
#  u'clown',
#  u'gain',
#  u'eat',
#  u'dame',
#  u'authority',
#  u'star',
#  u'astounding',
#  u'friends',
#  u'appoint',
#  u'determination',
#  u'pardon',
#  u'attentive',
#  u'confederate',
#  u'solution',
#  u'convenience',
#  u'even',
#  u'desirous',
#  u'orchestra',
#  u'active',
#  u'credit',
#  u'permit',
#  u'suitable',
#  u'fantastic',
#  u'call',
#  u'calm',
#  u'recommend',
#  u'survive',
#  u'warm',
#  u'rights',
#  u'persuasive',
#  u'give',
#  u'honey',
#  u'curiosity',
#  u'president',
#  u'assuredly',
#  u'goodbye',
#  u'better',
#  u'vigorous',
#  u'brightness',
#  u'luck',
#  u'dawn',
#  u'velvet',
#  u'content',
#  u'reader',
#  u'surprise',
#  u'moving',
#  u'task',
#  u'matter',
#  u'modern',
#  u'fitting',
#  u'established',
#  u'ensure',
#  u'principle',
#  u'visitor',
#  u'divinity',
#  u'explain',
#  u'sugar',
#  u'reconstruction',
#  u'coast',
#  u'earn',
#  u'optimistic',
#  u'fascinating',
#  u'simplest',
#  u'tolerance',
#  u'gems',
#  u'kindred',
#  u'amazing',
#  u'contribution',
#  u'represented',
#  u'resourcefulness',
#  u'commission',
#  u'interest',
#  u'lovely',
#  u'guardianship',
#  u'make',
#  u'delight',
#  u'opportunity',
#  u'kid',
#  u'practiced',
#  u'fashionable',
#  u'consciousness',
#  u'human',
#  u'facts',
#  u'yep',
#  u'yes',
#  u'candidate',
#  u'save',
#  u'discreet',
#  u'dreamy',
#  u'dreams',
#  u'shoulder',
#  u'dignity',
#  u'patience',
#  u'deal',
#  u'dear',
#  u'bold',
#  u'marshal',
#  u'thinner',
#  u'refined',
#  u'flying',
#  u'creditable',
#  u'fore',
#  u'powerfully',
#  u'agreeing',
#  u'apology',
#  u'precise',
#  u'relieve',
#  u'resourceful',
#  u'fancier',
#  u'finally',
#  u'choir',
#  u'round',
#  u'guardian',
#  u'tolerantly',
#  u'elect',
#  u'plumb',
#  u'sympathetic',
#  u'sharper',
#  u'visit',
#  u'compactly',
#  u'soup',
#  u'purr',
#  u'pure',
#  u'sworn',
#  u'grow',
#  u'tale',
#  u'provide',
#  u'talk',
#  u'cute',
#  u'cathedral',
#  u'wishing',
#  u'stability',
#  u'thank',
#  u'interesting',
#  u'main',
#  u'swiftness',
#  u'rock',
#  u'ripe',
#  u'correct',
#  u'assurance',
#  u'advance',
#  u'question',
#  u'fast',
#  u'accurately',
#  u'undoubtedly',
#  u'gigantic',
#  u'efficient',
#  u'interior',
#  u'normal',
#  u'especially',
#  u'gracefully',
#  u'enough',
#  u'enthusiasm',
#  u'honesty',
#  u'seal',
#  u'salutation',
#  u'wonder',
#  u'satisfying',
#  u'reading',
#  u'august',
#  u'comprehend',
#  u'logic',
#  u'sensible',
#  u'capable',
#  u'educated',
#  u'sound',
#  u'sincere',
#  u'pay',
#  u'speech',
#  u'triumphantly',
#  u'companion',
#  u'easing',
#  u'amazed',
#  u'money',
#  u'astonishment',
#  u'extensive',
#  u'pill',
#  u'grin',
#  u'twin',
#  u'voluntarily',
#  u'passionate',
#  u'instantly',
#  u'moderate',
#  u'profusely',
#  u'notable',
#  u'squarely',
#  u'practical',
#  u'structure',
#  u'noiseless',
#  u'sensibly',
#  u'affection',
#  u'fellow',
#  u'imagination',
#  u'shopping',
#  u'fill',
#  u'shelter',
#  u'important',
#  u'equitable',
#  u'god',
#  u'enjoying',
#  u'winning',
#  u'affable',
#  u'ribbon',
#  u'stood',
#  u'tribute',
#  u'public',
#  u'promising',
#  u'dashing',
#  u'eye',
#  u'distinct',
#  u'diamond',
#  u'formality',
#  u'landed',
#  u'particular',
#  u'treaty',
#  u'share',
#  u'numbers',
#  u'sharp',
#  u'flawless',
#  u'comfort',
#  u'sacred',
#  u'advice',
#  u'bloom',
#  u'doctor',
#  u'responsibility',
#  u'pleasure',
#  u'infant',
#  u'pad',
#  u'good',
#  u'unreal',
#  u'association',
#  u'easily',
#  u'exquisite',
#  u'engaging',
#  u'connect',
#  u'assist',
#  u'pleasant',
#  u'wages',
#  u'smoother',
#  u'beloved',
#  u'vibrant',
#  u'needle',
#  u'sensation',
#  u'favorable',
#  u'youth',
#  u'majority',
#  u'build',
#  u'charm',
#  u'significant',
#  u'amaze',
#  u'sanctity',
#  u'fine',
#  u'permission',
#  u'cheaper',
#  u'courage',
#  u'silk',
#  u'common',
#  u'gospel',
#  u'lion',
#  u'tender',
#  u'expert',
#  u'please',
#  u'trustingly',
#  u'simple',
#  u'patiently',
#  u'create',
#  u'gay',
#  u'understand',
#  u'solid',
#  u'fun',
#  u'benign',
#  u'leisurely',
#  u'organization',
#  u'preference',
#  u'shape',
#  ...]

# %%
chandlernegwords
# Out:
# [u'fawn',
#  u'hanging',
#  u'scold',
#  u'lord',
#  u'foul',
#  u'disturb',
#  u'busybody',
#  u'tired',
#  u'haughtily',
#  u'spitefulness',
#  u'cult',
#  u'spotty',
#  u'divide',
#  u'stern',
#  u'cocaine',
#  u'cheating',
#  u'spoke',
#  u'strike',
#  u'hurt',
#  u'hole',
#  u'caution',
#  u'hog',
#  u'complaining',
#  u'damage',
#  u'gouge',
#  u'despondent',
#  u'wrong',
#  u'extortion',
#  u'sarcastically',
#  u'wrought',
#  u'wickedly',
#  u'screaming',
#  u'hidden',
#  u'ached',
#  u'indecent',
#  u'clumsy',
#  u'addicted',
#  u'whip',
#  u'smirk',
#  u'disinterested',
#  u'fugitive',
#  u'enormous',
#  u'disturbed',
#  u'loudness',
#  u'bitter',
#  u'collapse',
#  u'motionless',
#  u'crawl',
#  u'peril',
#  u'coward',
#  u'rusty',
#  u'pneumonia',
#  u'idle',
#  u'feeling',
#  u'shyly',
#  u'pigs',
#  u'defiantly',
#  u'hum',
#  u'object',
#  u'addict',
#  u'conceded',
#  u'scream',
#  u'bomb',
#  u'busy',
#  u'bust',
#  u'touched',
#  u'emphatically',
#  u'spilling',
#  u'patch',
#  u'unexpectedly',
#  u'resigned',
#  u'stealthy',
#  u'scorn',
#  u'pirate',
#  u'smelled',
#  u'debt',
#  u'pity',
#  u'accident',
#  u'dents',
#  u'argue',
#  u'obscenity',
#  u'chill',
#  u'gritty',
#  u'severity',
#  u'cumbersome',
#  u'haphazard',
#  u'split',
#  u'emphatic',
#  u'haggard',
#  u'chafing',
#  u'coldness',
#  u'subpoena',
#  u'prison',
#  u'knock',
#  u'shadow',
#  u'creep',
#  u'enemies',
#  u'bottom',
#  u'inhuman',
#  u'gorge',
#  u'losing',
#  u'despair',
#  u'lacked',
#  u'slightly',
#  u'sob',
#  u'goddamn',
#  u'shrilly',
#  u'myopia',
#  u'smashed',
#  u'disgrace',
#  u'protested',
#  u'smell',
#  u'slaves',
#  u'smelling',
#  u'warn',
#  u'stricken',
#  u'writhe',
#  u'jarring',
#  u'uneven',
#  u'jerk',
#  u'gloomy',
#  u'leave',
#  u'somber',
#  u'anaconda',
#  u'depressions',
#  u'falling',
#  u'crashing',
#  u'dwindling',
#  u'concealed',
#  u'bloody',
#  u'fake',
#  u'angry',
#  u'opposed',
#  u'scratched',
#  u'intoxicated',
#  u'scratches',
#  u'discontented',
#  u'tobacco',
#  u'unnatural',
#  u'pretend',
#  u'slowness',
#  u'offense',
#  u'stole',
#  u'divided',
#  u'spot',
#  u'wrinkled',
#  u'filthy',
#  u'disagreeable',
#  u'darkened',
#  u'swollen',
#  u'drunken',
#  u'yawning',
#  u'thumb',
#  u'torn',
#  u'troubles',
#  u'suspicion',
#  u'thump',
#  u'troubled',
#  u'bashful',
#  u'revert',
#  u'breach',
#  u'owing',
#  u'astray',
#  u'seriously',
#  u'complicated',
#  u'bumpy',
#  u'scarred',
#  u'gaff',
#  u'neglect',
#  u'vote',
#  u'bite',
#  u'lesbian',
#  u'ridiculous',
#  u'fooled',
#  u'impractical',
#  u'depressed',
#  u'damned',
#  u'illness',
#  u'sag',
#  u'argument',
#  u'sad',
#  u'buried',
#  u'sap',
#  u'wanting',
#  u'ironically',
#  u'touchy',
#  u'friction',
#  u'scarce',
#  u'aggressive',
#  u'slow',
#  u'cursing',
#  u'worried',
#  u'liable',
#  u'worries',
#  u'gangster',
#  u'teens',
#  u'checkered',
#  u'menacing',
#  u'extravagantly',
#  u'libel',
#  u'profane',
#  u'dubious',
#  u'lump',
#  u'breakdown',
#  u'sickness',
#  u'domineering',
#  u'idiotically',
#  u'peculiarities',
#  u'slimy',
#  u'grounded',
#  u'starving',
#  u'dark',
#  u'snarl',
#  u'snare',
#  u'vague',
#  u'boast',
#  u'stranger',
#  u'claw',
#  u'stationary',
#  u'unsuccessfully',
#  u'stone',
#  u'burning',
#  u'sneering',
#  u'burglar',
#  u'rage',
#  u'dirty',
#  u'rust',
#  u'darker',
#  u'fright',
#  u'exhausted',
#  u'stealing',
#  u'wildly',
#  u'ax',
#  u'sympathetically',
#  u'dented',
#  u'menace',
#  u'mocking',
#  u'weariness',
#  u'hunting',
#  u'puzzled',
#  u'harry',
#  u'small',
#  u'handicapped',
#  u'hash',
#  u'indecision',
#  u'obstructing',
#  u'possession',
#  u'cunning',
#  u'neglected',
#  u'creature',
#  u'lanky',
#  u'sympathize',
#  u'refuse',
#  u'rowdy',
#  u'wrench',
#  u'blurring',
#  u'symptoms',
#  u'plotters',
#  u'ruining',
#  u'lies',
#  u'wry',
#  u'severely',
#  u'dispiritedly',
#  u'weeds',
#  u'sucked',
#  u'coping',
#  u'disorganized',
#  u'anxious',
#  u'impudence',
#  u'nervously',
#  u'reproach',
#  u'bumped',
#  u'devoid',
#  u'insolence',
#  u'clump',
#  u'flimsy',
#  u'condolences',
#  u'suffocating',
#  u'commotion',
#  u'frail',
#  u'unequal',
#  u'arson',
#  u'gaby',
#  u'barred',
#  u'barren',
#  u'dragged',
#  u'despise',
#  u'ugh',
#  u'overwhelmed',
#  u'peculiar',
#  u'failed',
#  u'unjustly',
#  u'indifference',
#  u'resent',
#  u'frightening',
#  u'enemy',
#  u'obscure',
#  u'insane',
#  u'untouched',
#  u'barely',
#  u'poverty',
#  u'loaf',
#  u'hollow',
#  u'belt',
#  u'worthless',
#  u'devil',
#  u'hardness',
#  u'uncertain',
#  u'pound',
#  u'agitation',
#  u'chase',
#  u'funny',
#  u'deformity',
#  u'horde',
#  u'uncouth',
#  u'rumbling',
#  u'stunt',
#  u'crying',
#  u'shove',
#  u'emergency',
#  u'suffering',
#  u'blackjack',
#  u'pale',
#  u'seclusion',
#  u'crooks',
#  u'odor',
#  u'obscured',
#  u'exaggerated',
#  u'wrinkles',
#  u'ambush',
#  u'illegal',
#  u'garbage',
#  u'competition',
#  u'influence',
#  u'concealment',
#  u'puzzling',
#  u'invalid',
#  u'wrongly',
#  u'hells',
#  u'annoyed',
#  u'incomplete',
#  u'sharply',
#  u'scratch',
#  u'concerned',
#  u'dislike',
#  u'torture',
#  u'damning',
#  u'try',
#  u'rack',
#  u'crook',
#  u'odd',
#  u'punch',
#  u'doubt',
#  u'irrepressible',
#  u'rubbish',
#  u'defiance',
#  u'retreated',
#  u'wedge',
#  u'bent',
#  u'slip',
#  u'weaken',
#  u'struggling',
#  u'delay',
#  u'comedy',
#  u'scornful',
#  u'fits',
#  u'noises',
#  u'knotted',
#  u'reversal',
#  u'doubtful',
#  u'snake',
#  u'cage',
#  u'watery',
#  u'bump',
#  u'deficiency',
#  u'irritation',
#  u'jagged',
#  u'greedy',
#  u'embarrass',
#  u'scary',
#  u'injudicious',
#  u'scars',
#  u'chilly',
#  u'scare',
#  u'straining',
#  u'painful',
#  u'enforcement',
#  u'chagrin',
#  u'bother',
#  u'tortured',
#  u'misunderstand',
#  u'accusing',
#  u'false',
#  u'warily',
#  u'disgustedly',
#  u'hypocrite',
#  u'rough',
#  u'asylum',
#  u'trivial',
#  u'jar',
#  u'bonds',
#  u'prohibition',
#  u'smash',
#  u'contemptible',
#  u'dungeon',
#  u'insulting',
#  u'injustice',
#  u'pistol',
#  u'vanish',
#  u'absentee',
#  u'staring',
#  u'incest',
#  u'accursed',
#  u'implicate',
#  u'outsider',
#  u'waste',
#  u'sourly',
#  u'lush',
#  u'excessively',
#  u'lunatic',
#  u'ransom',
#  u'glaring',
#  u'hangman',
#  u'dust',
#  u'bothering',
#  u'negligence',
#  u'pompous',
#  u'trample',
#  u'arrest',
#  u'complicity',
#  u'taunt',
#  u'crisp',
#  u'flickering',
#  u'warned',
#  u'inexperienced',
#  u'thief',
#  u'hissing',
#  u'humming',
#  u'disbelief',
#  u'avoid',
#  u'pressure',
#  u'coldly',
#  u'blackness',
#  u'tiny',
#  u'crooked',
#  u'mere',
#  u'shyness',
#  u'grate',
#  u'soreness',
#  u'problem',
#  u'gossip',
#  u'reckless',
#  u'prying',
#  u'frightfully',
#  u'reprovingly',
#  u'mercenary',
#  u'suicidal',
#  u'copy',
#  u'defraud',
#  u'daze',
#  u'wildcat',
#  u'bewildered',
#  u'exaggerate',
#  u'pinch',
#  u'nigger',
#  u'decadence',
#  u'foolishness',
#  u'smoke',
#  u'lonesome',
#  u'angrily',
#  u'plot',
#  u'divorced',
#  u'worn',
#  u'quivering',
#  u'heartless',
#  u'indifferent',
#  u'agony',
#  u'resignation',
#  u'fever',
#  u'lax',
#  u'complacent',
#  u'elusive',
#  u'hasty',
#  u'greed',
#  u'versus',
#  u'break',
#  u'bang',
#  u'rocky',
#  u'gallows',
#  u'dumping',
#  u'mangled',
#  u'whining',
#  u'hooked',
#  u'remorse',
#  u'mourning',
#  u'maniac',
#  u'louse',
#  u'lousy',
#  u'disuse',
#  u'oppose',
#  u'vibrated',
#  u'hearse',
#  u'john',
#  u'damaging',
#  u'offhand',
#  u'wasted',
#  u'guilt',
#  u'devious',
#  u'failing',
#  u'stalls',
#  u'forced',
#  u'hesitation',
#  u'grave',
#  u'peevish',
#  u'latent',
#  u'painfully',
#  u'unfair',
#  u'frowning',
#  u'nasty',
#  u'miserably',
#  u'damnation',
#  u'miserable',
#  u'diffidence',
#  u'brat',
#  u'steep',
#  u'ill',
#  u'hopelessness',
#  u'spear',
#  u'conviction',
#  u'abrupt',
#  u'moan',
#  u'mistake',
#  u'terribly',
#  u'stink',
#  u'dumped',
#  u'sting',
#  u'dizzy',
#  u'raid',
#  u'fuss',
#  u'hang',
#  u'evil',
#  u'indefinitely',
#  u'humble',
#  u'ragged',
#  u'victim',
#  u'bastards',
#  u'retreat',
#  u'starvation',
#  u'pugnacious',
#  u'bore',
#  u'confusing',
#  u'unavoidable',
#  u'communist',
#  u'denied',
#  u'beating',
#  u'pose',
#  u'wasting',
#  u'bound',
#  u'prisoner',
#  u'lewd',
#  u'stumble',
#  u'wan',
#  u'fight',
#  u'war',
#  u'lowest',
#  u'sagging',
#  u'mysterious',
#  u'absent',
#  u'wretched',
#  u'dying',
#  u'stake',
#  u'unwilling',
#  u'cheated',
#  u'phlegm',
#  u'indecently',
#  u'battle',
#  u'disdainful',
#  u'flash',
#  u'dissatisfied',
#  u'terror',
#  u'grill',
#  u'derisive',
#  u'anonymous',
#  u'trouble',
#  u'blast',
#  u'feeble',
#  u'steeply',
#  u'gun',
#  u'perplexity',
#  u'curse',
#  u'ineffectual',
#  u'explosion',
#  u'impatiently',
#  u'trial',
#  u'uphill',
#  u'embarrassing',
#  u'terminal',
#  u'unimpressed',
#  u'dubiously',
#  u'malevolence',
#  u'cranky',
#  u'disgusted',
#  u'vomited',
#  u'crept',
#  u'batty',
#  u'crumple',
#  u'cold',
#  u'trifle',
#  u'servant',
#  u'hurried',
#  u'challenge',
#  u'belligerence',
#  u'hastily',
#  u'tangles',
#  u'tangled',
#  u'blind',
#  u'jealousy',
#  u'impossible',
#  u'sheer',
#  u'callous',
#  u'grasping',
#  u'tragic',
#  u'dinky',
#  u'crack',
#  u'slap',
#  u'slam',
#  u'distorted',
#  u'anger',
#  u'lumpy',
#  u'fate',
#  u'failure',
#  u'jolt',
#  u'stain',
#  u'shrill',
#  u'imbecile',
#  u'soot',
#  u'recalcitrant',
#  u'concern',
#  u'blame',
#  u'hurts',
#  u'reluctantly',
#  u'sadly',
#  u'liberal',
#  u'punished',
#  u'wounds',
#  u'trick',
#  u'implacable',
#  u'soil',
#  u'bestial',
#  u'worry',
#  u'complained',
#  u'traps',
#  u'severe',
#  u'vomit',
#  u'death',
#  u'senseless',
#  u'desecrate',
#  u'struck',
#  u'frown',
#  u'execution',
#  u'rear',
#  u'futilely',
#  u'exposed',
#  u'hemorrhage',
#  u'squirm',
#  u'throb',
#  u'strained',
#  u'uneasy',
#  u'throw',
#  u'creaking',
#  u'chop',
#  u'protests',
#  u'stuttered',
#  u'low',
#  u'drains',
#  u'trying',
#  u'fraud',
#  u'sadness',
#  u'gambling',
#  u'poor',
#  u'apathy',
#  u'dreadful',
#  u'horror',
#  u'punish',
#  u'throbbing',
#  u'inert',
#  u'darkness',
#  u'lurch',
#  u'skid',
#  u'loose',
#  u'excess',
#  u'creeps',
#  u'losses',
#  u'whine',
#  u'creepy',
#  u'hogs',
#  u'chunky',
#  u'ash',
#  u'injury',
#  u'lowering',
#  u'excuse',
#  u'broke',
#  u'pretense',
#  u'offended',
#  u'stinging',
#  u'hampered',
#  u'gash',
#  u'rude',
#  u'sneak',
#  u'gasp',
#  u'crafty',
#  u'hell',
#  u'reluctance',
#  u'absence',
#  u'fool',
#  u'din',
#  u'desperately',
#  u'predatory',
#  u'restless',
#  u'conflicting',
#  u'blundering',
#  u'issue',
#  u'ass',
#  u'dirt',
#  u'soak',
#  u'terrible',
#  u'blush',
#  u'unexpected',
#  u'craps',
#  u'miss',
#  u'insignificant',
#  u'storm',
#  u'boredom',
#  u'blindly',
#  u'squeaky',
#  u'impersonal',
#  u'sty',
#  u'urgently',
#  u'sensual',
#  u'lie',
#  u'adrift',
#  u'trance',
#  u'trapped',
#  u'useless',
#  u'plunder',
#  u'viciously',
#  u'unreasonable',
#  u'humid',
#  u'distressing',
#  u'stubbornness',
#  u'less',
#  u'flighty',
#  u'suspect',
#  u'porcupine',
#  u'shanghai',
#  u'pretending',
#  u'poisoned',
#  u'cramp',
#  u'disapproving',
#  u'close',
#  u'revolution',
#  u'horrid',
#  u'unconscious',
#  u'missing',
#  u'timidly',
#  u'abruptly',
#  u'gaunt',
#  u'forgotten',
#  u'battery',
#  u'whatever',
#  u'wearily',
#  u'damn',
#  u'coarse',
#  u'threaten',
#  u'mockingly',
#  u'empty',
#  u'soiled',
#  u'dusty',
#  u'endanger',
#  u'loot',
#  u'snappishly',
#  u'discredit',
#  u'madly',
#  u'docked',
#  u'obviously',
#  u'uproariously',
#  u'cave',
#  u'cocky',
#  u'game',
#  u'parade',
#  u'urgent',
#  u'savage',
#  u'inconvenience',
#  u'stew',
#  u'gnome',
#  u'nonsense',
#  u'drain',
#  u'smelly',
#  u'smells',
#  u'frost',
#  u'hail',
#  u'dull',
#  u'wicked',
#  u'nab',
#  u'sullen',
#  u'dashed',
#  u'fears',
#  u'crouching',
#  u'pretended',
#  u'drag',
#  u'bribe',
#  u'ignorant',
#  u'arid',
#  u'shack',
#  u'murderous',
#  u'nausea',
#  u'stiff',
#  u'booze',
#  u'enforce',
#  u'punishing',
#  u'poke',
#  u'tribunal',
#  u'rotten',
#  u'upsetting',
#  u'gent',
#  u'danger',
#  u'cloud',
#  u'penalty',
#  u'crap',
#  u'remains',
#  u'hardened',
#  u'whisky',
#  u'fearsome',
#  u'boasting',
#  u'neurotic',
#  u'disgusting',
#  u'brittle',
#  u'scornfully',
#  u'sardonically',
#  u'shaking',
#  u'confess',
#  u'sneer',
#  u'hostile',
#  u'diminished',
#  u'bitch',
#  u'attack',
#  u'beg',
#  u'sardonic',
#  u'need',
#  u'screw',
#  u'bastard',
#  u'demise',
#  u'disagreeably',
#  u'upset',
#  u'scrambled',
#  u'halting',
#  u'unfinished',
#  u'doubting',
#  u'shy',
#  u'dangerous',
#  u'accuses',
#  u'orphan',
#  u'desperate',
#  u'nightmare',
#  u'horrible',
#  u'sabotage',
#  u'interfere',
#  u'limits',
#  u'quit',
#  u'slowly',
#  u'treat',
#  u'expenditure',
#  u'debtor',
#  u'capture',
#  u'shooting',
#  u'strange',
#  u'fanatics',
#  u'sagged',
#  u'steals',
#  u'destruction',
#  u'mistaken',
#  u'mistakes',
#  u'indignation',
#  u'kick',
#  u'crushed',
#  u'livid',
#  u'burden',
#  u'immediately',
#  u'loss',
#  u'lost',
#  u'lose',
#  u'shed',
#  u'glare',
#  u'leery',
#  u'helplessness',
#  u'grinding',
#  u'imperfectly',
#  u'prohibited',
#  u'arrogantly',
#  u'secretive',
#  u'accused',
#  u'lagged',
#  u'overflow',
#  u'cruel',
#  u'reservations',
#  u'upsets',
#  u'twist',
#  u'rumors',
#  u'crummy',
#  u'suspiciously',
#  u'stab',
#  u'doggedly',
#  u'dripped',
#  u'unsteadily',
#  u'protest',
#  u'sorry',
#  u'smack',
#  u'stolen',
#  u'frozen',
#  u'force',
#  u'subordinate',
#  u'kidnap',
#  u'wreck',
#  u'hazy',
#  u'smudge',
#  u'hunch',
#  u'wary',
#  u'expose',
#  u'whack',
#  u'punk',
#  u'degenerate',
#  u'anguish',
#  u'faults',
#  u'vicious',
#  u'ghastly',
#  u'eavesdropping',
#  u'weakness',
#  u'mistrust',
#  u'interruption',
#  u'revolting',
#  u'revenge',
#  u'struggle',
#  u'mistress',
#  u'greasy',
#  u'loud',
#  u'enraged',
#  u'naughty',
#  u'brutality',
#  u'hood',
#  u'nastiness',
#  u'concussion',
#  u'twisted',
#  u'gambler',
#  u'anxiety',
#  u'cruelly',
#  u'bitterness',
#  u'louder',
#  u'silly',
#  u'spoiled',
#  u'rattle',
#  u'mind',
#  u'grind',
#  u'impotent',
#  u'mashed',
#  u'alarm',
#  u'impudently',
#  u'scotch',
#  u'uneasiness',
#  u'sneaking',
#  u'resisting',
#  u'debts',
#  u'insinuate',
#  u'hoard',
#  u'patter',
#  u'bar',
#  u'bad',
#  u'rival',
#  u'subject',
#  u'scrap',
#  u'artificial',
#  u'lazy',
#  u'ignorance',
#  u'weary',
#  u'disorderly',
#  u'wheedle',
#  u'government',
#  u'ugly',
#  u'complaint',
#  u'defeated',
#  u'shame',
#  u'growl',
#  u'unfortunate',
#  u'warden',
#  u'jealous',
#  u'weakly',
#  u'sentence',
#  u'vanity',
#  u'unnecessary',
#  u'confront',
#  u'notorious',
#  ...]

# %%
len(chandlerposwords)/float(len(chandlerposwords)+ len(chandlernegwords))
# Out:
# 0.44115853658536586

# %%
Counter(together).most_common()
# Out:
# [(u'got', 1095),
#  (u'ned', 983),
#  (u'went', 963),
#  (u'asked', 939),
#  (u'beaumont', 905),
#  (u'face', 861),
#  (u'spade', 859),
#  (u'one', 846),
#  (u'man', 821),
#  (u'eyes', 778),
#  (u'get', 758),
#  (u'put', 709),
#  (u'door', 692),
#  (u'right', 680),
#  (u'think', 667),
#  (u'hand', 658),
#  (u'came', 639),
#  (u'anything', 630),
#  (u'see', 619),
#  (u'could', 601),
#  (u'told', 592),
#  (u'around', 558),
#  (u'go', 556),
#  (u'looked', 554),
#  (u'well', 551),
#  (u'going', 543),
#  (u'head', 521),
#  (u'room', 485),
#  (u'want', 467),
#  (u'tell', 466),
#  (u'us', 458),
#  (u'time', 452),
#  (u'away', 449),
#  (u'come', 449),
#  (u'voice', 443),
#  (u'let', 442),
#  (u'something', 438),
#  (u'say', 437),
#  (u'took', 432),
#  (u'would', 431),
#  (u'left', 424),
#  (u'nothing', 420),
#  (u'yes', 417),
#  (u'way', 399),
#  (u'made', 398),
#  (u'hands', 392),
#  (u'two', 385),
#  (u'much', 381),
#  (u'enough', 380),
#  (u'make', 372),
#  (u'girl', 361),
#  (u'good', 358),
#  (u'turned', 329),
#  (u'sat', 321),
#  (u'take', 310),
#  (u'night', 310),
#  (u'thought', 309),
#  (u'maybe', 303),
#  (u'killed', 292),
#  (u'mouth', 289),
#  (u'look', 289),
#  (u'madvig', 289),
#  (u'sure', 282),
#  (u'chair', 279),
#  (u'first', 279),
#  (u'stood', 278),
#  (u'street', 278),
#  (u'table', 275),
#  (u'found', 270),
#  (u'give', 270),
#  (u'another', 267),
#  (u'still', 267),
#  (u'side', 264),
#  (u'knew', 263),
#  (u'find', 248),
#  (u'nora', 245),
#  (u'long', 245),
#  (u'opened', 245),
#  (u'police', 238),
#  (u'bed', 238),
#  (u'mr', 238),
#  (u'without', 235),
#  (u'looking', 234),
#  (u'front', 234),
#  (u'mean', 233),
#  (u'shook', 233),
#  (u'lot', 232),
#  (u'saw', 231),
#  (u'mrs', 229),
#  (u'floor', 226),
#  (u'dont', 222),
#  (u'house', 221),
#  (u'boy', 219),
#  (u'dark', 217),
#  (u'behind', 216),
#  (u'three', 216),
#  (u'wanted', 216),
#  (u'half', 215),
#  (u'things', 214),
#  (u'last', 212),
#  (u'five', 212),
#  (u'wynant', 210),
#  (u'talk', 205),
#  (u'keep', 203),
#  (u'held', 198),
#  (u'else', 198),
#  (u'hell', 197),
#  (u'smiled', 197),
#  (u'gave', 197),
#  (u'stopped', 196),
#  (u'might', 196),
#  (u'morning', 195),
#  (u'old', 193),
#  (u'even', 193),
#  (u'seen', 193),
#  (u'paul', 192),
#  (u'help', 189),
#  (u'hat', 188),
#  (u'people', 188),
#  (u'trying', 188),
#  (u'done', 187),
#  (u'leggett', 186),
#  (u'cairo', 186),
#  (u'white', 185),
#  (u'gabrielle', 184),
#  (u'thing', 184),
#  (u'gone', 183),
#  (u'dorothy', 182),
#  (u'though', 180),
#  (u'arm', 179),
#  (u'lips', 178),
#  (u'together', 177),
#  (u'collinson', 177),
#  (u'never', 176),
#  (u'gun', 176),
#  (u'feet', 176),
#  (u'sir', 176),
#  (u'home', 175),
#  (u'laughed', 175),
#  (u'anybody', 175),
#  (u'place', 174),
#  (u'noonan', 170),
#  (u'money', 168),
#  (u'oh', 168),
#  (u'mimi', 167),
#  (u'tried', 166),
#  (u'open', 165),
#  (u'telephone', 165),
#  (u'called', 165),
#  (u'red', 164),
#  (u'ten', 164),
#  (u'small', 162),
#  (u'nodded', 162),
#  (u'far', 162),
#  (u'fat', 161),
#  (u'minutes', 160),
#  (u'except', 159),
#  (u'till', 158),
#  (u'pocket', 157),
#  (u'heard', 157),
#  (u'whisper', 157),
#  (u'guild', 153),
#  (u'began', 152),
#  (u'dead', 152),
#  (u'body', 152),
#  (u'woman', 152),
#  (u'fitzstephan', 151),
#  (u'ask', 150),
#  (u'father', 150),
#  (u'black', 149),
#  (u'spades', 148),
#  (u'saying', 146),
#  (u'moved', 146),
#  (u'car', 145),
#  (u'thats', 144),
#  (u'ought', 144),
#  (u'gutman', 144),
#  (u'better', 144),
#  (u'talking', 144),
#  (u'along', 143),
#  (u'damned', 143),
#  (u'mind', 142),
#  (u'beside', 142),
#  (u'office', 141),
#  (u'holding', 140),
#  (u'brown', 140),
#  (u'men', 140),
#  (u'god', 139),
#  (u'getting', 139),
#  (u'shut', 138),
#  (u'happened', 138),
#  (u'big', 137),
#  (u'nobody', 137),
#  (u'four', 136),
#  (u'rory', 135),
#  (u'corner', 135),
#  (u'macaulay', 134),
#  (u'kind', 134),
#  (u'glass', 132),
#  (u'smile', 132),
#  (u'suppose', 132),
#  (u'willsson', 132),
#  (u'try', 131),
#  (u'paper', 130),
#  (u'desk', 129),
#  (u'end', 128),
#  (u'set', 127),
#  (u'ever', 127),
#  (u'couple', 126),
#  (u'close', 126),
#  (u'hard', 126),
#  (u'didnt', 126),
#  (u'returned', 125),
#  (u'seemed', 125),
#  (u'afternoon', 125),
#  (u'day', 125),
#  (u'brought', 124),
#  (u'miss', 124),
#  (u'towards', 124),
#  (u'coat', 124),
#  (u'ran', 123),
#  (u'stop', 122),
#  (u'henry', 122),
#  (u'coming', 122),
#  (u'hundred', 121),
#  (u'hotel', 120),
#  (u'fingers', 119),
#  (u'past', 119),
#  (u'cigarette', 119),
#  (u'rest', 118),
#  (u'matter', 118),
#  (u'somebody', 117),
#  (u'believe', 117),
#  (u'murder', 117),
#  (u'youre', 117),
#  (u'always', 116),
#  (u'shot', 116),
#  (u'kill', 116),
#  (u'wife', 116),
#  (u'im', 115),
#  (u'across', 115),
#  (u'reno', 115),
#  (u'spoke', 113),
#  (u'later', 113),
#  (u'city', 113),
#  (u'must', 113),
#  (u'really', 112),
#  (u'phone', 112),
#  (u'guess', 111),
#  (u'sent', 111),
#  (u'jeff', 111),
#  (u'story', 111),
#  (u'light', 111),
#  (u'words', 111),
#  (u'pretty', 110),
#  (u'yet', 110),
#  (u'straight', 109),
#  (u'hair', 109),
#  (u'says', 109),
#  (u'afraid', 109),
#  (u'since', 108),
#  (u'picked', 108),
#  (u'show', 108),
#  (u'new', 107),
#  (u'replied', 107),
#  (u'walked', 106),
#  (u'telling', 106),
#  (u'kid', 105),
#  (u'blue', 105),
#  (u'used', 104),
#  (u'nick', 104),
#  (u'thin', 103),
#  (u'window', 103),
#  (u'call', 103),
#  (u'chief', 103),
#  (u'thaler', 102),
#  (u'chance', 102),
#  (u'bad', 102),
#  (u'name', 102),
#  (u'thousand', 101),
#  (u'cigar', 101),
#  (u'leaned', 101),
#  (u'part', 101),
#  (u'business', 100),
#  (u'jack', 100),
#  (u'work', 99),
#  (u'shoulder', 99),
#  (u'alone', 98),
#  (u'years', 98),
#  (u'next', 98),
#  (u'drink', 98),
#  (u'sitting', 98),
#  (u'probably', 97),
#  (u'run', 97),
#  (u'tom', 97),
#  (u'inside', 96),
#  (u'young', 96),
#  (u'trouble', 96),
#  (u'remember', 96),
#  (u'yeah', 96),
#  (u'arms', 96),
#  (u'standing', 95),
#  (u'twenty', 95),
#  (u'either', 95),
#  (u'word', 94),
#  (u'thanks', 94),
#  (u'wait', 94),
#  (u'became', 94),
#  (u'kept', 93),
#  (u'pushed', 93),
#  (u'slowly', 93),
#  (u'living', 93),
#  (u'thirty', 93),
#  (u'san', 92),
#  (u'mickey', 92),
#  (u'started', 92),
#  (u'shoulders', 92),
#  (u'hear', 92),
#  (u'teeth', 91),
#  (u'raised', 90),
#  (u'son', 90),
#  (u'dinah', 90),
#  (u'dundy', 90),
#  (u'oshaughnessy', 89),
#  (u'frowned', 88),
#  (u'attorney', 88),
#  (u'care', 88),
#  (u'building', 88),
#  (u'step', 88),
#  (u'idea', 88),
#  (u'moment', 88),
#  (u'sort', 88),
#  (u'throat', 88),
#  (u'stand', 88),
#  (u'taylor', 88),
#  (u'hold', 87),
#  (u'foot', 87),
#  (u'everybody', 87),
#  (u'farr', 87),
#  (u'course', 87),
#  (u'clothes', 87),
#  (u'stuff', 86),
#  (u'pistol', 86),
#  (u'stay', 86),
#  (u'making', 86),
#  (u'charles', 86),
#  (u'hello', 85),
#  (u'caught', 85),
#  (u'taken', 85),
#  (u'hour', 85),
#  (u'turn', 85),
#  (u'district', 85),
#  (u'ive', 84),
#  (u'sam', 84),
#  (u'forward', 84),
#  (u'boys', 84),
#  (u'guy', 84),
#  (u'play', 83),
#  (u'job', 83),
#  (u'leave', 82),
#  (u'truth', 82),
#  (u'shad', 82),
#  (u'none', 82),
#  (u'almost', 82),
#  (u'dropped', 82),
#  (u'six', 82),
#  (u'whether', 82),
#  (u'chin', 81),
#  (u'husband', 81),
#  (u'second', 80),
#  (u'letter', 80),
#  (u'dollars', 80),
#  (u'listen', 79),
#  (u'tonight', 79),
#  (u'soon', 79),
#  (u'days', 79),
#  (u'knows', 79),
#  (u'waiting', 79),
#  (u'legs', 78),
#  (u'pulled', 78),
#  (u'ill', 78),
#  (u'blood', 78),
#  (u'tim', 78),
#  (u'senator', 78),
#  (u'best', 77),
#  (u'max', 77),
#  (u'others', 77),
#  (u'overcoat', 77),
#  (u'everything', 77),
#  (u'hurt', 76),
#  (u'wrong', 76),
#  (u'pale', 76),
#  (u'taking', 76),
#  (u'wide', 76),
#  (u'gilbert', 75),
#  (u'steps', 75),
#  (u'francisco', 75),
#  (u'grinned', 75),
#  (u'please', 75),
#  (u'clock', 74),
#  (u'jorgensen', 74),
#  (u'bedroom', 74),
#  (u'thinking', 74),
#  (u'likely', 74),
#  (u'asking', 73),
#  (u'morelli', 73),
#  (u'understand', 73),
#  (u'huh', 73),
#  (u'edge', 73),
#  (u'detective', 72),
#  (u'thursby', 72),
#  (u'lay', 72),
#  (u'green', 72),
#  (u'least', 72),
#  (u'supposed', 72),
#  (u'watch', 72),
#  (u'working', 71),
#  (u'knocked', 71),
#  (u'doorway', 71),
#  (u'ahead', 71),
#  (u'may', 71),
#  (u'killing', 71),
#  (u'road', 71),
#  (u'eye', 71),
#  (u'knees', 70),
#  (u'reason', 70),
#  (u'cotton', 70),
#  (u'round', 70),
#  (u'question', 70),
#  (u'stared', 70),
#  (u'chest', 69),
#  (u'neither', 69),
#  (u'check', 69),
#  (u'apartment', 69),
#  (u'daughter', 68),
#  (u'promised', 68),
#  (u'seem', 68),
#  (u'doctor', 68),
#  (u'cut', 68),
#  (u'named', 68),
#  (u'pick', 68),
#  (u'brother', 68),
#  (u'use', 68),
#  (u'high', 67),
#  (u'meant', 67),
#  (u'empty', 67),
#  (u'exactly', 67),
#  (u'cant', 67),
#  (u'town', 67),
#  (u'top', 67),
#  (u'mother', 67),
#  (u'sofa', 67),
#  (u'lying', 67),
#  (u'nice', 67),
#  (u'followed', 66),
#  (u'mine', 66),
#  (u'swell', 66),
#  (u'wont', 66),
#  (u'read', 66),
#  (u'nose', 66),
#  (u'crossed', 66),
#  (u'sorry', 66),
#  (u'corridor', 66),
#  (u'brigid', 66),
#  (u'forehead', 66),
#  (u'stick', 66),
#  (u'sit', 66),
#  (u'wall', 66),
#  (u'ago', 65),
#  (u'hope', 65),
#  (u'lip', 65),
#  (u'answer', 65),
#  (u'fellow', 65),
#  (u'every', 65),
#  (u'julia', 65),
#  (u'carried', 65),
#  (u'wants', 64),
#  (u'cold', 64),
#  (u'low', 64),
#  (u'finished', 64),
#  (u'janet', 64),
#  (u'closed', 64),
#  (u'brand', 63),
#  (u'handkerchief', 63),
#  (u'cried', 63),
#  (u'life', 62),
#  (u'minute', 62),
#  (u'smiling', 62),
#  (u'thick', 62),
#  (u'death', 62),
#  (u'talked', 62),
#  (u'unless', 62),
#  (u'times', 62),
#  (u'rang', 62),
#  (u'quite', 61),
#  (u'whole', 61),
#  (u'miles', 61),
#  (u'short', 61),
#  (u'grey', 61),
#  (u'yellow', 60),
#  (u'uh', 60),
#  (u'dick', 60),
#  (u'papers', 60),
#  (u'rose', 60),
#  (u'lower', 60),
#  (u'elihu', 59),
#  (u'bell', 59),
#  (u'wrist', 59),
#  (u'piece', 59),
#  (u'whidden', 58),
#  (u'bird', 58),
#  (u'alice', 58),
#  (u'rolff', 58),
#  (u'loose', 58),
#  (u'broke', 58),
#  (u'evening', 58),
#  (u'rolly', 58),
#  (u'running', 58),
#  (u'bit', 58),
#  (u'noise', 58),
#  (u'finger', 58),
#  (u'dozen', 57),
#  (u'fire', 57),
#  (u'envelope', 57),
#  (u'eight', 57),
#  (u'agreed', 57),
#  (u'given', 57),
#  (u'thinks', 56),
#  (u'cairos', 56),
#  (u'hall', 56),
#  (u'whatever', 56),
#  (u'gray', 56),
#  (u'turning', 56),
#  (u'knife', 56),
#  (u'fine', 56),
#  (u'yesterday', 56),
#  (u'glad', 56),
#  (u'jumped', 55),
#  (u'taxicab', 55),
#  (u'kitchen', 55),
#  (u'key', 55),
#  (u'pete', 55),
#  (u'vernon', 55),
#  (u'suggested', 55),
#  (u'tall', 55),
#  (u'late', 55),
#  (u'mathews', 55),
#  (u'water', 55),
#  (u'hit', 55),
#  (u'arrived', 55),
#  (u'showed', 54),
#  (u'bush', 54),
#  (u'sight', 54),
#  (u'lie', 54),
#  (u'less', 54),
#  (u'friends', 54),
#  (u'sound', 54),
#  (u'youve', 54),
#  (u'sleep', 54),
#  (u'theres', 54),
#  (u'blond', 53),
#  (u'certainly', 53),
#  (u'heavy', 53),
#  (u'dull', 53),
#  (u'sheriff', 53),
#  (u'third', 53),
#  (u'felt', 53),
#  (u'fell', 53),
#  (u'neck', 53),
#  (u'forget', 53),
#  (u'presently', 53),
#  (u'plenty', 53),
#  (u'many', 53),
#  (u'questions', 53),
#  (u'breath', 52),
#  (u'send', 52),
#  (u'bent', 52),
#  (u'youll', 52),
#  (u'smoke', 52),
#  (u'wolf', 52),
#  (u'able', 52),
#  (u'anyway', 52),
#  (u'decided', 52),
#  (u'news', 52),
#  (u'faced', 52),
#  (u'known', 52),
#  (u'leaving', 52),
#  (u'york', 52),
#  (u'despain', 51),
#  (u'number', 51),
#  (u'bring', 51),
#  (u'staring', 51),
#  (u'eric', 51),
#  (u'simply', 51),
#  (u'lieutenant', 51),
#  (u'hung', 51),
#  (u'passed', 51),
#  (u'agency', 51),
#  (u'minnie', 50),
#  (u'opal', 50),
#  (u'tone', 50),
#  (u'air', 50),
#  (u'giving', 50),
#  (u'tough', 50),
#  (u'quickly', 50),
#  (u'donald', 50),
#  (u'knowing', 50),
#  (u'happen', 50),
#  (u'love', 49),
#  (u'makes', 49),
#  (u'letters', 49),
#  (u'fifty', 49),
#  (u'learned', 49),
#  (u'addressed', 49),
#  (u'phoned', 49),
#  (u'pink', 49),
#  (u'fall', 49),
#  (u'reached', 49),
#  (u'bathroom', 49),
#  (u'dinner', 49),
#  (u'week', 49),
#  (u'andrews', 49),
#  (u'world', 48),
#  (u'stairs', 48),
#  (u'year', 48),
#  (u'breakfast', 48),
#  (u'comes', 48),
#  (u'met', 48),
#  (u'seven', 48),
#  (u'frightened', 48),
#  (u'stepped', 48),
#  (u'effie', 48),
#  (u'playing', 48),
#  (u'beat', 48),
#  (u'quiet', 48),
#  (u'attention', 48),
#  (u'touched', 47),
#  (u'hes', 47),
#  (u'large', 47),
#  (u'whisky', 47),
#  (u'meet', 47),
#  (u'ear', 47),
#  (u'pockets', 47),
#  (u'seems', 47),
#  (u'suddenly', 47),
#  (u'flat', 47),
#  (u'haldorn', 47),
#  (u'walk', 47),
#  (u'tired', 46),
#  (u'ring', 46),
#  (u'nunheim', 46),
#  (u'hang', 46),
#  (u'clear', 46),
#  (u'need', 46),
#  (u'drew', 46),
#  (u'bar', 46),
#  (u'riese', 46),
#  (u'crazy', 46),
#  (u'pay', 46),
#  (u'putting', 46),
#  (u'trust', 46),
#  (u'book', 46),
#  (u'worked', 45),
#  (u'drank', 45),
#  (u'coffee', 45),
#  (u'club', 45),
#  (u'growled', 45),
#  (u'nearly', 45),
#  (u'facing', 45),
#  (u'difference', 45),
#  (u'fist', 45),
#  (u'point', 45),
#  (u'wish', 45),
#  (u'rather', 45),
#  (u'feel', 45),
#  (u'perhaps', 45),
#  (u'demanded', 44),
#  (u'joseph', 44),
#  (u'newspaper', 44),
#  (u'sense', 44),
#  (u'hesitated', 44),
#  (u'perine', 44),
#  (u'silly', 44),
#  (u'fink', 44),
#  (u'case', 44),
#  (u'windows', 44),
#  (u'watching', 44),
#  (u'address', 43),
#  (u'walking', 43),
#  (u'temple', 43),
#  (u'glasses', 43),
#  (u'fact', 43),
#  (u'friend', 43),
#  (u'wouldnt', 43),
#  (u'lights', 43),
#  (u'waited', 43),
#  (u'repeated', 43),
#  (u'avenue', 43),
#  (u'explained', 42),
#  (u'thumb', 42),
#  (u'bright', 42),
#  (u'west', 42),
#  (u'funny', 42),
#  (u'line', 42),
#  (u'near', 42),
#  (u'break', 42),
#  (u'bank', 42),
#  (u'forty', 42),
#  (u'studsy', 42),
#  (u'struck', 42),
#  (u'nine', 42),
#  (u'whose', 42),
#  (u'ivans', 42),
#  (u'hospital', 42),
#  (u'cleared', 42),
#  (u'outside', 42),
#  (u'falcon', 41),
#  (u'tight', 41),
#  (u'full', 41),
#  (u'seeing', 41),
#  (u'aaronia', 41),
#  (u'id', 41),
#  (u'block', 41),
#  (u'bottle', 41),
#  (u'gutmans', 41),
#  (u'willing', 41),
#  (u'soft', 41),
#  (u'christ', 41),
#  (u'shoot', 41),
#  (u'apart', 41),
#  (u'today', 41),
#  (u'expect', 41),
#  (u'cheek', 41),
#  (u'shall', 40),
#  (u'start', 40),
#  (u'sister', 40),
#  (u'somewhere', 40),
#  (u'manner', 40),
#  (u'months', 40),
#  (u'immediately', 40),
#  (u'dear', 40),
#  (u'finally', 40),
#  (u'downstairs', 40),
#  (u'bill', 40),
#  (u'scowled', 40),
#  (u'dan', 40),
#  (u'hours', 39),
#  (u'information', 39),
#  (u'upstairs', 39),
#  (u'jerry', 39),
#  (u'evidence', 39),
#  (u'drove', 39),
#  (u'trick', 39),
#  (u'youd', 39),
#  (u'liked', 39),
#  (u'damn', 39),
#  (u'luck', 39),
#  (u'moving', 39),
#  (u'softly', 39),
#  (u'bullet', 39),
#  (u'macswain', 38),
#  (u'lowered', 38),
#  (u'spread', 38),
#  (u'means', 38),
#  (u'drop', 38),
#  (u'twisted', 38),
#  (u'paid', 38),
#  (u'whispered', 38),
#  (u'already', 38),
#  (u'blew', 37),
#  (u'square', 37),
#  (u'besides', 37),
#  (u'blocks', 37),
#  (u'interested', 37),
#  (u'change', 37),
#  (u'tomorrow', 37),
#  (u'touch', 37),
#  (u'family', 37),
#  (u'wasnt', 37),
#  (u'lost', 37),
#  (u'dog', 37),
#  (u'diamonds', 37),
#  (u'lawyer', 37),
#  (u'fun', 37),
#  (u'sighed', 37),
#  (u'breathing', 37),
#  (u'busy', 36),
#  (u'easy', 36),
#  (u'wet', 36),
#  (u'quinn', 36),
#  (u'ground', 36),
#  (u'upton', 36),
#  (u'toward', 36),
#  (u'gesture', 36),
#  (u'broad', 36),
#  (u'patted', 36),
#  (u'pointed', 36),
#  (u'letting', 36),
#  (u'jerked', 36),
#  (u'havent', 36),
#  (u'mustache', 36),
#  (u'haired', 36),
#  (u'insisted', 36),
#  (u'women', 36),
#  (u'tch', 36),
#  (u'fair', 35),
#  (u'spot', 35),
#  (u'mans', 35),
#  (u'carefully', 35),
#  (u'fifteen', 35),
#  (u'lifted', 35),
#  (u'secretary', 35),
#  (u'worry', 35),
#  (u'early', 35),
#  (u'hurry', 35),
#  (u'cheeks', 35),
#  (u'bet', 35),
#  (u'shooting', 35),
#  (u'party', 35),
#  (u'important', 35),
#  (u'yard', 35),
#  (u'dressed', 35),
#  (u'path', 35),
#  (u'figure', 35),
#  (u'level', 35),
#  (u'looks', 35),
#  (u'gets', 35),
#  (u'assured', 34),
#  (u'child', 34),
#  (u'surprised', 34),
#  (u'flesh', 34),
#  (u'rooms', 34),
#  (u'worth', 34),
#  (u'safe', 34),
#  (u'elevator', 34),
#  (u'speak', 34),
#  (u'somewhat', 34),
#  (u'shake', 34),
#  (u'eyed', 34),
#  (u'laugh', 34),
#  (u'personville', 34),
#  (u'quesada', 34),
#  (u'tip', 34),
#  (u'lobby', 34),
#  (u'hot', 33),
#  (u'exclaimed', 33),
#  (u'aside', 33),
#  (u'person', 33),
#  (u'sharply', 33),
#  (u'led', 33),
#  (u'mamma', 33),
#  (u'complained', 33),
#  (u'strong', 33),
#  (u'ready', 33),
#  (u'seat', 33),
#  (u'excited', 33),
#  (u'changed', 33),
#  (u'longer', 33),
#  (u'wilmer', 33),
#  (u'chances', 33),
#  (u'murdered', 33),
#  (u'locked', 32),
#  (u'wooden', 32),
#  (u'date', 32),
#  (u'keeping', 32),
#  (u'learn', 32),
#  (u'also', 32),
#  (u'great', 32),
#  (u'jaw', 32),
#  (u'frame', 32),
#  (u'live', 32),
#  (u'store', 32),
#  (u'save', 32),
#  (u'box', 32),
#  (u'mad', 32),
#  (u'shoes', 32),
#  (u'deep', 32),
#  (u'dollar', 32),
#  (u'center', 32),
#  (u'twice', 32),
#  (u'catch', 32),
#  (u'ice', 32),
#  (u'polhaus', 32),
#  (u'rubbed', 32),
#  (u'interrupted', 32),
#  (u'dope', 32),
#  (u'clyde', 32),
#  (u'hanging', 31),
#  (u'hole', 31),
#  (u'boat', 31),
#  (u'move', 31),
#  (u'apparently', 31),
#  (u'true', 31),
#  (u'game', 31),
#  (u'become', 31),
#  (u'silence', 31),
#  (u'ordered', 31),
#  (u'hiding', 31),
#  (u'feeney', 31),
#  (u'tongue', 31),
#  (u'ears', 31),
#  (u'interest', 31),
#  (u'settled', 31),
#  (u'drawer', 31),
#  (u'waiter', 31),
#  (u'sharp', 31),
#  (u'fixed', 31),
#  (u'kicked', 31),
#  (u'color', 31),
#  (u'knob', 31),
#  (u'promise', 31),
#  (u'fit', 30),
#  (u'silver', 30),
#  (u'believed', 30),
#  (u'dressing', 30),
#  (u'sidewise', 30),
#  (u'inches', 30),
#  (u'shrugged', 30),
#  (u'listened', 30),
#  (u'fight', 30),
#  (u'actually', 30),
#  (u'fool', 30),
#  (u'girls', 30),
#  (u'sake', 30),
#  (u'middle', 30),
#  (u'narrow', 30),
#  (u'lines', 30),
#  (u'watched', 30),
#  (u'court', 30),
#  (u'bottom', 29),
#  (u'coppers', 29),
#  (u'alley', 29),
#  (u'dress', 29),
#  (u'sometimes', 29),
#  (u'jesus', 29),
#  (u'newspapers', 29),
#  (u'polite', 29),
#  (u'showing', 29),
#  (u'shiny', 29),
#  (u'eyebrows', 29),
#  (u'thank', 29),
#  (u'reading', 29),
#  (u'dough', 29),
#  (u'beginning', 29),
#  (u'bernie', 29),
#  (u'account', 29),
#  (u'nail', 29),
#  (u'stuck', 29),
#  (u'gin', 29),
#  (u'covered', 29),
#  (u'married', 29),
#  (u'ate', 28),
#  (u'feeling', 28),
#  (u'played', 28),
#  (u'burning', 28),
#  (u'nurse', 28),
#  (u'carrying', 28),
#  (u'detectives', 28),
#  (u'lew', 28),
#  (u'albury', 28),
#  (u'thoughtfully', 28),
#  (u'linehan', 28),
#  (u'clean', 28),
#  (u'within', 28),
#  (u'helped', 28),
#  (u'following', 28),
#  (u'archer', 28),
#  (u'joint', 28),
#  (u'shes', 28),
#  (u'filled', 28),
#  (u'spent', 28),
#  (u'buy', 28),
#  (u'wise', 28),
#  (u'election', 28),
#  (u'jacobi', 28),
#  (u'hill', 28),
#  (u'statement', 28),
#  (u'wrote', 28),
#  (u'deputy', 28),
#  (u'collar', 28),
#  (u'drunk', 28),
#  (u'sick', 28),
#  (u'bomb', 27),
#  (u'rolled', 27),
#  (u'hunting', 27),
#  (u'pressed', 27),
#  (u'leaning', 27),
#  (u'straightened', 27),
#  (u'rode', 27),
#  (u'ends', 27),
#  (u'chairs', 27),
#  (u'smooth', 27),
#  (u'elbow', 27),
#  (u'order', 27),
#  (u'upper', 27),
#  (u'food', 27),
#  (u'county', 27),
#  (u'dawn', 27),
#  (u'died', 27),
#  (u'skin', 27),
#  ...]

# %%
completeposwords = []
completenegwords = []
for i in together:
    if i in poswords:
        completeposwords.append(i)
    elif i in negwords:
        completenegwords.append(i)

# %%
len(completeposwords), len(completenegwords)
# Out:
# (19735, 17075)

# %%
Counter(completeposwords).most_common()
# Out:
# [(u'right', 680),
#  (u'hand', 658),
#  (u'well', 551),
#  (u'want', 467),
#  (u'yes', 417),
#  (u'enough', 380),
#  (u'make', 372),
#  (u'good', 358),
#  (u'sure', 282),
#  (u'stood', 278),
#  (u'give', 270),
#  (u'found', 270),
#  (u'police', 238),
#  (u'talk', 205),
#  (u'might', 196),
#  (u'even', 193),
#  (u'help', 189),
#  (u'white', 185),
#  (u'sir', 176),
#  (u'home', 175),
#  (u'money', 168),
#  (u'open', 165),
#  (u'better', 144),
#  (u'god', 139),
#  (u'kind', 134),
#  (u'smile', 132),
#  (u'matter', 118),
#  (u'rest', 118),
#  (u'light', 111),
#  (u'pretty', 110),
#  (u'straight', 109),
#  (u'kid', 105),
#  (u'call', 103),
#  (u'work', 99),
#  (u'shoulder', 99),
#  (u'young', 96),
#  (u'standing', 95),
#  (u'word', 94),
#  (u'attorney', 88),
#  (u'care', 88),
#  (u'stand', 88),
#  (u'building', 88),
#  (u'forward', 84),
#  (u'job', 83),
#  (u'truth', 82),
#  (u'best', 77),
#  (u'wide', 76),
#  (u'please', 75),
#  (u'understand', 73),
#  (u'green', 72),
#  (u'working', 71),
#  (u'ahead', 71),
#  (u'eye', 71),
#  (u'round', 70),
#  (u'reason', 70),
#  (u'question', 70),
#  (u'daughter', 68),
#  (u'promised', 68),
#  (u'brother', 68),
#  (u'pick', 68),
#  (u'doctor', 68),
#  (u'top', 67),
#  (u'nice', 67),
#  (u'hope', 65),
#  (u'fellow', 65),
#  (u'smiling', 62),
#  (u'agreed', 57),
#  (u'glad', 56),
#  (u'fine', 56),
#  (u'sound', 54),
#  (u'friends', 54),
#  (u'plenty', 53),
#  (u'able', 52),
#  (u'giving', 50),
#  (u'knowing', 50),
#  (u'dinner', 49),
#  (u'love', 49),
#  (u'learned', 49),
#  (u'breakfast', 48),
#  (u'quiet', 48),
#  (u'attention', 48),
#  (u'large', 47),
#  (u'meet', 47),
#  (u'trust', 46),
#  (u'pay', 46),
#  (u'clear', 46),
#  (u'worked', 45),
#  (u'wish', 45),
#  (u'sense', 44),
#  (u'friend', 43),
#  (u'cleared', 42),
#  (u'bright', 42),
#  (u'full', 41),
#  (u'expect', 41),
#  (u'willing', 41),
#  (u'soft', 41),
#  (u'dear', 40),
#  (u'finally', 40),
#  (u'luck', 39),
#  (u'information', 39),
#  (u'liked', 39),
#  (u'moving', 39),
#  (u'interested', 37),
#  (u'fun', 37),
#  (u'easy', 36),
#  (u'broad', 36),
#  (u'important', 35),
#  (u'level', 35),
#  (u'carefully', 35),
#  (u'fair', 35),
#  (u'worth', 34),
#  (u'safe', 34),
#  (u'assured', 34),
#  (u'child', 34),
#  (u'laugh', 34),
#  (u'hot', 33),
#  (u'strong', 33),
#  (u'ready', 33),
#  (u'excited', 33),
#  (u'led', 33),
#  (u'save', 32),
#  (u'live', 32),
#  (u'learn', 32),
#  (u'store', 32),
#  (u'great', 32),
#  (u'center', 32),
#  (u'interest', 31),
#  (u'true', 31),
#  (u'sharp', 31),
#  (u'promise', 31),
#  (u'fit', 30),
#  (u'court', 30),
#  (u'polite', 29),
#  (u'thank', 29),
#  (u'reading', 29),
#  (u'shiny', 29),
#  (u'thoughtfully', 28),
#  (u'nurse', 28),
#  (u'statement', 28),
#  (u'clean', 28),
#  (u'helped', 28),
#  (u'buy', 28),
#  (u'wise', 28),
#  (u'order', 27),
#  (u'dawn', 27),
#  (u'food', 27),
#  (u'youth', 27),
#  (u'smooth', 27),
#  (u'darling', 26),
#  (u'suit', 26),
#  (u'earnestly', 26),
#  (u'eat', 26),
#  (u'honest', 25),
#  (u'real', 25),
#  (u'usual', 25),
#  (u'marshal', 24),
#  (u'company', 24),
#  (u'sweet', 24),
#  (u'lead', 24),
#  (u'lighter', 23),
#  (u'grin', 23),
#  (u'pull', 23),
#  (u'shape', 23),
#  (u'helping', 23),
#  (u'marry', 23),
#  (u'completely', 23),
#  (u'surprise', 22),
#  (u'happy', 22),
#  (u'king', 22),
#  (u'pleasantly', 22),
#  (u'necessary', 22),
#  (u'warm', 21),
#  (u'visit', 21),
#  (u'especially', 21),
#  (u'gold', 21),
#  (u'grand', 21),
#  (u'fast', 21),
#  (u'present', 21),
#  (u'reasonable', 20),
#  (u'free', 20),
#  (u'laughing', 20),
#  (u'joined', 20),
#  (u'likes', 20),
#  (u'win', 20),
#  (u'surely', 20),
#  (u'comfortable', 20),
#  (u'count', 20),
#  (u'angel', 19),
#  (u'innocent', 19),
#  (u'wonder', 19),
#  (u'return', 19),
#  (u'pleasant', 19),
#  (u'silk', 19),
#  (u'alive', 19),
#  (u'baby', 19),
#  (u'special', 19),
#  (u'admit', 19),
#  (u'plain', 19),
#  (u'works', 19),
#  (u'naturally', 19),
#  (u'excitement', 19),
#  (u'captain', 18),
#  (u'curiosity', 18),
#  (u'law', 18),
#  (u'fairly', 18),
#  (u'deal', 18),
#  (u'younger', 18),
#  (u'careful', 18),
#  (u'cash', 18),
#  (u'easily', 18),
#  (u'fresh', 18),
#  (u'friendly', 18),
#  (u'knowledge', 18),
#  (u'facts', 17),
#  (u'prove', 17),
#  (u'steady', 17),
#  (u'intended', 17),
#  (u'clearly', 17),
#  (u'persuade', 16),
#  (u'satisfied', 16),
#  (u'responsible', 16),
#  (u'aunt', 16),
#  (u'driven', 16),
#  (u'slender', 16),
#  (u'solid', 16),
#  (u'understood', 16),
#  (u'jump', 16),
#  (u'manage', 16),
#  (u'smart', 16),
#  (u'lean', 16),
#  (u'speech', 15),
#  (u'focus', 15),
#  (u'marked', 15),
#  (u'complete', 15),
#  (u'curiously', 15),
#  (u'general', 15),
#  (u'pass', 15),
#  (u'advice', 15),
#  (u'tender', 15),
#  (u'honestly', 15),
#  (u'sleek', 14),
#  (u'herald', 14),
#  (u'iron', 14),
#  (u'explain', 14),
#  (u'offer', 14),
#  (u'interesting', 14),
#  (u'rock', 14),
#  (u'drive', 14),
#  (u'enthusiasm', 14),
#  (u'diamond', 14),
#  (u'proctor', 14),
#  (u'confidence', 14),
#  (u'advanced', 14),
#  (u'tree', 13),
#  (u'human', 13),
#  (u'laughter', 13),
#  (u'succeeded', 13),
#  (u'brains', 13),
#  (u'gleam', 13),
#  (u'forgive', 13),
#  (u'defense', 13),
#  (u'simple', 13),
#  (u'dame', 13),
#  (u'rosy', 13),
#  (u'train', 13),
#  (u'slim', 13),
#  (u'value', 13),
#  (u'stirring', 13),
#  (u'genuine', 12),
#  (u'nicely', 12),
#  (u'beer', 12),
#  (u'lovely', 12),
#  (u'neat', 12),
#  (u'trusted', 12),
#  (u'advantage', 12),
#  (u'entrance', 12),
#  (u'natural', 12),
#  (u'amusement', 12),
#  (u'sane', 12),
#  (u'beautiful', 12),
#  (u'dream', 12),
#  (u'leading', 12),
#  (u'motive', 12),
#  (u'cautiously', 12),
#  (u'peace', 12),
#  (u'evenly', 12),
#  (u'perfectly', 12),
#  (u'merry', 12),
#  (u'holy', 11),
#  (u'positively', 11),
#  (u'glow', 11),
#  (u'desire', 11),
#  (u'policeman', 11),
#  (u'safety', 11),
#  (u'silent', 11),
#  (u'amused', 11),
#  (u'fully', 11),
#  (u'electric', 11),
#  (u'prepared', 11),
#  (u'comfortably', 11),
#  (u'beam', 11),
#  (u'importance', 11),
#  (u'partner', 11),
#  (u'swear', 11),
#  (u'pool', 11),
#  (u'easier', 10),
#  (u'eagerly', 10),
#  (u'balance', 10),
#  (u'humor', 10),
#  (u'dance', 10),
#  (u'pillow', 10),
#  (u'merrily', 10),
#  (u'bargain', 10),
#  (u'earnest', 10),
#  (u'freed', 10),
#  (u'hire', 10),
#  (u'cove', 10),
#  (u'action', 10),
#  (u'committed', 10),
#  (u'marriage', 10),
#  (u'patient', 10),
#  (u'cheerful', 10),
#  (u'including', 10),
#  (u'placid', 10),
#  (u'loved', 10),
#  (u'guts', 10),
#  (u'reasonably', 9),
#  (u'master', 9),
#  (u'happily', 9),
#  (u'flame', 9),
#  (u'strength', 9),
#  (u'notion', 9),
#  (u'radio', 9),
#  (u'gentleman', 9),
#  (u'warmth', 9),
#  (u'musical', 9),
#  (u'board', 9),
#  (u'positive', 9),
#  (u'cab', 9),
#  (u'priestly', 9),
#  (u'normal', 9),
#  (u'definite', 9),
#  (u'engaged', 9),
#  (u'cabinet', 9),
#  (u'casual', 9),
#  (u'public', 9),
#  (u'particular', 9),
#  (u'shrewd', 9),
#  (u'dare', 9),
#  (u'cure', 9),
#  (u'composed', 9),
#  (u'united', 9),
#  (u'planning', 9),
#  (u'lucky', 9),
#  (u'sweetheart', 9),
#  (u'pardon', 8),
#  (u'support', 8),
#  (u'cool', 8),
#  (u'understanding', 8),
#  (u'merriment', 8),
#  (u'afford', 8),
#  (u'heart', 8),
#  (u'profit', 8),
#  (u'upside', 8),
#  (u'upright', 8),
#  (u'believing', 8),
#  (u'assistant', 8),
#  (u'roadster', 8),
#  (u'pacific', 8),
#  (u'rising', 8),
#  (u'handsome', 8),
#  (u'original', 8),
#  (u'landed', 8),
#  (u'relaxed', 8),
#  (u'proposition', 8),
#  (u'kiss', 8),
#  (u'quality', 8),
#  (u'favor', 8),
#  (u'ability', 8),
#  (u'cream', 8),
#  (u'ball', 8),
#  (u'sky', 8),
#  (u'audible', 8),
#  (u'certainty', 8),
#  (u'deliberate', 7),
#  (u'glittering', 7),
#  (u'mayor', 7),
#  (u'amazement', 7),
#  (u'heartily', 7),
#  (u'plush', 7),
#  (u'discovery', 7),
#  (u'received', 7),
#  (u'suggest', 7),
#  (u'opportunity', 7),
#  (u'dreams', 7),
#  (u'nerve', 7),
#  (u'respectable', 7),
#  (u'soup', 7),
#  (u'grow', 7),
#  (u'playful', 7),
#  (u'main', 7),
#  (u'amiable', 7),
#  (u'spare', 7),
#  (u'sensible', 7),
#  (u'apologize', 7),
#  (u'shelter', 7),
#  (u'thoughtful', 7),
#  (u'sun', 7),
#  (u'destination', 7),
#  (u'granted', 7),
#  (u'justice', 7),
#  (u'patiently', 7),
#  (u'persuasive', 7),
#  (u'sing', 7),
#  (u'pleased', 7),
#  (u'jam', 7),
#  (u'familiar', 7),
#  (u'assure', 7),
#  (u'grail', 7),
#  (u'sufficient', 7),
#  (u'press', 7),
#  (u'golden', 6),
#  (u'calm', 6),
#  (u'successful', 6),
#  (u'excellent', 6),
#  (u'honey', 6),
#  (u'splendid', 6),
#  (u'communicate', 6),
#  (u'excitedly', 6),
#  (u'coast', 6),
#  (u'delight', 6),
#  (u'presence', 6),
#  (u'flying', 6),
#  (u'nicest', 6),
#  (u'vigorously', 6),
#  (u'mild', 6),
#  (u'remarkably', 6),
#  (u'exact', 6),
#  (u'uniform', 6),
#  (u'extra', 6),
#  (u'discuss', 6),
#  (u'assurance', 6),
#  (u'intuition', 6),
#  (u'inventor', 6),
#  (u'capable', 6),
#  (u'triumphantly', 6),
#  (u'reward', 6),
#  (u'astonishment', 6),
#  (u'legal', 6),
#  (u'practical', 6),
#  (u'agree', 6),
#  (u'consider', 6),
#  (u'experience', 6),
#  (u'readily', 6),
#  (u'share', 6),
#  (u'wonderful', 6),
#  (u'determined', 6),
#  (u'fond', 6),
#  (u'courage', 6),
#  (u'backing', 6),
#  (u'grant', 6),
#  (u'march', 6),
#  (u'mighty', 6),
#  (u'acquaintance', 6),
#  (u'definitely', 6),
#  (u'gaily', 6),
#  (u'degree', 6),
#  (u'apologetic', 6),
#  (u'addresses', 6),
#  (u'wit', 6),
#  (u'customer', 6),
#  (u'beckoned', 6),
#  (u'bodyguard', 6),
#  (u'lover', 6),
#  (u'precious', 6),
#  (u'respect', 6),
#  (u'success', 6),
#  (u'flush', 6),
#  (u'watchman', 6),
#  (u'authority', 6),
#  (u'shining', 5),
#  (u'orchestra', 5),
#  (u'protection', 5),
#  (u'fitting', 5),
#  (u'visitor', 5),
#  (u'toast', 5),
#  (u'score', 5),
#  (u'consciousness', 5),
#  (u'bold', 5),
#  (u'finely', 5),
#  (u'willingly', 5),
#  (u'journey', 5),
#  (u'faster', 5),
#  (u'leads', 5),
#  (u'choice', 5),
#  (u'join', 5),
#  (u'chocolate', 5),
#  (u'shield', 5),
#  (u'wealthy', 5),
#  (u'hut', 5),
#  (u'urge', 5),
#  (u'professional', 5),
#  (u'jovial', 5),
#  (u'satisfaction', 5),
#  (u'learning', 5),
#  (u'valuable', 5),
#  (u'intimate', 5),
#  (u'politeness', 5),
#  (u'deserve', 5),
#  (u'numbers', 5),
#  (u'pleasure', 5),
#  (u'expert', 5),
#  (u'cleaning', 5),
#  (u'ingratiating', 5),
#  (u'hopes', 5),
#  (u'land', 5),
#  (u'wishes', 5),
#  (u'traveling', 5),
#  (u'nimble', 5),
#  (u'honor', 5),
#  (u'winning', 5),
#  (u'precisely', 5),
#  (u'gentle', 5),
#  (u'dodge', 5),
#  (u'tranquil', 5),
#  (u'watchful', 5),
#  (u'church', 5),
#  (u'library', 5),
#  (u'liking', 5),
#  (u'equally', 5),
#  (u'eagerness', 5),
#  (u'triumph', 4),
#  (u'study', 4),
#  (u'recovery', 4),
#  (u'wink', 4),
#  (u'celebrating', 4),
#  (u'dashing', 4),
#  (u'playfully', 4),
#  (u'mercy', 4),
#  (u'divinity', 4),
#  (u'protect', 4),
#  (u'comprehension', 4),
#  (u'majestic', 4),
#  (u'physician', 4),
#  (u'humbly', 4),
#  (u'yep', 4),
#  (u'ease', 4),
#  (u'bath', 4),
#  (u'muscular', 4),
#  (u'assistance', 4),
#  (u'supporting', 4),
#  (u'sympathetic', 4),
#  (u'effort', 4),
#  (u'pure', 4),
#  (u'sworn', 4),
#  (u'cute', 4),
#  (u'increase', 4),
#  (u'invitation', 4),
#  (u'proving', 4),
#  (u'recover', 4),
#  (u'interior', 4),
#  (u'proud', 4),
#  (u'august', 4),
#  (u'insist', 4),
#  (u'sincere', 4),
#  (u'pad', 4),
#  (u'delicate', 4),
#  (u'justify', 4),
#  (u'satin', 4),
#  (u'sanity', 4),
#  (u'satisfactory', 4),
#  (u'slick', 4),
#  (u'terrified', 4),
#  (u'boldly', 4),
#  (u'fill', 4),
#  (u'candid', 4),
#  (u'distinct', 4),
#  (u'glowing', 4),
#  (u'responsibility', 4),
#  (u'major', 4),
#  (u'build', 4),
#  (u'art', 4),
#  (u'sea', 4),
#  (u'sensitive', 4),
#  (u'supply', 4),
#  (u'consideration', 4),
#  (u'eager', 4),
#  (u'inviting', 4),
#  (u'continue', 4),
#  (u'curious', 4),
#  (u'shine', 4),
#  (u'faith', 4),
#  (u'impressed', 4),
#  (u'considerable', 4),
#  (u'truthfully', 4),
#  (u'nap', 4),
#  (u'compact', 4),
#  (u'exchange', 4),
#  (u'intelligent', 4),
#  (u'greater', 4),
#  (u'sufficiently', 4),
#  (u'soothing', 4),
#  (u'trusting', 4),
#  (u'reform', 4),
#  (u'swift', 4),
#  (u'tremendous', 4),
#  (u'immense', 4),
#  (u'bull', 4),
#  (u'ripe', 4),
#  (u'laurel', 4),
#  (u'happiness', 4),
#  (u'generous', 4),
#  (u'audibly', 4),
#  (u'actual', 4),
#  (u'guard', 4),
#  (u'confident', 4),
#  (u'triumphant', 4),
#  (u'convince', 4),
#  (u'leisurely', 3),
#  (u'enjoy', 3),
#  (u'active', 3),
#  (u'substance', 3),
#  (u'permit', 3),
#  (u'household', 3),
#  (u'swiftness', 3),
#  (u'dignified', 3),
#  (u'beauty', 3),
#  (u'loyalty', 3),
#  (u'modest', 3),
#  (u'president', 3),
#  (u'appreciate', 3),
#  (u'modesty', 3),
#  (u'velvet', 3),
#  (u'unbroken', 3),
#  (u'mirth', 3),
#  (u'orderly', 3),
#  (u'reputation', 3),
#  (u'cushion', 3),
#  (u'confide', 3),
#  (u'inquisitive', 3),
#  (u'gratitude', 3),
#  (u'coherent', 3),
#  (u'aid', 3),
#  (u'patent', 3),
#  (u'contact', 3),
#  (u'candidate', 3),
#  (u'dreamy', 3),
#  (u'gift', 3),
#  (u'delighted', 3),
#  (u'music', 3),
#  (u'satisfactorily', 3),
#  (u'astonished', 3),
#  (u'amusing', 3),
#  (u'counsel', 3),
#  (u'maximum', 3),
#  (u'crystal', 3),
#  (u'scientific', 3),
#  (u'welcome', 3),
#  (u'loyal', 3),
#  (u'remarkable', 3),
#  (u'impressive', 3),
#  (u'brave', 3),
#  (u'tougher', 3),
#  (u'celebrated', 3),
#  (u'prefer', 3),
#  (u'sincerely', 3),
#  (u'goods', 3),
#  (u'easiest', 3),
#  (u'behalf', 3),
#  (u'purr', 3),
#  (u'birthday', 3),
#  (u'tale', 3),
#  (u'chattering', 3),
#  (u'correct', 3),
#  (u'errand', 3),
#  (u'necessarily', 3),
#  (u'glossy', 3),
#  (u'nicer', 3),
#  (u'sunset', 3),
#  (u'precise', 3),
#  (u'uppermost', 3),
#  (u'admiration', 3),
#  (u'infallible', 3),
#  (u'salutation', 3),
#  (u'gaiety', 3),
#  (u'spirit', 3),
#  (u'straighten', 3),
#  (u'statue', 3),
#  (u'relief', 3),
#  (u'notable', 3),
#  (u'exciting', 3),
#  (u'disposed', 3),
#  (u'affection', 3),
#  (u'imagination', 3),
#  (u'religious', 3),
#  (u'ribbon', 3),
#  (u'soldier', 3),
#  (u'toughness', 3),
#  (u'accept', 3),
#  (u'lyre', 3),
#  (u'harmless', 3),
#  (u'fancy', 3),
#  (u'needle', 3),
#  (u'cleaner', 3),
#  (u'significant', 3),
#  (u'permission', 3),
#  (u'sunny', 3),
#  (u'investigate', 3),
#  (u'sex', 3),
#  (u'spirits', 3),
#  (u'available', 3),
#  (u'succeed', 3),
#  (u'improved', 3),
#  (u'gay', 3),
#  (u'guide', 3),
#  (u'task', 3),
#  (u'organization', 3),
#  (u'openly', 3),
#  (u'elect', 3),
#  (u'recommended', 3),
#  (u'logical', 3),
#  (u'marvelous', 3),
#  (u'softness', 3),
#  (u'agreement', 3),
#  (u'properly', 3),
#  (u'genial', 3),
#  (u'expedition', 3),
#  (u'innocence', 3),
#  (u'calmness', 3),
#  (u'smiles', 3),
#  (u'suave', 3),
#  (u'friendliness', 3),
#  (u'playmate', 3),
#  (u'clever', 3),
#  (u'rich', 3),
#  (u'obvious', 3),
#  (u'insistent', 3),
#  (u'polished', 3),
#  (u'perfect', 3),
#  (u'kindness', 3),
#  (u'handy', 3),
#  (u'defend', 3),
#  (u'frank', 3),
#  (u'precaution', 3),
#  (u'finest', 3),
#  (u'bulldog', 3),
#  (u'appealing', 3),
#  (u'assurances', 3),
#  (u'enthusiastic', 3),
#  (u'impression', 3),
#  (u'brighter', 3),
#  (u'hopefully', 3),
#  (u'luminous', 3),
#  (u'routine', 3),
#  (u'progress', 3),
#  (u'approval', 3),
#  (u'labor', 3),
#  (u'speedily', 3),
#  (u'tenderly', 3),
#  (u'rapid', 3),
#  (u'transparent', 3),
#  (u'ample', 3),
#  (u'proper', 3),
#  (u'freedom', 3),
#  (u'female', 3),
#  (u'gain', 3),
#  (u'supreme', 3),
#  (u'mutual', 3),
#  (u'corporation', 3),
#  (u'pride', 2),
#  (u'vastly', 2),
#  (u'prize', 2),
#  (u'fondly', 2),
#  (u'convenience', 2),
#  (u'admiral', 2),
#  (u'hero', 2),
#  (u'humility', 2),
#  (u'credit', 2),
#  (u'suitable', 2),
#  (u'patience', 2),
#  (u'survive', 2),
#  (u'relax', 2),
#  (u'rights', 2),
#  (u'organized', 2),
#  (u'absolute', 2),
#  (u'keen', 2),
#  (u'provide', 2),
#  (u'wins', 2),
#  (u'brightness', 2),
#  (u'recognizable', 2),
#  (u'fellowship', 2),
#  (u'encourage', 2),
#  (u'adjust', 2),
#  (u'associate', 2),
#  (u'modern', 2),
#  (u'convenient', 2),
#  (u'medical', 2),
#  (u'treaty', 2),
#  (u'principle', 2),
#  (u'pope', 2),
#  (u'respectfully', 2),
#  (u'sugar', 2),
#  (u'population', 2),
#  (u'tribute', 2),
#  (u'fascinating', 2),
#  (u'gladness', 2),
#  (u'grandmother', 2),
#  (u'accord', 2),
#  (u'logic', 2),
#  (u'contribution', 2),
#  (u'sunshine', 2),
#  (u'elaborate', 2),
#  (u'confirmed', 2),
#  (u'tops', 2),
#  (u'ownership', 2),
#  (u'practiced', 2),
#  (u'greatest', 2),
#  (u'admiringly', 2),
#  (u'athletic', 2),
#  (u'succeeding', 2),
#  (u'officer', 2),
#  (u'insistence', 2),
#  (u'ensure', 2),
#  (u'thinner', 2),
#  (u'profession', 2),
#  (u'balanced', 2),
#  (u'vitality', 2),
#  (u'powerfully', 2),
#  (u'promises', 2),
#  (u'faithful', 2),
#  (u'soundly', 2),
#  (u'convincing', 2),
#  (u'relieve', 2),
#  (u'rod', 2),
#  (u'devoted', 2),
#  (u'settle', 2),
#  (u'comforting', 2),
#  (u'boost', 2),
#  (u'brilliant', 2),
#  (u'tolerantly', 2),
#  (u'hospitality', 2),
#  (u'wealth', 2),
#  (u'aye', 2),
#  (u'compactly', 2),
#  (u'indescribable', 2),
#  (u'intelligible', 2),
#  (u'discussion', 2),
#  (u'improving', 2),
#  (u'inform', 2),
#  (u'thoughtfulness', 2),
#  (u'qualified', 2),
#  (u'undoubtedly', 2),
#  (u'gigantic', 2),
#  (u'oath', 2),
#  (u'prospect', 2),
#  (u'terrific', 2),
#  (u'neatly', 2),
#  (u'clearer', 2),
#  (u'fore', 2),
#  (u'title', 2),
#  (u'truly', 2),
#  (u'priest', 2),
#  (u'vision', 2),
#  (u'honesty', 2),
#  (u'satisfying', 2),
#  (u'inseparable', 2),
#  (u'peaceful', 2),
#  (u'shopping', 2),
#  (u'minister', 2),
#  (u'prominence', 2),
#  (u'promising', 2),
#  (u'author', 2),
#  (u'preparatory', 2),
#  (u'poetic', 2),
#  (u'noble', 2),
#  (u'assist', 2),
#  (u'companion', 2),
#  (u'constitutional', 2),
#  (u'amazed', 2),
#  (u'gentleness', 2),
#  (u'credentials', 2),
#  (u'fortune', 2),
#  (u'benefit', 2),
#  (u'joking', 2),
#  (u'football', 2),
#  (u'assembly', 2),
#  (u'squarely', 2),
#  (u'fondness', 2),
#  (u'ace', 2),
#  (u'favorite', 2),
#  (u'guiltless', 2),
#  (u'watchdog', 2),
#  (u'stars', 2),
#  (u'rouse', 2),
#  (u'taste', 2),
#  (u'educated', 2),
#  (u'ay', 2),
#  (u'valid', 2),
#  (u'legitimate', 2),
#  (u'attentive', 2),
#  (u'enjoying', 2),
#  (u'heaven', 2),
#  (u'sweetly', 2),
#  (u'exceptionally', 2),
#  (u'establish', 2),
#  (u'teach', 2),
#  (u'composure', 2),
#  (u'comfort', 2),
#  (u'foreseen', 2),
#  (u'ethics', 2),
#  (u'scientist', 2),
#  (u'inquiry', 2),
#  (u'ally', 2),
#  (u'association', 2),
#  (u'sympathy', 2),
#  (u'exquisite', 2),
#  (u'engaging', 2),
#  (u'health', 2),
#  (u'wages', 2),
#  (u'saint', 2),
#  (u'consonant', 2),
#  (u'grace', 2),
#  (u'bride', 2),
#  (u'caress', 2),
#  (u'persuasively', 2),
#  (u'writer', 2),
#  (u'cheaper', 2),
#  (u'famous', 2),
#  (u'perfume', 2),
#  (u'common', 2),
#  (u'courteous', 2),
#  (u'plausible', 2),
#  (u'outward', 2),
#  (u'glistening', 2),
#  (u'candor', 2),
#  (u'premises', 2),
#  (u'whiteness', 2),
#  (u'prospects', 2),
#  (u'protector', 2),
#  (u'approve', 2),
#  (u'manners', 2),
#  (u'community', 2),
#  (u'keystone', 2),
#  (u'determination', 2),
#  (u'utmost', 2),
#  (u'bonus', 2),
#  (u'admission', 2),
#  (u'strongest', 2),
#  (u'twinkle', 2),
#  (u'vivid', 2),
#  (u'cautious', 2),
#  (u'sharper', 2),
#  (u'deserved', 2),
#  (u'caretaker', 2),
#  (u'appropriate', 2),
#  (u'solidity', 2),
#  (u'graceful', 2),
#  (u'divine', 2),
#  (u'depth', 2),
#  (u'aristocrat', 2),
#  (u'masculine', 2),
#  (u'alight', 2),
#  (u'virtuous', 2),
#  (u'agreeable', 2),
#  (u'inclined', 2),
#  (u'gladly', 2),
#  (u'lamb', 2),
#  (u'fortunate', 2),
#  (u'proven', 2),
#  (u'preferring', 2),
#  (u'unhurried', 2),
#  (u'allow', 2),
#  (u'classy', 2),
#  (u'university', 2),
#  (u'delightful', 2),
#  (u'upward', 2),
#  (u'acknowledgment', 2),
#  (u'stud', 2),
#  (u'thriving', 2),
#  (u'stride', 2),
#  (u'softer', 2),
#  (u'plainly', 2),
#  (u'salient', 2),
#  (u'flourish', 2),
#  (u'sultry', 2),
#  (u'heft', 2),
#  (u'accuracy', 2),
#  (u'stronger', 2),
#  (u'achieve', 2),
#  (u'joy', 2),
#  (u'strides', 2),
#  (u'firmness', 2),
#  (u'safely', 2),
#  (u'glorious', 2),
#  (u'flourishing', 2),
#  (u'decent', 2),
#  (u'novel', 2),
#  (u'advisable', 2),
#  (u'optimistic', 2),
#  (u'congratulations', 2),
#  ...]

# %%
Counter(completenegwords).most_common()
# Out:
# [(u'spade', 859),
#  (u'killed', 292),
#  (u'long', 245),
#  (u'mean', 233),
#  (u'boy', 219),
#  (u'dark', 217),
#  (u'hell', 197),
#  (u'trying', 188),
#  (u'gun', 176),
#  (u'small', 162),
#  (u'fat', 161),
#  (u'dead', 152),
#  (u'black', 149),
#  (u'damned', 143),
#  (u'mind', 142),
#  (u'try', 131),
#  (u'hard', 126),
#  (u'close', 126),
#  (u'miss', 124),
#  (u'cigarette', 119),
#  (u'murder', 117),
#  (u'shot', 116),
#  (u'kill', 116),
#  (u'spoke', 113),
#  (u'words', 111),
#  (u'afraid', 109),
#  (u'bad', 102),
#  (u'trouble', 96),
#  (u'wait', 94),
#  (u'slowly', 93),
#  (u'pistol', 86),
#  (u'leave', 82),
#  (u'ill', 78),
#  (u'blood', 78),
#  (u'hurt', 76),
#  (u'wrong', 76),
#  (u'pale', 76),
#  (u'least', 72),
#  (u'supposed', 72),
#  (u'killing', 71),
#  (u'cut', 68),
#  (u'mother', 67),
#  (u'lying', 67),
#  (u'empty', 67),
#  (u'sorry', 66),
#  (u'cold', 64),
#  (u'low', 64),
#  (u'death', 62),
#  (u'dick', 60),
#  (u'lower', 60),
#  (u'loose', 58),
#  (u'broke', 58),
#  (u'noise', 58),
#  (u'knife', 56),
#  (u'whatever', 56),
#  (u'late', 55),
#  (u'hit', 55),
#  (u'lie', 54),
#  (u'less', 54),
#  (u'fell', 53),
#  (u'forget', 53),
#  (u'dull', 53),
#  (u'smoke', 52),
#  (u'bent', 52),
#  (u'hung', 51),
#  (u'staring', 51),
#  (u'tough', 50),
#  (u'fall', 49),
#  (u'frightened', 48),
#  (u'touched', 47),
#  (u'whisky', 47),
#  (u'tired', 46),
#  (u'hang', 46),
#  (u'bar', 46),
#  (u'crazy', 46),
#  (u'need', 46),
#  (u'fist', 45),
#  (u'silly', 44),
#  (u'case', 44),
#  (u'break', 42),
#  (u'thumb', 42),
#  (u'struck', 42),
#  (u'funny', 42),
#  (u'shoot', 41),
#  (u'block', 41),
#  (u'immediately', 40),
#  (u'trick', 39),
#  (u'damn', 39),
#  (u'twisted', 38),
#  (u'lawyer', 37),
#  (u'lost', 37),
#  (u'busy', 36),
#  (u'spot', 35),
#  (u'worry', 35),
#  (u'shooting', 35),
#  (u'shake', 34),
#  (u'complained', 33),
#  (u'sharply', 33),
#  (u'mad', 32),
#  (u'deep', 32),
#  (u'interrupted', 32),
#  (u'dope', 32),
#  (u'hanging', 31),
#  (u'hole', 31),
#  (u'game', 31),
#  (u'fight', 30),
#  (u'narrow', 30),
#  (u'fool', 30),
#  (u'bottom', 29),
#  (u'stuck', 29),
#  (u'feeling', 28),
#  (u'burning', 28),
#  (u'drunk', 28),
#  (u'spent', 28),
#  (u'sick', 28),
#  (u'bomb', 27),
#  (u'died', 27),
#  (u'hunting', 27),
#  (u'weight', 27),
#  (u'racket', 27),
#  (u'protested', 26),
#  (u'curse', 26),
#  (u'angry', 26),
#  (u'throw', 26),
#  (u'stiff', 26),
#  (u'doubt', 26),
#  (u'murderer', 26),
#  (u'row', 25),
#  (u'die', 25),
#  (u'scratched', 25),
#  (u'awfully', 25),
#  (u'blow', 25),
#  (u'cursed', 25),
#  (u'serious', 24),
#  (u'nonsense', 24),
#  (u'bastard', 24),
#  (u'loud', 23),
#  (u'impatiently', 23),
#  (u'torn', 23),
#  (u'worried', 23),
#  (u'gambler', 23),
#  (u'dumb', 23),
#  (u'shaking', 23),
#  (u'rusty', 22),
#  (u'angrily', 22),
#  (u'lousy', 22),
#  (u'suicide', 22),
#  (u'fear', 22),
#  (u'guilty', 22),
#  (u'dirty', 22),
#  (u'worse', 22),
#  (u'crying', 22),
#  (u'bother', 22),
#  (u'wild', 22),
#  (u'scotch', 21),
#  (u'slightly', 21),
#  (u'troubles', 21),
#  (u'mob', 21),
#  (u'poor', 21),
#  (u'dragged', 21),
#  (u'broken', 21),
#  (u'rough', 21),
#  (u'joke', 21),
#  (u'accident', 21),
#  (u'knock', 20),
#  (u'swollen', 20),
#  (u'sap', 20),
#  (u'missed', 20),
#  (u'drinking', 20),
#  (u'lose', 20),
#  (u'frowning', 19),
#  (u'fault', 19),
#  (u'shadow', 19),
#  (u'jail', 19),
#  (u'rear', 19),
#  (u'dagger', 19),
#  (u'irritably', 19),
#  (u'heel', 19),
#  (u'wrinkled', 19),
#  (u'trembling', 19),
#  (u'heavily', 19),
#  (u'hate', 18),
#  (u'escape', 18),
#  (u'seriously', 18),
#  (u'anger', 18),
#  (u'hardly', 18),
#  (u'nervous', 18),
#  (u'barely', 18),
#  (u'pretending', 18),
#  (u'bonds', 18),
#  (u'cross', 18),
#  (u'ragged', 17),
#  (u'blind', 17),
#  (u'blame', 17),
#  (u'terrible', 17),
#  (u'cry', 17),
#  (u'burned', 17),
#  (u'missing', 17),
#  (u'pretended', 17),
#  (u'corpse', 17),
#  (u'dump', 17),
#  (u'fighting', 17),
#  (u'alarm', 16),
#  (u'ugly', 16),
#  (u'wound', 16),
#  (u'lied', 16),
#  (u'crime', 16),
#  (u'stupid', 16),
#  (u'harsh', 16),
#  (u'crumpled', 16),
#  (u'liar', 16),
#  (u'puzzled', 16),
#  (u'darkness', 16),
#  (u'forgotten', 16),
#  (u'wearily', 16),
#  (u'kick', 16),
#  (u'dangerous', 16),
#  (u'hearing', 15),
#  (u'forced', 15),
#  (u'victim', 15),
#  (u'lies', 15),
#  (u'dim', 15),
#  (u'wanting', 15),
#  (u'harry', 15),
#  (u'limp', 15),
#  (u'horrible', 15),
#  (u'muddy', 15),
#  (u'arrest', 15),
#  (u'cracked', 14),
#  (u'split', 14),
#  (u'sentence', 14),
#  (u'prison', 14),
#  (u'losing', 14),
#  (u'suspect', 14),
#  (u'falling', 14),
#  (u'trial', 14),
#  (u'suspicion', 14),
#  (u'rattled', 14),
#  (u'slow', 14),
#  (u'anxious', 14),
#  (u'dirt', 14),
#  (u'ash', 14),
#  (u'suspicious', 14),
#  (u'rid', 14),
#  (u'impatient', 14),
#  (u'danger', 14),
#  (u'bitterly', 14),
#  (u'false', 14),
#  (u'upset', 14),
#  (u'bum', 14),
#  (u'tobacco', 14),
#  (u'screwed', 14),
#  (u'grave', 13),
#  (u'pretend', 13),
#  (u'battered', 13),
#  (u'hastily', 13),
#  (u'ridiculous', 13),
#  (u'shrill', 13),
#  (u'worrying', 13),
#  (u'dying', 13),
#  (u'excuse', 13),
#  (u'divorce', 13),
#  (u'refused', 13),
#  (u'remains', 13),
#  (u'mock', 13),
#  (u'embarrassment', 13),
#  (u'crack', 13),
#  (u'revolver', 12),
#  (u'cult', 12),
#  (u'strike', 12),
#  (u'nasty', 12),
#  (u'mud', 12),
#  (u'jealous', 12),
#  (u'war', 12),
#  (u'hoarse', 12),
#  (u'blurred', 12),
#  (u'calls', 12),
#  (u'gravely', 12),
#  (u'harm', 12),
#  (u'ruin', 12),
#  (u'failed', 12),
#  (u'junk', 12),
#  (u'sullen', 12),
#  (u'utterly', 12),
#  (u'shack', 12),
#  (u'poke', 12),
#  (u'sore', 12),
#  (u'criminal', 12),
#  (u'desperate', 12),
#  (u'scared', 12),
#  (u'hurricane', 12),
#  (u'risk', 11),
#  (u'worn', 11),
#  (u'punk', 11),
#  (u'mistress', 11),
#  (u'sober', 11),
#  (u'spite', 11),
#  (u'mistake', 11),
#  (u'unnecessary', 11),
#  (u'vanished', 11),
#  (u'bloody', 11),
#  (u'sour', 11),
#  (u'disagreeably', 11),
#  (u'careless', 11),
#  (u'hurried', 11),
#  (u'reluctantly', 11),
#  (u'pop', 11),
#  (u'stone', 11),
#  (u'burglar', 11),
#  (u'worst', 11),
#  (u'faint', 11),
#  (u'sneak', 11),
#  (u'difficulty', 11),
#  (u'foolish', 11),
#  (u'rotten', 11),
#  (u'confession', 11),
#  (u'warned', 11),
#  (u'bitch', 11),
#  (u'prisoner', 11),
#  (u'burglary', 11),
#  (u'quit', 11),
#  (u'lord', 10),
#  (u'john', 10),
#  (u'bitter', 10),
#  (u'unpleasant', 10),
#  (u'conceal', 10),
#  (u'darkened', 10),
#  (u'copy', 10),
#  (u'cursing', 10),
#  (u'stumbled', 10),
#  (u'lanky', 10),
#  (u'glaring', 10),
#  (u'nervously', 10),
#  (u'enemy', 10),
#  (u'unconscious', 10),
#  (u'warning', 10),
#  (u'concerned', 10),
#  (u'uncomfortable', 10),
#  (u'coldly', 10),
#  (u'cutting', 10),
#  (u'tense', 10),
#  (u'shed', 10),
#  (u'shabby', 10),
#  (u'pinch', 9),
#  (u'force', 9),
#  (u'hunch', 9),
#  (u'badly', 9),
#  (u'haste', 9),
#  (u'hidden', 9),
#  (u'hooked', 9),
#  (u'weak', 9),
#  (u'wear', 9),
#  (u'fuss', 9),
#  (u'grimace', 9),
#  (u'odor', 9),
#  (u'scornfully', 9),
#  (u'clumsy', 9),
#  (u'scowl', 9),
#  (u'tumbled', 9),
#  (u'guilt', 9),
#  (u'abruptly', 9),
#  (u'devil', 9),
#  (u'stolen', 9),
#  (u'irritable', 9),
#  (u'blackjack', 9),
#  (u'concealed', 9),
#  (u'dragging', 9),
#  (u'watery', 9),
#  (u'bothered', 9),
#  (u'doubtful', 9),
#  (u'indignantly', 9),
#  (u'grab', 9),
#  (u'difficult', 9),
#  (u'crushed', 9),
#  (u'slug', 9),
#  (u'meaningless', 9),
#  (u'twist', 9),
#  (u'foolishness', 8),
#  (u'divorced', 8),
#  (u'mashed', 8),
#  (u'queer', 8),
#  (u'liquor', 8),
#  (u'breaks', 8),
#  (u'convict', 8),
#  (u'burn', 8),
#  (u'bruised', 8),
#  (u'shaky', 8),
#  (u'yawning', 8),
#  (u'tangled', 8),
#  (u'lumpy', 8),
#  (u'blunt', 8),
#  (u'crooked', 8),
#  (u'strain', 8),
#  (u'frown', 8),
#  (u'disappointed', 8),
#  (u'hysterical', 8),
#  (u'awful', 8),
#  (u'disturbed', 8),
#  (u'mystery', 8),
#  (u'ass', 8),
#  (u'fallen', 8),
#  (u'rifle', 8),
#  (u'booze', 8),
#  (u'insane', 8),
#  (u'violently', 8),
#  (u'vague', 8),
#  (u'exaggerated', 8),
#  (u'hatred', 8),
#  (u'downhill', 8),
#  (u'influence', 8),
#  (u'possession', 8),
#  (u'trap', 8),
#  (u'scare', 8),
#  (u'savagely', 8),
#  (u'nuisance', 8),
#  (u'scrambled', 8),
#  (u'yell', 8),
#  (u'muzzle', 7),
#  (u'solemn', 7),
#  (u'poison', 7),
#  (u'mess', 7),
#  (u'gallows', 7),
#  (u'enormous', 7),
#  (u'louse', 7),
#  (u'hopeless', 7),
#  (u'anxiety', 7),
#  (u'spoiled', 7),
#  (u'rat', 7),
#  (u'idiotic', 7),
#  (u'tiny', 7),
#  (u'shame', 7),
#  (u'dizzy', 7),
#  (u'bruise', 7),
#  (u'burnt', 7),
#  (u'bore', 7),
#  (u'enemies', 7),
#  (u'blackmail', 7),
#  (u'puzzle', 7),
#  (u'grief', 7),
#  (u'jerk', 7),
#  (u'merely', 7),
#  (u'filthy', 7),
#  (u'drunken', 7),
#  (u'buried', 7),
#  (u'pain', 7),
#  (u'horribly', 7),
#  (u'cheap', 7),
#  (u'mocking', 7),
#  (u'uneasy', 7),
#  (u'rage', 7),
#  (u'backward', 7),
#  (u'sunk', 7),
#  (u'desperately', 7),
#  (u'childish', 7),
#  (u'headache', 7),
#  (u'useless', 7),
#  (u'serve', 7),
#  (u'gaby', 7),
#  (u'timid', 7),
#  (u'hated', 7),
#  (u'spook', 7),
#  (u'bleeding', 7),
#  (u'sink', 7),
#  (u'crap', 7),
#  (u'noises', 7),
#  (u'panic', 7),
#  (u'furious', 7),
#  (u'backwards', 7),
#  (u'alarmed', 7),
#  (u'utter', 7),
#  (u'accused', 7),
#  (u'waste', 7),
#  (u'indignation', 7),
#  (u'crisp', 7),
#  (u'avoid', 7),
#  (u'noisy', 7),
#  (u'contemptuously', 7),
#  (u'suspiciously', 7),
#  (u'wary', 6),
#  (u'somber', 6),
#  (u'hog', 6),
#  (u'vicious', 6),
#  (u'snarling', 6),
#  (u'ghastly', 6),
#  (u'struggle', 6),
#  (u'enraged', 6),
#  (u'scream', 6),
#  (u'resisting', 6),
#  (u'miserably', 6),
#  (u'subject', 6),
#  (u'argue', 6),
#  (u'stink', 6),
#  (u'evil', 6),
#  (u'haggard', 6),
#  (u'starvation', 6),
#  (u'confusion', 6),
#  (u'beating', 6),
#  (u'sob', 6),
#  (u'wasting', 6),
#  (u'bound', 6),
#  (u'jealousy', 6),
#  (u'sagging', 6),
#  (u'skip', 6),
#  (u'flash', 6),
#  (u'dig', 6),
#  (u'explosion', 6),
#  (u'cuckoo', 6),
#  (u'confused', 6),
#  (u'swore', 6),
#  (u'disagreeable', 6),
#  (u'troubled', 6),
#  (u'monster', 6),
#  (u'slap', 6),
#  (u'punished', 6),
#  (u'pressing', 6),
#  (u'darker', 6),
#  (u'idiot', 6),
#  (u'growling', 6),
#  (u'refuse', 6),
#  (u'bumped', 6),
#  (u'radical', 6),
#  (u'threatening', 6),
#  (u'extremely', 6),
#  (u'threaten', 6),
#  (u'loot', 6),
#  (u'uneasily', 6),
#  (u'obviously', 6),
#  (u'hates', 6),
#  (u'complaint', 6),
#  (u'crouching', 6),
#  (u'slip', 6),
#  (u'lame', 6),
#  (u'lunatic', 6),
#  (u'bothering', 6),
#  (u'sadly', 6),
#  (u'shell', 6),
#  (u'beg', 6),
#  (u'warily', 6),
#  (u'payment', 6),
#  (u'skinny', 6),
#  (u'crude', 6),
#  (u'sourly', 6),
#  (u'sagged', 6),
#  (u'slight', 6),
#  (u'smack', 5),
#  (u'bewildered', 5),
#  (u'punishment', 5),
#  (u'warn', 5),
#  (u'tramp', 5),
#  (u'bang', 5),
#  (u'rattle', 5),
#  (u'screwy', 5),
#  (u'uneasiness', 5),
#  (u'anxiously', 5),
#  (u'lazy', 5),
#  (u'irregular', 5),
#  (u'dumped', 5),
#  (u'brutal', 5),
#  (u'unfortunate', 5),
#  (u'falls', 5),
#  (u'ruined', 5),
#  (u'panicky', 5),
#  (u'terror', 5),
#  (u'gloomy', 5),
#  (u'feeble', 5),
#  (u'stole', 5),
#  (u'annoyance', 5),
#  (u'bite', 5),
#  (u'argument', 5),
#  (u'shocked', 5),
#  (u'insanity', 5),
#  (u'disappointment', 5),
#  (u'babbling', 5),
#  (u'starving', 5),
#  (u'grim', 5),
#  (u'strained', 5),
#  (u'scornful', 5),
#  (u'toilet', 5),
#  (u'sympathetically', 5),
#  (u'puffy', 5),
#  (u'lowering', 5),
#  (u'flap', 5),
#  (u'staggering', 5),
#  (u'spoils', 5),
#  (u'scar', 5),
#  (u'drained', 5),
#  (u'breaking', 5),
#  (u'deserted', 5),
#  (u'goofy', 5),
#  (u'bland', 5),
#  (u'pains', 5),
#  (u'trapped', 5),
#  (u'stall', 5),
#  (u'severe', 5),
#  (u'threats', 5),
#  (u'timidly', 5),
#  (u'hollow', 5),
#  (u'coarse', 5),
#  (u'mockingly', 5),
#  (u'demand', 5),
#  (u'uncertain', 5),
#  (u'frantic', 5),
#  (u'skeptical', 5),
#  (u'jumpy', 5),
#  (u'wrinkles', 5),
#  (u'lemon', 5),
#  (u'invalid', 5),
#  (u'upsetting', 5),
#  (u'delay', 5),
#  (u'undersized', 5),
#  (u'unpredictable', 5),
#  (u'confess', 5),
#  (u'straining', 5),
#  (u'misunderstand', 5),
#  (u'accusing', 5),
#  (u'disgustedly', 5),
#  (u'deny', 5),
#  (u'shy', 5),
#  (u'difficulties', 5),
#  (u'interfere', 5),
#  (u'spoil', 5),
#  (u'treat', 5),
#  (u'strange', 5),
#  (u'mistaken', 5),
#  (u'clouded', 5),
#  (u'grinding', 5),
#  (u'effeminate', 5),
#  (u'maroon', 5),
#  (u'pig', 5),
#  (u'poorly', 4),
#  (u'soiled', 4),
#  (u'degeneracy', 4),
#  (u'kidnap', 4),
#  (u'caution', 4),
#  (u'bunk', 4),
#  (u'unsteady', 4),
#  (u'tricked', 4),
#  (u'interrupt', 4),
#  (u'rocky', 4),
#  (u'mangled', 4),
#  (u'whining', 4),
#  (u'maniac', 4),
#  (u'peculiar', 4),
#  (u'bloated', 4),
#  (u'conceded', 4),
#  (u'pirate', 4),
#  (u'smelled', 4),
#  (u'humming', 4),
#  (u'warden', 4),
#  (u'weakly', 4),
#  (u'failing', 4),
#  (u'thumbs', 4),
#  (u'confront', 4),
#  (u'pugnacious', 4),
#  (u'stumble', 4),
#  (u'absent', 4),
#  (u'temper', 4),
#  (u'smelling', 4),
#  (u'stricken', 4),
#  (u'dissatisfied', 4),
#  (u'perplexity', 4),
#  (u'distaste', 4),
#  (u'dusty', 4),
#  (u'bruises', 4),
#  (u'fake', 4),
#  (u'divided', 4),
#  (u'crashed', 4),
#  (u'stupidly', 4),
#  (u'crept', 4),
#  (u'feverish', 4),
#  (u'servant', 4),
#  (u'scolded', 4),
#  (u'impossible', 4),
#  (u'distorted', 4),
#  (u'hack', 4),
#  (u'jolt', 4),
#  (u'hedge', 4),
#  (u'concern', 4),
#  (u'hurts', 4),
#  (u'harshly', 4),
#  (u'wounds', 4),
#  (u'profane', 4),
#  (u'devoid', 4),
#  (u'stranger', 4),
#  (u'strictly', 4),
#  (u'fright', 4),
#  (u'gambling', 4),
#  (u'dented', 4),
#  (u'brandy', 4),
#  (u'prying', 4),
#  (u'shattered', 4),
#  (u'preposterous', 4),
#  (u'hesitation', 4),
#  (u'horrified', 4),
#  (u'stiffness', 4),
#  (u'grill', 4),
#  (u'stubborn', 4),
#  (u'gasp', 4),
#  (u'bleak', 4),
#  (u'crowded', 4),
#  (u'absence', 4),
#  (u'goof', 4),
#  (u'hurting', 4),
#  (u'sucked', 4),
#  (u'scheme', 4),
#  (u'hopelessly', 4),
#  (u'betray', 4),
#  (u'fiend', 4),
#  (u'carelessness', 4),
#  (u'pound', 4),
#  (u'stubbornly', 4),
#  (u'motionless', 4),
#  (u'rumbling', 4),
#  (u'emergency', 4),
#  (u'savage', 4),
#  (u'crooks', 4),
#  (u'peculiarly', 4),
#  (u'drag', 4),
#  (u'annoyed', 4),
#  (u'rigid', 4),
#  (u'scratch', 4),
#  (u'nervousness', 4),
#  (u'accuse', 4),
#  (u'shock', 4),
#  (u'odd', 4),
#  (u'opaque', 4),
#  (u'punch', 4),
#  (u'examination', 4),
#  (u'thirsty', 4),
#  (u'pigs', 4),
#  (u'crash', 4),
#  (u'muddle', 4),
#  (u'bump', 4),
#  (u'burke', 4),
#  (u'biting', 4),
#  (u'negro', 4),
#  (u'asylum', 4),
#  (u'doubting', 4),
#  (u'derisively', 4),
#  (u'narrower', 4),
#  (u'gutter', 4),
#  (u'complicity', 4),
#  (u'glare', 4),
#  (u'leak', 4),
#  (u'secretive', 4),
#  (u'impatience', 4),
#  (u'limit', 4),
#  (u'unintelligible', 4),
#  (u'unsteadily', 4),
#  (u'limited', 3),
#  (u'protest', 3),
#  (u'whack', 3),
#  (u'screaming', 3),
#  (u'disturb', 3),
#  (u'louder', 3),
#  (u'stern', 3),
#  (u'plot', 3),
#  (u'scarred', 3),
#  (u'phony', 3),
#  (u'quarrel', 3),
#  (u'quivering', 3),
#  (u'complaining', 3),
#  (u'damage', 3),
#  (u'resignation', 3),
#  (u'demanding', 3),
#  (u'complacent', 3),
#  (u'weakness', 3),
#  (u'stealing', 3),
#  (u'fugitive', 3),
#  (u'wildly', 3),
#  (u'wasted', 3),
#  (u'idle', 3),
#  (u'humble', 3),
#  (u'defiantly', 3),
#  (u'painfully', 3),
#  (u'debts', 3),
#  (u'bust', 3),
#  (u'disgust', 3),
#  (u'emphatically', 3),
#  (u'patch', 3),
#  (u'steal', 3),
#  (u'debt', 3),
#  (u'disorderly', 3),
#  (u'chill', 3),
#  (u'abrupt', 3),
#  (u'expenses', 3),
#  (u'growl', 3),
#  (u'destroy', 3),
#  (u'failure', 3),
#  (u'surrender', 3),
#  (u'smashed', 3),
#  (u'disgrace', 3),
#  (u'battle', 3),
#  (u'disgusting', 3),
#  (u'cloudy', 3),
#  (u'unexpected', 3),
#  (u'slower', 3),
#  (u'slowed', 3),
#  (u'riot', 3),
#  (u'slowness', 3),
#  (u'disgusted', 3),
#  (u'awkward', 3),
#  (u'killer', 3),
#  (u'owing', 3),
#  (u'flaccid', 3),
#  (u'complicated', 3),
#  (u'lump', 3),
#  (u'plea', 3),
#  (u'butt', 3),
#  (u'cracks', 3),
#  (u'sag', 3),
#  (u'slam', 3),
#  (u'hungry', 3),
#  (u'aggressive', 3),
#  (u'crashing', 3),
#  (u'stain', 3),
#  (u'begging', 3),
#  (u'liable', 3),
#  (u'resentment', 3),
#  (u'liberal', 3),
#  (u'symptoms', 3),
#  (u'dubious', 3),
#  (u'struggling', 3),
#  (u'domineering', 3),
#  (u'idiotically', 3),
#  (u'violent', 3),
#  (u'robbery', 3),
#  (u'moon', 3),
#  (u'violence', 3),
#  (u'sneering', 3),
#  (u'brute', 3),
#  (u'fraud', 3),
#  (u'ruffian', 3),
#  (u'frighten', 3),
#  (u'accusingly', 3),
#  (u'ax', 3),
#  (u'seriousness', 3),
#  (u'stocks', 3),
#  (u'lack', 3),
#  (u'weariness', 3),
#  (u'subjected', 3),
#  (u'removal', 3),
#  (u'horror', 3),
#  (u'manslaughter', 3),
#  (u'crush', 3),
#  (u'coroner', 3),
#  (u'revenge', 3),
#  (u'uneven', 3),
#  (u'skepticism', 3),
#  (u'armed', 3),
#  (u'mysterious', 3),
#  (u'wretched', 3),
#  (u'dazed', 3),
#  (u'minimum', 3),
#  (u'imitation', 3),
#  (u'numb', 3),
#  (u'departure', 3),
#  (u'crafty', 3),
#  (u'anonymous', 3),
#  (u'stains', 3),
#  (u'wry', 3),
#  (u'sucker', 3),
#  (u'pigeon', 3),
#  (u'cyclone', 3),
#  (u'tiresome', 3),
#  (u'issue', 3),
#  (u'threat', 3),
#  (u'blush', 3),
#  (u'hangs', 3),
#  (u'grimy', 3),
#  (u'blindly', 3),
#  (u'ungodly', 3),
#  (u'insulted', 3),
#  (u'cave', 3),
#  (u'frail', 3),
#  (u'serene', 3),
#  (u'stumped', 3),
#  (u'hardened', 3),
#  (u'obscure', 3),
#  (u'coward', 3),
#  (u'drooping', 3),
#  (u'corruption', 3),
#  (u'regretfully', 3),
#  (u'indefinite', 3),
#  (u'buck', 3),
#  (u'shove', 3),
#  (u'ached', 3),
#  (u'distrust', 3),
#  (u'urgent', 3),
#  (u'pet', 3),
#  (u'gnome', 3),
#  (u'bored', 3),
#  (u'bulbous', 3),
#  (u'gang', 3),
#  (u'dislike', 3),
#  (u'uncomfortably', 3),
#  (u'malice', 3),
#  (u'crook', 3),
#  (u'depression', 3),
#  (u'extreme', 3),
#  (u'scandal', 3),
#  (u'retreated', 3),
#  (u'struggled', 3),
#  (u'cage', 3),
#  (u'bewilderment', 3),
#  (u'greedy', 3),
#  (u'sneer', 3),
#  (u'impulsive', 3),
#  (u'chilly', 3),
#  (u'bulky', 3),
#  (u'confuse', 3),
#  (u'sack', 3),
#  (u'ancient', 3),
#  (u'attack', 3),
#  (u'tortured', 3),
#  (u'miserable', 3),
#  (u'cracking', 3),
#  (u'dandruff', 3),
#  (u'unfinished', 3),
#  (u'terminal', 3),
#  (u'insulting', 3),
#  (u'busted', 3),
#  (u'perplexed', 3),
#  (u'bullying', 3),
#  (u'thief', 3),
#  (u'leery', 3),
#  (u'ashamed', 3),
#  (u'blackness', 3),
#  (u'fleshy', 3),
#  (u'shyness', 3),
#  (u'cruel', 3),
#  (u'rickety', 3),
#  (u'crummy', 3),
#  (u'reckless', 3),
#  (u'stab', 3),
#  (u'stunt', 3),
#  (u'reprovingly', 3),
#  (u'fawn', 2),
#  (u'foul', 2),
#  (u'defraud', 2),
#  (u'scold', 2),
#  (u'nigger', 2),
#  (u'cloudiness', 2),
#  (u'overdo', 2),
#  (u'haughtily', 2),
#  (u'wreck', 2),
#  (u'ridicule', 2),
#  (u'expose', 2),
#  (u'hostile', 2),
#  (u'scolding', 2),
#  (u'neglect', 2),
#  (u'greed', 2),
#  (u'madly', 2),
#  (u'shadowy', 2),
#  (u'explode', 2),
#  (u'wariness', 2),
#  (u'whip', 2),
#  (u'revolting', 2),
#  (u'naughty', 2),
#  (u'concussion', 2),
#  (u'offhand', 2),
#  (u'crawl', 2),
#  (u'shyly', 2),
#  (u'grind', 2),
#  (u'relapse', 2),
#  (u'impotent', 2),
#  (u'object', 2),
#  (u'peevish', 2),
#  (u'incomplete', 2),
#  (u'sneaking', 2),
#  (u'latent', 2),
#  (u'foolishly', 2),
#  (u'skeptically', 2),
#  (u'unexpectedly', 2),
#  (u'diffidence', 2),
#  (u'temptation', 2),
#  (u'scrap', 2),
#  (u'unable', 2),
#  (u'ignorance', 2),
#  (u'weary', 2),
#  (u'defiance', 2),
#  (u'pity', 2),
#  (u'brat', 2),
#  (u'brag', 2),
#  (u'dents', 2),
#  (u'obscenity', 2),
#  (u'spear', 2),
#  (u'lick', 2),
#  (u'sting', 2),
#  (u'haphazard', 2),
#  (u'rail', 2),
#  (u'incredulously', 2),
#  (u'possessed', 2),
#  (u'coldness', 2),
#  (u'departed', 2),
#  (u'divide', 2),
#  (u'rumor', 2),
#  (u'addicts', 2),
#  (u'beast', 2),
#  (u'contrariness', 2),
#  ...]
