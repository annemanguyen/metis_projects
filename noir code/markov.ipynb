# %%
import glob
import os
from collections import defaultdict

# %%
import random

# %%
texts = []
path = '/home/amn34/metis/stuff/noirs/chandler/'
for books in glob.glob(os.path.join(path, '*.txt')):
    doc = open(books).read()
    texts.append(doc.replace('-',' ').split())

# %%
texts = [item for sublist in texts for item in sublist]

# %%
cdict = {}

for i in range(len(texts)-2):
    key = (texts[i], texts[i+1])
    follow = texts[i+2]
    
    if key in cdict:
        cdict[key].append(follow)
    else: cdict[key] = [follow]

# %%
while True:
    if random.choice(cstartdict.keys())

output = []
output.extend(start)

startposs = [i for i in cmiddict.keys() if i[0] == start[1]]

output.append(random.choice(startposs)[1])

# %%
print output
# Out:
# ["Murdock's", 'expense."', 'His', 'voice', 'voice', 'cackled.', 'I', 'hung', 'up', 'in', 'it."', "Vannier's", 'olive', 'olive', 'in', 'a', 'jam."', 'Ohls']

# %%
nextword[1]
# Out:
# 'Ohls'

# %%
for i in cstartdict.keys():
    if i[0] == 'Ohls':
        print i
# Out:
# ('Ohls', 'growled')
# ('Ohls', 'yawned')
# ('Ohls', 'said.')
# ('Ohls', 'waited')
# ('Ohls', 'having')
# ('Ohls', 'made')
# ('Ohls', 'sat')
# ('Ohls', 'reached')
# ('Ohls', 'said:')
# ('Ohls', 'went')
# ('Ohls', 'snarled')
# ('Ohls', 'grinned.')
# ('Ohls', 'jerked')
# ('Ohls', 'said')
# ('Ohls', 'stared')
# ('Ohls', 'shook')
# ('Ohls', 'pulled')
# ('Ohls', 'lifted')
# ('Ohls', 'looked')
# ('Ohls', 'cocked')
# ('Ohls', 'asked.')
# ('Ohls', 'showed')
# ('Ohls', 'stood')
# ('Ohls', 'called')
# ('Ohls', 'that')
# ('Ohls', 'lit')
# ('Ohls', 'took')
# ('Ohls', 'came')
# ('Ohls', 'backed')
# ('Ohls', 'spread')
# ('Ohls', 'nodded.')
# ('Ohls', 'said,')
# ('Ohls', 'broke')
# ('Ohls', 'and')
# ('Ohls', 'or')
# ('Ohls', 'side')
# ('Ohls', 'of')
# ('Ohls', 'nodded')
# ('Ohls', 'was')
# ('Ohls', 'at')
# ('Ohls', 'pushed')
# ('Ohls', 'told')
# ('Ohls', 'asked')
# ('Ohls', 'laughed.')
# ('Ohls', 'had')
# ('Ohls', 'sighed')
# ('Ohls', "didn't")
# ('Ohls', 'gets')

# %%
for i in range(1,50):
    nextword = (output[-2], output[-1])
    if nextword in cmiddict.keys():
        output.append(random.choice(cmiddict[nextword]))
    else:
        midposs = [i for i in cstartdict.keys() if i[0] == nextword[1]]
        restart = random.choice(midposs)
        output.extend(restart)
        
if output[-1][-1] != '.':
    output.extend(cenddict[random.choice(cenddict.keys())])

print ' '.join(output)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-341-c85c49fc317d> in <module>()
#       5     else:
#       6         midposs = [i for i in cstartdict.keys() if i[0] == nextword[1]]
# ----> 7         restart = random.choice(midposs)
#       8         output.extend(restart)
#       9
#
# /home/amn34/anaconda2/lib/python2.7/random.pyc in choice(self, seq)
#     273     def choice(self, seq):
#     274         """Choose a random element from a non-empty sequence."""
# --> 275         return seq[int(self.random() * len(seq))]  # raises IndexError if seq is empty
#     276
#     277     def shuffle(self, x, random=None):
#
# IndexError: list index out of range

# %%
startposs
# Out:
# [('dry,', 'husky'),
#  ('dry,', 'Doctor.'),
#  ('dry,', 'folded'),
#  ('dry,', 'Tejjy'),
#  ('dry,', 'and')]

# %%
output
# Out:
# ['Very', 'dry,', 'Doctor.', 'Very']

# %%
cmiddict[('Doctor.', 'Very')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-304-841a18b045a2> in <module>()
# ----> 1 cmiddict[('Doctor.', 'Very')]
#
# KeyError: ('Doctor.', 'Very')

# %%
midwords = sorted(cmiddict.keys())

# %%
midwords[4000:5000]
# Out:
# [('"Nuts.', 'You'),
#  ('"O.K.', 'Alfred,"'),
#  ('"O.K.', 'I'),
#  ('"O.K.', "I'm"),
#  ('"O.K.', 'if'),
#  ('"O.K.,"', 'he'),
#  ('"Obviously', 'his'),
#  ('"Obviously', 'there'),
#  ('"Obviously,', 'I'),
#  ('"Of', 'course'),
#  ('"Of', 'course,'),
#  ('"Of', 'course,"'),
#  ('"Of', 'course.'),
#  ('"Of', 'course."'),
#  ('"Of', 'dark'),
#  ('"Off', 'the'),
#  ('"Office"', 'in'),
#  ('"Office.', 'Your'),
#  ('"Officers', 'of'),
#  ('"Oh', 'Christ,'),
#  ('"Oh', 'Gillerlain'),
#  ('"Oh', 'I'),
#  ('"Oh', 'Mr.'),
#  ('"Oh', 'a'),
#  ('"Oh', 'boy,"'),
#  ('"Oh', 'boy.'),
#  ('"Oh', 'brother,'),
#  ('"Oh', 'by'),
#  ('"Oh', 'dear,"'),
#  ('"Oh', 'for'),
#  ('"Oh', 'guns,"'),
#  ('"Oh', "he's"),
#  ('"Oh', 'hell'),
#  ('"Oh', 'hell,"'),
#  ('"Oh', 'hell.'),
#  ('"Oh', 'ho,"'),
#  ('"Oh', 'in'),
#  ('"Oh', 'it'),
#  ('"Oh', 'just'),
#  ('"Oh', 'my'),
#  ('"Oh', 'no,"'),
#  ('"Oh', 'no.'),
#  ('"Oh', 'no."'),
#  ('"Oh', 'not'),
#  ('"Oh', 'oh,"'),
#  ('"Oh', 'oh.'),
#  ('"Oh', 'pal.'),
# ...
